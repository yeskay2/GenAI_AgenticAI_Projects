# %% [markdown]
# # 🤝 Mitmeagendi töövoosüsteemid GitHubi mudelitega (Python)
#
# ## 📋 Õpieesmärgid
#
# See märkmik näitab, kuidas luua keerukaid mitmeagendi süsteeme, kasutades Microsofti agendiraamistikku koos GitHubi mudelitega. Õpid korraldama mitme spetsialiseeritud agendi koostööd, et lahendada keerulisi probleeme struktureeritud töövoogude kaudu.
#
# **Mitmeagendi võimekused, mida sa õpid:**
# - 👥 **Agendi koostöö**: Mitme agendi ühine töö ühiste eesmärkide saavutamiseks
# - 🔄 **Töövoo korraldamine**: Struktureeritud agenditevahelise suhtluse koordineerimine
# - 🎭 **Rollide spetsialiseerumine**: Agendid, kellel on erinevad isiksused ja ekspertvaldkonnad
# - 📋 **Kvaliteedi tagamine**: Töö ülevaatamine ja täiustamine agendite koostöö kaudu
#
# ## 🎯 Mitmeagendi arhitektuuri kontseptsioonid
#
# ### Mitmeagendi põhimõtted
# - **Tööjaotus**: Iga agent on spetsialiseerunud konkreetsele valdkonnale
# - **Koostööpõhine otsustamine**: Agendid vaatavad üle ja täiustavad üksteise tööd
# - **Töövoo koordineerimine**: Struktureeritud ülesannete üleandmine ja suhtlusmustrid
# - **Kvaliteedi parandamine**: Iteratiivne täiustamine mitme perspektiivi analüüsi kaudu
#
# ### Agendi suhtlusmustrid
# - **Järjestikune töötlemine**: Lineaarne töövoog, kus agendid osalevad kindlas järjekorras
# - **Eakaaslaste ülevaatus**: Agendid valideerivad ja täiustavad üksteise väljundeid
# - **Hierarhiline struktuur**: Juhtivad agendid koordineerivad spetsialiste
# - **Konsensuse saavutamine**: Mitme agendi panus lõplike otsuste tegemisel
#
# ## 🏗️ Tehniline arhitektuur
#
# ### Töövoosüsteemi komponendid
# - **Microsofti agendiraamistik**: Pythonis rakendatud arenenud töövoo tugi
# - **WorkflowBuilder**: Deklaratiivne töövoo määratlemise ja täitmise mootor
# - **Agendi koordineerimine**: Struktureeritud suhtlus- ja ülesannete üleandmise mehhanismid
# - **Sündmuspõhine töötlemine**: Reaktiivne töövoo täitmine agendi väljundite põhjal
#
# ### Mitmeagendi protsessivoog
# ```python
# User Request → Agent 1 (Specialist) → Agent 2 (Reviewer) → Quality Check
#                 ↓                      ↓                    ↓
#          Initial Solution → Review & Feedback → Refined Output → Final Result
# ```
#
# ## 🎭 Agendi rollide näited
#
# ### Hotelli concierge-süsteem
# See märkmik demonstreerib reisisoovituste süsteemi spetsialiseeritud rollidega:
#
# #### 🏨 **Vastuvõtuagent**
# - **Ekspertiis**: Reisisoovitused ja kohalikud teadmised
# - **Isiksus**: Tõhus, kogenud, lühike suhtlusstiil
# - **Kohustused**: Esialgsete reisisoovituste ja tegevuste loomine
#
# #### 🎩 **Concierge-agent**
# - **Ekspertiis**: Autentsed kohalikud kogemused ja kvaliteedi hindamine
# - **Isiksus**: Nõudlik, keskendunud mitte-turistlikele soovitustele
# - **Kohustused**: Reisisoovituste ülevaatamine ja autentsuse parandamine
#
# ## 🔧 Tehniline teostus
#
# ### Töövoo arhitektuur
# - **Agendi määratlemine**: Spetsialiseeritud juhised ja isiksuse konfiguratsioon
# - **Workflow Builder**: Deklaratiivne töövoo määratlemine sündmuste käsitlemisega
# - **Suhtlusprotokoll**: Struktureeritud sõnumivahetus agentide vahel
# - **Tulemuste koondamine**: Mitme agendi perspektiivide väljundite ühendamine
#
# ### Sündmuspõhine koordineerimine
# - **WorkflowEvent**: Käivituspunktid agendi aktiveerimiseks ja ülesannete üleandmiseks
# - **OutputEvent**: Struktureeritud andmevahetus agentide vahel
# - **Kvaliteedikontrollid**: Valideerimispunktid töövoo protsessis
# - **Tagasiside tsüklid**: Iteratiivne täiustamine agendite koostöö kaudu
#
# ## ⚙️ Eeltingimused ja seadistamine
#
# **Nõutavad sõltuvused:**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **Keskkonna konfiguratsioon (.env fail):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Mitmeagendi disainimustrid
#
# ### 1. **Tootja-tarbija muster**
# - Spetsialiseeritud agendid loovad sisu, mida teised üle vaatavad
# - Selged ülesannete üleandmise punktid ja andmevahetusprotokollid
# - Kvaliteedi tagamine sõltumatu ülevaatuse kaudu
# - Iteratiivsed täiustamise ja parandamise tsüklid
#
# ### 2. **Komitee muster**
# - Mitme agendi erinevad perspektiivid
# - Konsensuse saavutamine struktureeritud arutelu kaudu
# - Demokraatlik otsustamine kaalutud arvamustega
# - Konfliktide lahendamine ja viigiseisu murdmise mehhanismid
#
# ### 3. **Hierarhiline muster**
# - Juhtivad agendid koordineerivad spetsialiste
# - Selged autoriteedistruktuurid ja otsuste voog
# - Eskaleerimisteed keerukate otsuste jaoks
# - Tulemuslikkuse jälgimine ja kvaliteedikontroll
#
# ### 4. **Torujoone muster**
# - Järjestikune töötlemine spetsialiseeritud etappidega
# - Iga agent lisab väärtust oma ekspertiisivaldkonnas
# - Tõhus läbilaskevõime paralleelse töötlemise kaudu
# - Vigade käsitlemine ja taastamine igas etapis
#
# ## 🚀 Täiustatud mitmeagendi funktsioonid
#
# ### Töövoo korraldamine
# - **Dünaamiline suunamine**: Kontekstipõhine agendi valik ja suunamine
# - **Paralleelne töötlemine**: Agentide samaaegne täitmine efektiivsuse tagamiseks
# - **Vigade taastamine**: Agentide rikete ja korduste sujuv käsitlemine
# - **Tulemuslikkuse jälgimine**: Töövoo täitmise jälgimine ja optimeerimine
#
# ### Agendi suhtlus
# - **Struktureeritud sõnumivahetus**: Tüübikindlad suhtlusprotokollid
# - **Konteksti säilitamine**: Vestluse ajaloo säilitamine agentide vahel
# - **Metaandmete edastamine**: Rikkalik teabevahetus tekstisisust kaugemale
# - **Sündmuste edastamine**: Avaldamise-tellimise mustrid koordineerimiseks
#
# ### Kvaliteedi tagamine
# - **Mitme perspektiivi ülevaatus**: Erinevad agendid toovad unikaalseid vaatenurki
# - **Iteratiivne täiustamine**: Progressiivne täiustamine koostöö kaudu
# - **Valideerimispunktid**: Kvaliteedikontrollid kogu töövoo vältel
# - **Tulemuslikkuse mõõdikud**: Koostöö tõhususe mõõtmine
#
# ## 📊 Kasutusalad ja rakendused
#
# ### Äriliste protsesside automatiseerimine
# - Dokumentide ülevaatamise ja kinnitamise töövood
# - Klienditeeninduse eskaleerimissüsteemid
# - Kvaliteedi tagamine ja vastavuse kontrollimine
# - Mitmeastmeline sisu loomine ja redigeerimine
#
# ### Uurimine ja analüüs
# - Teadusartiklite eakaaslaste ülevaatussüsteemid
# - Mitme analüütiku finantsanalüüs
# - Koostööpõhine aruannete kirjutamine ja faktide kontrollimine
# - Akadeemiliste artiklite ülevaatus ja täiustamine
#
# ### Loov koostöö
# - Sisu loomine koos toimetajate ja ülevaatajatega
# - Mitme perspektiivi loov ajurünnak
# - Iteratiivne disain ja tagasisidesüsteemid
# - Koostööpõhine lugude loomine ja maailmade ehitamine
#
# Kas oled valmis korraldama intelligentset mitmeagendi koostööd? Loome süsteeme, kus agendid töötavad koos nagu kõrge jõudlusega meeskond! 🌟🤖

# %%
! pip install agent-framework-core -U

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent

# %%
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings

# %%
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# Workflow output: Visit the Louvre Museum for an unparalleled art experience.

# %% [markdown]
# ---
#
# **Lahtiütlus**:
# See dokument on tõlgitud AI tõlketeenuse [Co-op Translator](https://github.com/Azure/co-op-translator) abil. Kuigi püüame tagada täpsust, palume arvestada, et automaatsed tõlked võivad sisaldada vigu või ebatäpsusi. Algne dokument selle algses keeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitame kasutada professionaalset inimtõlget. Me ei vastuta selle tõlke kasutamisest tulenevate arusaamatuste või valesti tõlgenduste eest.
