# %% [markdown]
# # 🤝 Sistemi di Workflow Multi-Agente con Modelli GitHub (Python)
#
# ## 📋 Obiettivi di Apprendimento
#
# Questo notebook dimostra come costruire sistemi multi-agente sofisticati utilizzando il Microsoft Agent Framework con Modelli GitHub. Imparerai a orchestrare più agenti specializzati che lavorano insieme per risolvere problemi complessi attraverso workflow strutturati.
#
# **Capacità Multi-Agente che Svilupperai:**
# - 👥 **Collaborazione tra Agenti**: Più agenti che lavorano insieme verso obiettivi comuni
# - 🔄 **Orchestrazione del Workflow**: Coordinazione strutturata delle interazioni tra agenti
# - 🎭 **Specializzazione dei Ruoli**: Agenti con personalità e aree di competenza distinte
# - 📋 **Assicurazione della Qualità**: Revisione e perfezionamento attraverso la collaborazione tra agenti
#
# ## 🎯 Concetti di Architettura Multi-Agente
#
# ### Principi Fondamentali Multi-Agente
# - **Divisione del Lavoro**: Ogni agente si specializza in un dominio specifico
# - **Decisioni Collaborative**: Gli agenti rivedono e perfezionano il lavoro degli altri
# - **Coordinazione del Workflow**: Passaggi strutturati e modelli di comunicazione
# - **Miglioramento della Qualità**: Perfezionamento iterativo attraverso analisi multi-prospettiva
#
# ### Modelli di Interazione tra Agenti
# - **Elaborazione Sequenziale**: Workflow lineare con partecipazione ordinata degli agenti
# - **Revisione tra Pari**: Gli agenti convalidano e migliorano i risultati degli altri
# - **Struttura Gerarchica**: Agenti leader che coordinano specialisti subordinati
# - **Costruzione del Consenso**: Più agenti che contribuiscono alle decisioni finali
#
# ## 🏗️ Architettura Tecnica
#
# ### Componenti del Sistema di Workflow
# - **Microsoft Agent Framework**: Implementazione Python con supporto avanzato per workflow
# - **WorkflowBuilder**: Motore di definizione ed esecuzione del workflow dichiarativo
# - **Coordinazione tra Agenti**: Meccanismi strutturati di comunicazione e passaggio
# - **Elaborazione Event-Driven**: Esecuzione reattiva del workflow basata sui risultati degli agenti
#
# ### Flusso del Processo Multi-Agente
# ```python
# User Request → Agent 1 (Specialist) → Agent 2 (Reviewer) → Quality Check
#                 ↓                      ↓                    ↓
#          Initial Solution → Review & Feedback → Refined Output → Final Result
# ```
#
# ## 🎭 Esempi di Ruoli degli Agenti
#
# ### Sistema di Concierge Alberghiero
# Questo notebook dimostra un sistema di raccomandazioni di viaggio con ruoli specializzati:
#
# #### 🏨 **Agente Reception**
# - **Competenza**: Raccomandazioni di viaggio e conoscenza locale
# - **Personalità**: Efficiente, esperto, stile di comunicazione conciso
# - **Responsabilità**: Generare suggerimenti iniziali di viaggio e attività
#
# #### 🎩 **Agente Concierge**
# - **Competenza**: Esperienze locali autentiche e valutazione della qualità
# - **Personalità**: Esigente, focalizzato su raccomandazioni non turistiche
# - **Responsabilità**: Rivedere e perfezionare i suggerimenti di viaggio per autenticità
#
# ## 🔧 Implementazione Tecnica
#
# ### Architettura del Workflow
# - **Definizione degli Agenti**: Configurazione di istruzioni specializzate e personalità
# - **Workflow Builder**: Definizione del workflow dichiarativo con gestione degli eventi
# - **Protocollo di Comunicazione**: Passaggio strutturato di messaggi tra agenti
# - **Aggregazione dei Risultati**: Combinazione dei risultati da prospettive multiple degli agenti
#
# ### Coordinazione Event-Driven
# - **WorkflowEvent**: Punti di attivazione per l'attivazione degli agenti e i passaggi
# - **OutputEvent**: Scambio strutturato di dati tra agenti
# - **Quality Gates**: Punti di validazione nel processo del workflow
# - **Feedback Loops**: Perfezionamento iterativo attraverso la collaborazione tra agenti
#
# ## ⚙️ Prerequisiti e Configurazione
#
#
# **Dipendenze Necessarie:**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **Configurazione dell'Ambiente (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Modelli di Design Multi-Agente
#
# ### 1. **Modello Produttore-Consumatore**
# - Agenti specializzati generano contenuti per la revisione da parte di altri
# - Punti di passaggio chiari e protocolli di scambio dati
# - Assicurazione della qualità attraverso revisione indipendente
# - Cicli di perfezionamento e miglioramento iterativo
#
# ### 2. **Modello Comitato**
# - Più agenti che contribuiscono con prospettive diverse
# - Costruzione del consenso attraverso discussioni strutturate
# - Decisioni democratiche con opinioni ponderate
# - Meccanismi di risoluzione dei conflitti e di rottura dei pareggi
#
# ### 3. **Modello Gerarchico**
# - Agenti leader che coordinano specialisti subordinati
# - Strutture di autorità chiare e flusso decisionale
# - Percorsi di escalation per decisioni complesse
# - Monitoraggio delle prestazioni e controllo della qualità
#
# ### 4. **Modello Pipeline**
# - Elaborazione sequenziale con fasi specializzate
# - Ogni agente aggiunge valore nel proprio dominio di competenza
# - Efficienza attraverso l'elaborazione parallela
# - Gestione degli errori e recupero in ogni fase
#
# ## 🚀 Funzionalità Avanzate Multi-Agente
#
# ### Orchestrazione del Workflow
# - **Routing Dinamico**: Selezione e routing degli agenti basati sul contesto
# - **Elaborazione Parallela**: Esecuzione concorrente degli agenti per efficienza
# - **Recupero dagli Errori**: Gestione elegante dei fallimenti degli agenti e dei tentativi
# - **Monitoraggio delle Prestazioni**: Tracciamento dell'esecuzione del workflow e ottimizzazione
#
# ### Comunicazione tra Agenti
# - **Messaggistica Strutturata**: Protocolli di comunicazione sicuri per i tipi
# - **Preservazione del Contesto**: Mantenimento della cronologia delle conversazioni tra agenti
# - **Passaggio di Metadata**: Scambio ricco di informazioni oltre al contenuto testuale
# - **Event Broadcasting**: Modelli publish-subscribe per la coordinazione
#
# ### Assicurazione della Qualità
# - **Revisione Multi-Prospettiva**: Diversi agenti che portano punti di vista unici
# - **Perfezionamento Iterativo**: Miglioramento progressivo attraverso la collaborazione
# - **Punti di Validazione**: Quality gates lungo il workflow
# - **Metriche di Prestazione**: Misurazione dell'efficacia della collaborazione
#
# ## 📊 Casi d'Uso e Applicazioni
#
# ### Automazione dei Processi Aziendali
# - Workflow di revisione e approvazione dei documenti
# - Sistemi di escalation per il servizio clienti
# - Controllo qualità e verifica della conformità
# - Creazione e modifica di contenuti multi-fase
#
# ### Ricerca e Analisi
# - Sistemi di revisione tra pari per articoli di ricerca
# - Analisi finanziaria multi-analista
# - Scrittura collaborativa di report e verifica dei fatti
# - Revisione e miglioramento di articoli accademici
#
# ### Collaborazione Creativa
# - Creazione di contenuti con editor e revisori
# - Brainstorming creativo multi-prospettiva
# - Sistemi iterativi di design e feedback
# - Narrazione collaborativa e costruzione di mondi
#
# Pronto a orchestrare collaborazioni intelligenti multi-agente? Costruiamo sistemi in cui gli agenti lavorano insieme come un team ad alte prestazioni! 🌟🤖

# %%
! pip install agent-framework-core -U

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent

# %%
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings

# %%
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# Workflow output: Visit the Louvre Museum for an unparalleled art experience.

# %% [markdown]
# ---
#
# **Disclaimer**:
# Questo documento è stato tradotto utilizzando il servizio di traduzione automatica [Co-op Translator](https://github.com/Azure/co-op-translator). Sebbene ci impegniamo per garantire l'accuratezza, si prega di notare che le traduzioni automatiche possono contenere errori o imprecisioni. Il documento originale nella sua lingua nativa dovrebbe essere considerato la fonte autorevole. Per informazioni critiche, si raccomanda una traduzione professionale effettuata da un traduttore umano. Non siamo responsabili per eventuali incomprensioni o interpretazioni errate derivanti dall'uso di questa traduzione.
