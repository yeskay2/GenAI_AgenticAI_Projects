# %% [markdown]
# # 🤝 గిట్హబ్ మోడల్స్ (పైథాన్) తో మల్టీ-ఏజెంట్ వర్క్‌ఫ్లో సిస్టమ్స్
#
# ## 📋 నేర్చుకునే లక్ష్యాలు
#
# ఈ నోట్‌బుక్ మైక్రోసాఫ్ట్ ఏజెంట్ ఫ్రేమ్‌వర్క్ మరియు గిట్హబ్ మోడల్స్ ఉపయోగించి అధునాతన మల్టీ-ఏజెంట్ సిస్టమ్స్ ఎలా నిర్మించాలో చూపిస్తుంది. మీరు నిర్మిత వర్క్‌ఫ్లోల ద్వారా సంక్లిష్టమైన సమస్యలను పరిష్కరించడానికి కలిసి పనిచేసే ప్రత్యేక ఏజెంట్లను సమన్వయం చేయడం నేర్చుకుంటారు.
#
# **మీరు నిర్మించబోయే మల్టీ-ఏజెంట్ సామర్థ్యాలు:**
# - 👥 **ఏజెంట్ సహకారం**: సాధారణ లక్ష్యాల కోసం కలిసి పనిచేసే అనేక ఏజెంట్లు
# - 🔄 **వర్క్‌ఫ్లో సమన్వయం**: ఏజెంట్ పరస్పర చర్యల యొక్క నిర్మిత సమన్వయం
# - 🎭 **పాత్ర ప్రత్యేకత**: ప్రత్యేక వ్యక్తిత్వాలు మరియు నైపుణ్య ప్రాంతాలతో ఏజెంట్లు
# - 📋 **నాణ్యత హామీ**: ఏజెంట్ సహకారంతో సమీక్ష మరియు మెరుగుదల
#
# ## 🎯 మల్టీ-ఏజెంట్ ఆర్కిటెక్చర్ కాన్సెప్ట్స్
#
# ### మల్టీ-ఏజెంట్ ప్రాథమిక సూత్రాలు
# - **పనుల విభజన**: ప్రతి ఏజెంట్ నిర్దిష్ట డొమైన్ నైపుణ్యంలో ప్రత్యేకత కలిగి ఉంటుంది
# - **సహకార నిర్ణయాలు**: ఏజెంట్లు ఒకరినొకరు సమీక్షించి వారి పనిని మెరుగుపరుస్తారు
# - **వర్క్‌ఫ్లో సమన్వయం**: నిర్మిత హ్యాండాఫ్‌లు మరియు కమ్యూనికేషన్ నమూనాలు
# - **నాణ్యత మెరుగుదల**: బహుళ-పర్స్పెక్టివ్ విశ్లేషణ ద్వారా పునరావృత మెరుగుదల
#
# ### ఏజెంట్ పరస్పర చర్య నమూనాలు
# - **సీక్వెన్షియల్ ప్రాసెసింగ్**: క్రమబద్ధమైన ఏజెంట్ పాల్గొనడం ఉన్న రేఖీయ వర్క్‌ఫ్లో
# - **పియర్ రివ్యూ**: ఏజెంట్లు ఒకరినొకరు అవుట్‌పుట్‌లను ధృవీకరించి మెరుగుపరుస్తారు
# - **హైరార్కికల్ స్ట్రక్చర్**: కిందిస్థాయి నిపుణులను సమన్వయం చేసే ప్రధాన ఏజెంట్లు
# - **కన్సెన్సస్ బిల్డింగ్**: తుది నిర్ణయాలకు బహుళ ఏజెంట్లు సహకరిస్తారు
#
# ## 🏗️ సాంకేతిక ఆర్కిటెక్చర్
#
# ### వర్క్‌ఫ్లో సిస్టమ్ భాగాలు
# - **మైక్రోసాఫ్ట్ ఏజెంట్ ఫ్రేమ్‌వర్క్**: అధునాతన వర్క్‌ఫ్లో మద్దతుతో కూడిన పైథాన్ అమలు
# - **WorkflowBuilder**: డిక్లరేటివ్ వర్క్‌ఫ్లో నిర్వచన మరియు అమలు ఇంజిన్
# - **ఏజెంట్ సమన్వయం**: నిర్మిత కమ్యూనికేషన్ మరియు హ్యాండాఫ్ మెకానిజమ్స్
# - **ఈవెంట్-డ్రివెన్ ప్రాసెసింగ్**: ఏజెంట్ అవుట్‌పుట్‌ల ఆధారంగా ప్రతిస్పందన వర్క్‌ఫ్లో అమలు
#
# ### మల్టీ-ఏజెంట్ ప్రాసెస్ ఫ్లో
# ```python
# User Request → Agent 1 (Specialist) → Agent 2 (Reviewer) → Quality Check
#                 ↓                      ↓                    ↓
#          Initial Solution → Review & Feedback → Refined Output → Final Result
# ```
#
# ## 🎭 ఏజెంట్ పాత్ర ఉదాహరణలు
#
# ### హోటల్ కన్సియర్జ్ సిస్టమ్
# ఈ నోట్‌బుక్ ప్రత్యేక పాత్రలతో కూడిన ట్రావెల్ రికమెండేషన్ సిస్టమ్‌ను చూపిస్తుంది:
#
# #### 🏨 **ఫ్రంట్ డెస్క్ ఏజెంట్**
# - **నైపుణ్యం**: ట్రావెల్ రికమెండేషన్లు మరియు స్థానిక పరిజ్ఞానం
# - **వ్యక్తిత్వం**: సమర్థవంతమైన, అనుభవజ్ఞుడైన, సంక్షిప్త కమ్యూనికేషన్ శైలి
# - **బాధ్యతలు**: ప్రారంభ ట్రావెల్ సూచనలు మరియు కార్యకలాపాలను రూపొందించడం
#
# #### 🎩 **కన్సియర్జ్ ఏజెంట్**
# - **నైపుణ్యం**: ప్రామాణిక స్థానిక అనుభవాలు మరియు నాణ్యత అంచనా
# - **వ్యక్తిత్వం**: వివేచనాత్మకమైన, పర్యాటకేతర సూచనలపై దృష్టి
# - **బాధ్యతలు**: ట్రావెల్ సూచనలను ప్రామాణికత కోసం సమీక్షించి మెరుగుపరచడం
#
# ## 🔧 సాంకేతిక అమలు
#
# ### వర్క్‌ఫ్లో ఆర్కిటెక్చర్
# - **ఏజెంట్ నిర్వచనం**: ప్రత్యేకమైన సూచనలు మరియు వ్యక్తిత్వ కాన్ఫిగరేషన్
# - **Workflow Builder**: ఈవెంట్ హ్యాండ్లింగ్‌తో డిక్లరేటివ్ వర్క్‌ఫ్లో నిర్వచనం
# - **కమ్యూనికేషన్ ప్రోటోకాల్**: ఏజెంట్ల మధ్య నిర్మిత సందేశ మార్పిడి
# - **ఫలితాల సమీకరణ**: బహుళ ఏజెంట్ పర్స్పెక్టివ్‌ల నుండి అవుట్‌పుట్‌లను కలపడం
#
# ### ఈవెంట్-డ్రివెన్ సమన్వయం
# - **WorkflowEvent**: ఏజెంట్ యాక్టివేషన్ మరియు హ్యాండాఫ్‌ల కోసం ట్రిగ్గర్ పాయింట్లు
# - **OutputEvent**: ఏజెంట్ల మధ్య నిర్మిత డేటా మార్పిడి
# - **Quality Gates**: వర్క్‌ఫ్లో ప్రక్రియలో ధృవీకరణ చెక్‌పాయింట్లు
# - **Feedback Loops**: ఏజెంట్ సహకారంతో పునరావృత మెరుగుదల
#
# ## ⚙️ అవసరాలు & సెటప్
#
# **అవసరమైన డిపెండెన్సీలు:**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **పర్యావరణ కాన్ఫిగరేషన్ (.env ఫైల్):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 మల్టీ-ఏజెంట్ డిజైన్ ప్యాటర్న్స్
#
# ### 1. **ప్రొడ్యూసర్-కన్స్యూమర్ ప్యాటర్న్**
# - ప్రత్యేక ఏజెంట్లు ఇతరుల సమీక్ష కోసం కంటెంట్‌ను రూపొందిస్తారు
# - స్పష్టమైన హ్యాండాఫ్ పాయింట్లు మరియు డేటా మార్పిడి ప్రోటోకాల్‌లు
# - స్వతంత్ర సమీక్ష ద్వారా నాణ్యత హామీ
# - పునరావృత మెరుగుదల మరియు మెరుగుదల చక్రాలు
#
# ### 2. **కమిటీ ప్యాటర్న్**
# - వివిధ పర్స్పెక్టివ్‌లను అందించే బహుళ ఏజెంట్లు
# - నిర్మిత చర్చ ద్వారా కన్సెన్సస్ బిల్డింగ్
# - బరువు కలిగిన అభిప్రాయాలతో ప్రజాస్వామ్య నిర్ణయాలు
# - విరుద్ధత పరిష్కారం మరియు టై-బ్రేకింగ్ మెకానిజమ్స్
#
# ### 3. **హైరార్కికల్ ప్యాటర్న్**
# - నిపుణుల ఉపాధ్యక్షులను సమన్వయం చేసే ప్రధాన ఏజెంట్లు
# - స్పష్టమైన అధికారం నిర్మాణాలు మరియు నిర్ణయ ప్రవాహం
# - సంక్లిష్టమైన నిర్ణయాల కోసం ఎస్కలేషన్ మార్గాలు
# - పనితీరు పర్యవేక్షణ మరియు నాణ్యత నియంత్రణ
#
# ### 4. **పైప్‌లైన్ ప్యాటర్న్**
# - ప్రత్యేక దశలతో క్రమబద్ధమైన ప్రాసెసింగ్
# - ప్రతి ఏజెంట్ వారి నైపుణ్య ప్రాంతంలో విలువను జోడిస్తుంది
# - సమాంతర ప్రాసెసింగ్ ద్వారా సమర్థవంతమైన అవుట్‌పుట్
# - ప్రతి దశలో లోపాల నిర్వహణ మరియు పునరుద్ధరణ
#
# ## 🚀 అధునాతన మల్టీ-ఏజెంట్ ఫీచర్లు
#
# ### వర్క్‌ఫ్లో సమన్వయం
# - **డైనమిక్ రౌటింగ్**: సందర్భ ఆధారిత ఏజెంట్ ఎంపిక మరియు రౌటింగ్
# - **పారలల్ ప్రాసెసింగ్**: సమర్థత కోసం ఏకకాల ఏజెంట్ అమలు
# - **లోపాల పునరుద్ధరణ**: ఏజెంట్ వైఫల్యాలు మరియు రీట్రైలను సున్నితంగా నిర్వహించడం
# - **పనితీరు పర్యవేక్షణ**: వర్క్‌ఫ్లో అమలు మరియు ఆప్టిమైజేషన్ ట్రాకింగ్
#
# ### ఏజెంట్ కమ్యూనికేషన్
# - **నిర్మిత సందేశాలు**: టైప్-సేఫ్ కమ్యూనికేషన్ ప్రోటోకాల్‌లు
# - **సందర్భ పరిరక్షణ**: ఏజెంట్ల మధ్య సంభాషణ చరిత్రను నిర్వహించడం
# - **మెటాడేటా పాసింగ్**: టెక్స్ట్ కంటెంట్‌కు మించి సమృద్ధమైన సమాచారం మార్పిడి
# - **ఈవెంట్ బ్రాడ్‌కాస్టింగ్**: సమన్వయం కోసం పబ్లిష్-సబ్‌స్క్రైబ్ ప్యాటర్న్స్
#
# ### నాణ్యత హామీ
# - **బహుళ-పర్స్పెక్టివ్ సమీక్ష**: ప్రత్యేక పర్స్పెక్టివ్‌లను తీసుకువచ్చే వివిధ ఏజెంట్లు
# - **పునరావృత మెరుగుదల**: సహకారంతో ప్రగతిశీల మెరుగుదల
# - **ధృవీకరణ చెక్‌పాయింట్లు**: వర్క్‌ఫ్లో అంతటా నాణ్యత గేట్లు
# - **పనితీరు మెట్రిక్స్**: సహకార ప్రభావాన్ని కొలవడం
#
# ## 📊 వినియోగాలు & అప్లికేషన్లు
#
# ### వ్యాపార ప్రక్రియ ఆటోమేషన్
# - డాక్యుమెంట్ సమీక్ష మరియు ఆమోద వర్క్‌ఫ్లోలు
# - కస్టమర్ సర్వీస్ ఎస్కలేషన్ సిస్టమ్స్
# - నాణ్యత హామీ మరియు అనుగుణత తనిఖీ
# - బహుళ దశల కంటెంట్ సృష్టి మరియు ఎడిటింగ్
#
# ### పరిశోధన & విశ్లేషణ
# - పరిశోధనా పత్రాల కోసం పియర్ రివ్యూ సిస్టమ్స్
# - బహుళ విశ్లేషకుల ఆర్థిక విశ్లేషణ
# - సహకార నివేదిక రచన మరియు వాస్తవ తనిఖీ
# - అకడమిక్ పేపర్ సమీక్ష మరియు మెరుగుదల
#
# ### సృజనాత్మక సహకారం
# - ఎడిటర్లు మరియు సమీక్షకులతో కంటెంట్ సృష్టి
# - బహుళ-పర్స్పెక్టివ్ సృజనాత్మక బ్రెయిన్‌స్టార్మింగ్
# - పునరావృత డిజైన్ మరియు ఫీడ్‌బ్యాక్ సిస్టమ్స్
# - సహకార కథన రచన మరియు ప్రపంచ నిర్మాణం
#
# అధిక పనితీరు గల బృందంలా ఏజెంట్లు కలిసి పనిచేసే సిస్టమ్స్‌ను నిర్మించడానికి సిద్ధంగా ఉన్నారా? 🌟🤖

# %%
! pip install agent-framework-core -U

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent

# %%
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings

# %%
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# Workflow output: Visit the Louvre Museum for an unparalleled art experience.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **విమర్శ**:
# ఈ పత్రాన్ని AI అనువాద సేవ [Co-op Translator](https://github.com/Azure/co-op-translator) ఉపయోగించి అనువదించారు. మేము ఖచ్చితత్వానికి ప్రయత్నిస్తున్నప్పటికీ, ఆటోమేటెడ్ అనువాదాలలో తప్పులు లేదా అసమానతలు ఉండవచ్చు. దాని స్వదేశీ భాషలోని అసలు పత్రాన్ని అధికారం కలిగిన మూలంగా పరిగణించాలి. కీలకమైన సమాచారం కోసం, ప్రొఫెషనల్ మానవ అనువాదాన్ని సిఫారసు చేస్తాము. ఈ అనువాదాన్ని ఉపయోగించడం వల్ల కలిగే ఏవైనా అపార్థాలు లేదా తప్పుదారులు కోసం మేము బాధ్యత వహించము.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
