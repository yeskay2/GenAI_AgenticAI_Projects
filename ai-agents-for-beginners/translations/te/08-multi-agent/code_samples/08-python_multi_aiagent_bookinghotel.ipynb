# %% [markdown]
# ## **నమూనాలు: హోటల్ బుకింగ్ కోసం మల్టీ-ఏఐ ఏజెంట్లు**
#
# ఈ వేగవంతమైన ప్రపంచంలో, వ్యాపార ప్రయాణాన్ని ప్లాన్ చేయడం కేవలం విమాన టికెట్ మరియు హోటల్ గది బుక్ చేయడం మాత్రమే కాదు. ఇది సమన్వయం మరియు సామర్థ్యాన్ని అవసరం చేస్తుంది, ఇది సాధించడం కొంచెం కష్టంగా ఉంటుంది. ఇక్కడ మల్టీ-ఏఐ ఏజెంట్లు రంగంలోకి వస్తాయి, మన ప్రయాణ అవసరాలను నిర్వహించే విధానాన్ని విప్లవాత్మకంగా మార్చుతాయి.
#
# మీ ప్రయాణానికి సంబంధించిన ప్రతి అంశాన్ని ఖచ్చితత్వం మరియు సౌలభ్యంతో నిర్వహించడానికి కలిసి పనిచేసే తెలివైన ఏజెంట్ల బృందం మీకు అందుబాటులో ఉందని ఊహించుకోండి. మా ఆధునిక ఏఐ టెక్నాలజీతో, బుకింగ్ సేవలు మరియు ప్రయాణ ప్రణాళిక ఏర్పాటుకు ప్రత్యేక ఏజెంట్లను రూపొందించాము, ఇది నిరంతర మరియు ఒత్తిడిలేని ప్రయాణ అనుభవాన్ని నిర్ధారిస్తుంది.
#
# ఇది ఒక ప్రాథమిక పరిస్థితి. వ్యాపార ప్రయాణాన్ని ప్లాన్ చేస్తున్నప్పుడు, విమాన టికెట్ సమాచారం, హోటల్ సమాచారం మొదలైన వాటిని పొందడానికి వ్యాపార ప్రయాణ ఏజెంట్‌తో సంప్రదించాల్సి ఉంటుంది. ఏఐ ఏజెంట్ల ద్వారా, బుకింగ్ సేవల కోసం ఏజెంట్లను మరియు ప్రయాణ ప్రణాళిక ఏర్పాటుకు ఏజెంట్లను నిర్మించి, సహకరించి, తెలివితేటల స్థాయిని మెరుగుపరచవచ్చు.

# %% [markdown]
# # Azure AI ఏజెంట్ సేవను ప్రారంభించి **.env** నుండి కాన్ఫిగరేషన్ సమాచారం పొందండి
#
# ### **.env**
#
# ఒక .env ఫైల్‌ను సృష్టించండి
#
# **.env** లో Azure AI ఏజెంట్ సేవ యొక్క కనెక్షన్ స్ట్రింగ్, AOAI ఉపయోగించే మోడల్, మరియు సంబంధిత Google API సెర్చ్ సేవ API, ENDPOINT మొదలైనవి ఉంటాయి.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "మీ Azure AI ఏజెంట్ సేవ మోడల్ డిప్లాయ్‌మెంట్ పేరు"
#
# [**NOTE**] మీకు 100,000 రేట్ లిమిట్ (నిమిషానికి టోకెన్లు) మరియు 600 రేట్ లిమిట్ (నిమిషానికి అభ్యర్థనలు) కలిగిన మోడల్ అవసరం.
#
#   మీరు Azure AI Foundry - Model and Endpoint లో మోడల్ పొందవచ్చు.
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "మీ Azure AI ఏజెంట్ సేవ ప్రాజెక్ట్ కనెక్షన్ స్ట్రింగ్"
#
#   మీరు AI Foundry Portal Screen లో మీ ప్రాజెక్ట్ ఓవర్వ్యూ లో ప్రాజెక్ట్ కనెక్షన్ స్ట్రింగ్ పొందవచ్చు.
#
# - **SERPAPI_SEARCH_API_KEY** = "మీ SERPAPI సెర్చ్ API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "మీ SERPAPI సెర్చ్ ENDPOINT"
#
# Azure AI ఏజెంట్ సేవ యొక్క మోడల్ డిప్లాయ్‌మెంట్ పేరు మరియు ప్రాజెక్ట్ కనెక్షన్ స్ట్రింగ్ పొందడానికి, మీరు Azure AI ఏజెంట్ సేవను సృష్టించాలి. [ఈ టెంప్లేట్](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) ఉపయోగించి నేరుగా సృష్టించడం సిఫార్సు చేయబడింది （***గమనిక:*** Azure AI ఏజెంట్ సేవ ప్రస్తుతం పరిమిత ప్రాంతంలో సెట్ చేయబడింది. [ఈ లింక్](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) ను చూడడం ద్వారా ప్రాంతాన్ని సెట్ చేయడం సిఫార్సు చేయబడింది)
#
# ఏజెంట్ SERPAPI ను యాక్సెస్ చేయాలి. [ఈ లింక్](https://serpapi.com/searches) ఉపయోగించి రిజిస్టర్ చేయడం సిఫార్సు చేయబడింది. రిజిస్ట్రేషన్ తర్వాత, మీరు ఒక ప్రత్యేక API KEY మరియు ENDPOINT పొందవచ్చు.

# %% [markdown]
# # Azureలో లాగిన్ చేయండి
#
# ఇప్పుడు మీరు Azureలో లాగిన్ చేయాలి. VScodeలో టెర్మినల్ ఓపెన్ చేసి `az login` కమాండ్ రన్ చేయండి.

# %% [markdown]
# # సెటప్
#
# ఈ నోట్‌బుక్‌ను నడపడానికి, మీరు క్రింది లైబ్రరీలను ఇన్‌స్టాల్ చేయాలి. అవసరమైన లైబ్రరీలు మరియు వాటికి సంబంధించిన పిప్ ఇన్‌స్టాల్ కమాండ్ల జాబితా ఇక్కడ ఉంది:
#
# azure-identity: Azure ఆథెంటికేషన్ కోసం.
# requests: HTTP రిక్వెస్ట్‌లను చేయడానికి.
# semantic-kernel: సెమాంటిక్ కర్నల్ ఫ్రేమ్‌వర్క్ కోసం (ఇది కస్టమ్ లేదా ప్రత్యేక లైబ్రరీ అని భావిస్తే, మీరు దీన్ని ప్రత్యేకమైన సోర్స్ లేదా రిపోజిటరీ నుండి ఇన్‌స్టాల్ చేయవలసి ఉంటుంది).

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # వివరణ:
# import asyncio: ఇది asyncio మాడ్యూల్‌ను ఇంపోర్ట్ చేస్తుంది, ఇది పైథాన్‌లో అసింక్రోనస్ ప్రోగ్రామింగ్‌కు మద్దతు అందిస్తుంది. ఇది async మరియు await సింటాక్స్ ఉపయోగించి సమాంతర కోడ్ రాయడానికి మీకు అనుమతిస్తుంది.
# from typing import Annotated: ఇది typing మాడ్యూల్ నుండి Annotated టైప్‌ను ఇంపోర్ట్ చేస్తుంది. Annotated టైప్ హింట్స్‌కు మెటాడేటాను జోడించడానికి ఉపయోగించబడుతుంది, ఇది ధృవీకరణ, డాక్యుమెంటేషన్ లేదా టూలింగ్ వంటి వివిధ ప్రయోజనాల కోసం ఉపయోగకరంగా ఉంటుంది.

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # వివరణ:
# dotenv నుండి load_dotenv మరియు load_dotenv() ఉపయోగించడం ద్వారా, మీరు .env ఫైల్‌లో కాన్ఫిగరేషన్ సెట్టింగ్స్ మరియు సెన్సిటివ్ సమాచారం (API కీలు మరియు డేటాబేస్ URLs వంటి) సులభంగా నిర్వహించవచ్చు, వాటిని మీ సోర్స్ కోడ్ నుండి వేరు చేసి, మీ అప్లికేషన్‌ను మరింత సురక్షితంగా మరియు సులభంగా కాన్ఫిగర్ చేయగలుగుతారు.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # వివరణ:
#
# ఇంపోర్ట్ స్టేట్‌మెంట్: from azure.identity.aio import DefaultAzureCredential: ఇది azure.identity.aio మాడ్యూల్ నుండి DefaultAzureCredential క్లాస్‌ను ఇంపోర్ట్ చేస్తుంది. మాడ్యూల్ పేరులోని aio భాగం ఇది అసింక్రోనస్ ఆపరేషన్ల కోసం రూపొందించబడిందని సూచిస్తుంది.
#
# DefaultAzureCredential యొక్క ఉద్దేశ్యం: DefaultAzureCredential క్లాస్ Azure SDK for Python లో భాగం. ఇది Azure సేవలతో ప్రామాణీకరణ చేయడానికి డిఫాల్ట్ మార్గాన్ని అందిస్తుంది. ఇది నిర్దిష్ట క్రమంలో పలు పద్ధతులను ఉపయోగించి ప్రామాణీకరణ చేయడానికి ప్రయత్నిస్తుంది, ఉదాహరణకు ఎన్విరాన్‌మెంట్ వేరియబుల్స్, మేనేజ్‌డ్ ఐడెంటిటీ, మరియు Azure CLI క్రెడెన్షియల్స్.
#
# అసింక్రోనస్ ఆపరేషన్లు: aio మాడ్యూల్ DefaultAzureCredential క్లాస్ అసింక్రోనస్ ఆపరేషన్లను మద్దతు ఇస్తుందని సూచిస్తుంది. అంటే, మీరు దీనిని asyncio తో ఉపయోగించి నాన్-బ్లాకింగ్ ప్రామాణీకరణ అభ్యర్థనలను నిర్వహించవచ్చు.

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # వివరణ:
# semantic_kernel ప్యాకేజీ నుండి వివిధ మాడ్యూల్స్ మరియు క్లాసులను ఇంపోర్ట్ చేస్తుంది. ప్రతి ఇంపోర్ట్ యొక్క వివరాలు ఇక్కడ ఉన్నాయి:
#
# semantic_kernel.agents నుండి AgentGroupChat: ఈ క్లాస్ AI ఏజెంట్ల కోసం గ్రూప్ చాట్ సంబంధిత ఫంక్షనాలిటీలను నిర్వహిస్తుంది. semantic_kernel.agents.azure_ai నుండి AzureAIAgent మరియు AzureAIAgentSettings:
#
# AzureAIAgent: ఈ క్లాస్ Azure AI సేవలను ఉపయోగించే AI ఏజెంట్లను సృష్టించడానికి మరియు నిర్వహించడానికి ఉపయోగించబడుతుంది.
#
# AzureAIAgentSettings: ఈ క్లాస్ AzureAIAgent కోసం సెట్టింగులను కాన్ఫిగర్ చేయడానికి ఉపయోగించబడుతుంది. semantic_kernel.agents.strategies.termination.termination_strategy నుండి TerminationStrategy:
#
# ఈ క్లాస్ AI ఏజెంట్లను కొన్ని పరిస్థితులలో ఎగ్జిక్యూషన్ ముగించడానికి వ్యూహాలను నిర్వచిస్తుంది. semantic_kernel.contents.chat_message_content నుండి ChatMessageContent:
#
# ఈ క్లాస్ చాట్ సందేశాల కంటెంట్‌ను నిర్వహించడానికి ఉపయోగించబడుతుంది. semantic_kernel.contents.utils.author_role నుండి AuthorRole:
#
# ఈ క్లాస్ చాట్ సందేశాల సందర్భంలో రచయితల కోసం వివిధ పాత్రలను నిర్వచిస్తుంది.
#
# semantic_kernel.functions.kernel_function_decorator నుండి kernel_function: ఈ డెకరేటర్ కర్నెల్ ఫంక్షన్లను నిర్వచించడానికి ఉపయోగించబడుతుంది, ఇవి semantic kernel ఫ్రేమ్‌వర్క్‌లో ఎగ్జిక్యూట్ చేయగల ఫంక్షన్లు.
#
# ఈ ఇంపోర్ట్‌లు AI ఏజెంట్లను సృష్టించడం మరియు నిర్వహించడం కోసం అవసరమైన భాగాలను సెట్ చేస్తాయి, ఇవి గ్రూప్ చాట్ వాతావరణంలో, హోటల్ బుకింగ్ లేదా ఇలాంటి కార్యకలాపాల కోసం పరస్పర చర్య చేయగలవు.

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # వివరణ:
# తరువాత మనం azure.ai.projects.models మాడ్యూల్ నుండి CodeInterpreterTool క్లాస్‌ను ఇంపోర్ట్ చేస్తాము.
#
# CodeInterpreterTool: ఈ క్లాస్ Azure AI SDKలో భాగంగా ఉంటుంది మరియు AI ప్రాజెక్టుల సందర్భంలో కోడ్‌ను అర్థం చేసుకోవడం మరియు అమలు చేయడానికి ఉపయోగించబడుతుంది. ఇది కోడ్ స్నిప్పెట్లు నడపడం, కోడ్‌ను విశ్లేషించడం లేదా AI వర్క్‌ఫ్లోలలో కోడ్ అమలును సమగ్రపరచడం వంటి ఫంక్షనాలిటీలను అందిస్తుంది.
# ఈ ఇంపోర్ట్ మీ ప్రాజెక్టులో CodeInterpreterToolను ఉపయోగించడానికి అవసరమైన భాగాన్ని సెట్ చేస్తుంది, ఇది డైనమిక్‌గా కోడ్‌ను అర్థం చేసుకోవడం మరియు అమలు చేయడం వంటి పనుల కోసం ఉపయోగకరంగా ఉంటుంది.

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # వివరణ:
# ApprovalTerminationStrategy క్లాస్ AI ఏజెంట్ ఆపరేషన్‌ను ముగించడానికి ప్రత్యేకమైన వ్యూహాన్ని అందిస్తుంది. ఏజెంట్ యొక్క ఇంటరాక్షన్ చరిత్రలో చివరి సందేశం "saved" అనే పదాన్ని కలిగి ఉంటే, ఏజెంట్ ఆపబడుతుంది. ఏదైనా "saved" అని నిర్ధారణ పొందిన తర్వాత ఏజెంట్ యొక్క పని పూర్తయిందని భావించే పరిస్థితుల్లో ఇది ఉపయోగకరంగా ఉంటుంది. ఇంటరాక్షన్ పద్ధతిని నిర్వచించండి. రిజర్వేషన్ ప్లాన్ సేవ్ అయిన తర్వాత, సేవ్ సిగ్నల్ అందుకున్నప్పుడు ఆపవచ్చు.

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # వివరణ:
#
# ఈ కోడ్ లైన్ create() పద్ధతిని పిలవడం ద్వారా డిఫాల్ట్ లేదా ముందుగా నిర్వచించిన సెట్టింగ్స్‌తో AzureAIAgentSettings ఆబ్జెక్ట్‌ను ప్రారంభిస్తుంది. ఈ సెట్టింగ్స్ ఆబ్జెక్ట్ (ai_agent_settings) తరువాత AzureAIAgent ఇన్‌స్టాన్స్‌ను కాన్ఫిగర్ చేయడానికి మరియు నిర్వహించడానికి ఉపయోగించవచ్చు.

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # వివరణ:
# requests లైబ్రరీని ఇంపోర్ట్ చేయడం ద్వారా, మీరు మీ Python కోడ్‌లో HTTP రిక్వెస్టులు సులభంగా చేయవచ్చు మరియు వెబ్ సర్వీసులతో ఇంటరాక్ట్ చేయవచ్చు.

# %%
import requests

# %% [markdown]
# # వివరణ:
# ఇది SERP (సెర్చ్ ఇంజిన్ రిజల్ట్స్ పేజీ) API సేవను యాక్సెస్ చేయడానికి API కీని నిల్వ చేసే వేరియబుల్. API కీ అనేది మీ ఖాతాతో సంబంధం ఉన్న అభ్యర్థనలను ధృవీకరించడానికి ఉపయోగించే ప్రత్యేక గుర్తింపు.
#
# 'GOOGLE_SEARCH_API_KEY': ఇది ఒక ప్లేస్‌హోల్డర్ స్ట్రింగ్. మీరు ''GOOGLE_SEARCH_API_KEY' ను మీ అసలు SERP API కీతో మార్చాలి.
#
# ఉద్దేశ్యం: ఈ లైన్ యొక్క ఉద్దేశ్యం API కీని ఒక వేరియబుల్‌లో నిల్వ చేయడం, తద్వారా SERP API సేవకు అభ్యర్థనలను ధృవీకరించడానికి ఉపయోగించవచ్చు. సేవను యాక్సెస్ చేయడానికి మరియు సెర్చ్‌లు నిర్వహించడానికి API కీ అవసరం.
#
# SERP API కీని ఎలా పొందాలి: SERP API కీని పొందడానికి, https://serpapi.com వద్ద ఈ సాధారణ దశలను అనుసరించండి (మీరు ఉపయోగిస్తున్న ప్రత్యేక SERP API సేవపై ఆధారపడి ఖచ్చితమైన దశలు మారవచ్చు):
#
# SERP API సేవను ఎంచుకోండి: SerpAPI, Google Custom Search JSON API మరియు ఇతరులు వంటి అనేక SERP API సేవలు అందుబాటులో ఉన్నాయి. మీ అవసరాలకు సరిపోయే సేవను ఎంచుకోండి.
#
# ఖాతాకు సైన్ అప్ చేయండి:
#
# ఎంచుకున్న SERP API సేవ వెబ్‌సైట్ https://www.serpapi.com కు వెళ్లి ఖాతాకు సైన్ అప్ చేయండి. మీరు కొన్ని ప్రాథమిక సమాచారం అందించవలసి ఉండవచ్చు మరియు మీ ఇమెయిల్ చిరునామాను ధృవీకరించవలసి ఉండవచ్చు.
#
# API కీని సృష్టించండి:
#
# సైన్ అప్ చేసిన తర్వాత, మీ ఖాతాలో లాగిన్ అవ్వండి మరియు API విభాగం లేదా డాష్‌బోర్డ్‌కు వెళ్లండి. కొత్త API కీని సృష్టించడానికి లేదా జనరేట్ చేయడానికి ఆప్షన్ కోసం చూడండి.
# API కీని కాపీ చేయండి:
#
# API కీ జనరేట్ అయిన తర్వాత, దానిని కాపీ చేయండి. ఈ కీ SERP API సేవకు మీ అభ్యర్థనలను ధృవీకరించడానికి ఉపయోగించబడుతుంది.
# ప్లేస్‌హోల్డర్‌ను మార్చండి:
#
# మీ .env ఫైల్‌లో ప్లేస్‌హోల్డర్‌ను మార్చండి

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # వివరణ:
# BookingPlugin క్లాస్ Serpapi.com Google Search API ఉపయోగించి హోటల్స్ మరియు ఫ్లైట్స్ బుకింగ్ కోసం పద్ధతులను అందిస్తుంది. ఇది అవసరమైన పారామీటర్లను నిర్మిస్తుంది, API అభ్యర్థనలను పంపుతుంది, మరియు సంబంధిత బుకింగ్ సమాచారం అందించడానికి ప్రతిస్పందనలను ప్రాసెస్ చేస్తుంది. API కీ (SERPAPI_SEARCH_API_KEY) మరియు ఎండ్‌పాయింట్ (SERPAPI_SEARCH_ENDPOINT) Google Search APIకి ప్రామాణీకరణ మరియు అభ్యర్థనలు పంపడానికి ఉపయోగించబడతాయి.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # వివరణ:
# SavePlugin క్లాస్ ఒక పద్ధతి saving_plan ను అందిస్తుంది, ఇది Azure AI సేవలను ఉపయోగించి ప్రయాణ ప్రణాళికలను సేవ్ చేయడానికి ఉపయోగపడుతుంది. ఇది Azure ప్రమాణాలను సెట్ చేస్తుంది, AI ఏజెంట్‌ను సృష్టిస్తుంది, వినియోగదారుల ఇన్‌పుట్‌లను ప్రాసెస్ చేసి ప్రయాణ ప్రణాళిక కంటెంట్‌ను రూపొందించి సేవ్ చేస్తుంది, మరియు ఫైల్ సేవ్ చేయడం మరియు క్లీనప్ ఆపరేషన్లను నిర్వహిస్తుంది. ఈ పద్ధతి విజయవంతంగా పూర్తయిన తర్వాత "Saved" ను తిరిగి ఇస్తుంది.

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # వివరణ:
# ఈ కోడ్ Azure AI ఏజెంట్లను సెట్ చేసి, విమానాలు మరియు హోటళ్ల బుకింగ్ చేయడం, అలాగే యూజర్ ఇన్‌పుట్‌ల ఆధారంగా ట్రిప్ ప్లాన్‌లను సేవ్ చేయడం వంటి పనులను నిర్వహిస్తుంది. ఇది Azure క్రెడెన్షియల్స్‌ను ఉపయోగించి ఏజెంట్లను సృష్టించి, కాన్ఫిగర్ చేస్తుంది, యూజర్ ఇన్‌పుట్‌లను గ్రూప్ చాట్ ద్వారా ప్రాసెస్ చేస్తుంది, మరియు పనులు పూర్తయ్యిన తర్వాత సరైన క్లీనప్‌ను నిర్ధారిస్తుంది. ఈ ఏజెంట్లు తమ తమ పనులను నిర్వహించడానికి ప్రత్యేకమైన ప్లగిన్లను (BookingPlugin మరియు SavePlugin) ఉపయోగిస్తాయి.

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **విమర్శ**:
# ఈ పత్రాన్ని AI అనువాద సేవ [Co-op Translator](https://github.com/Azure/co-op-translator) ఉపయోగించి అనువదించారు. మేము ఖచ్చితత్వానికి ప్రయత్నిస్తున్నప్పటికీ, ఆటోమేటెడ్ అనువాదాలలో తప్పులు లేదా అసమానతలు ఉండవచ్చు. దాని స్వదేశీ భాషలోని అసలు పత్రాన్ని అధికారం కలిగిన మూలంగా పరిగణించాలి. కీలకమైన సమాచారం కోసం, ప్రొఫెషనల్ మానవ అనువాదాన్ని సిఫారసు చేస్తాము. ఈ అనువాదాన్ని ఉపయోగించడం వల్ల కలిగే ఏవైనా అపార్థాలు లేదా తప్పుదారులు కోసం మేము బాధ్యత వహించము.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
