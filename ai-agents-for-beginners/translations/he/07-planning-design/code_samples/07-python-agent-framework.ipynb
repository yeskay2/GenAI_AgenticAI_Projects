# %% [markdown]
# # 🎯 תכנון ותבניות עיצוב עם מודלים של GitHub (Python)
#
# ## 📋 מטרות למידה
#
# מחברת זו מציגה תכנון מתקדם ותבניות עיצוב לבניית סוכנים חכמים באמצעות Microsoft Agent Framework עם מודלים של GitHub. תלמדו כיצד ליצור סוכנים שיכולים לפרק בעיות מורכבות, לתכנן פתרונות רב-שלביים ולתאם תהליכי עבודה מתוחכמים.
#
# **יכולות מתקדמות שתשלוט בהן:**
# - 🧠 **תכנון אסטרטגי**: פירוק משימות מורכבות למשימות משנה ניתנות לניהול
# - 🗺️ **הסקה רב-שלבית**: תבניות ביצוע רציפות ומקבילות של משימות
# - 🎯 **עיצוב מוכוון מטרה**: סוכנים שפועלים להשגת יעדים ספציפיים
# - 🔄 **תכנון אדפטיבי**: התאמת אסטרטגיה דינמית בהתאם להקשר
#
# ## 🎯 מושגי ארכיטקטורת תכנון
#
# ### רכיבי תכנון מרכזיים
# - **פירוק משימות**: פירוק בעיות מורכבות לחלקים קטנים וניתנים לניהול
# - **תכנון ביצוע**: קביעת סדר אופטימלי ותלות בין משימות משנה
# - **ניהול משאבים**: הקצאה יעילה של כלים ויכולות
# - **מעקב התקדמות**: מעקב אחר השלמה והתאמה לשינויים
#
# ### תבניות עיצוב לתכנון
# - **תבנית אסטרטגיה**: גישות תכנון שונות למצבים שונים
# - **שרשרת אחריות**: עיבוד רציף עם אפשרויות גיבוי
# - **תבנית פקודה**: ביצוע משימות עם יכולות ביטול/חזרה
# - **תבנית משקיף**: מעקב התקדמות ועדכונים מונעי אירועים
#
# ## 🏗️ ארכיטקטורה טכנית
#
# ### רכיבי מערכת תכנון
# - **Microsoft Agent Framework**: יישום Python עם תמיכה בתכנון מתקדם
# - **אינטגרציה עם מודלים של GitHub**: הסקה וקבלת החלטות ברמה גבוהה
# - **תזמור משימות**: ביצוע מתואם של תהליכי עבודה מורכבים
# - **ניהול מצב**: מעקב מתמשך אחר התקדמות תכנון ותוצאות
#
# ### תהליך זרימת תכנון
# ```python
# Complex Goal → Task Analysis → Subtask Decomposition → Execution Planning
#                 ↓                    ↓                    ↓
#          Priority Assessment → Resource Allocation → Sequential Execution
#                 ↓                    ↓                    ↓
#          Progress Monitoring → Adaptive Replanning → Goal Achievement
# ```
#
# ## 🧠 מתודולוגיות תכנון
#
# ### 1. **תכנון משימות היררכי**
# - פירוק מלמעלה למטה של מטרות מורכבות
# - מבני מטרות מקוננים עם תלות
# - תכנון רקורסיבי למטרות משנה
# - הקצאת משאבים יעילה בין רמות
#
# ### 2. **תכנון רציף**
# - ביצוע משימות שלב אחר שלב עם תלות ברורה
# - טיפול בשגיאות והתאוששות בכל שלב
# - נקודות בדיקה ואימות התקדמות
# - יכולות חזרה במקרה של שלבים שנכשלו
#
# ### 3. **תכנון מקבילי**
# - ביצוע מקביל של משימות עצמאיות
# - סנכרון משאבים ופתרון קונפליקטים
# - אופטימיזציה ביצועית באמצעות מקביליות
# - השלמה מתואמת ואיגום תוצאות
#
# ## ⚙️ דרישות מוקדמות והגדרות
#
# **תלויות נדרשות:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **הגדרת סביבה (קובץ .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 תבניות עיצוב לתכנון
#
# ### תכנון מוכוון מטרה
# - **מטרות SMART**: מטרות ספציפיות, מדידות, ברות השגה, רלוונטיות ומוגדרות בזמן
# - **מעקב אבני דרך**: מדידת התקדמות ונקודות בדיקה לאימות
# - **קריטריוני הצלחה**: הגדרות ברורות להשלמת משימות
# - **אסטרטגיות אדפטיביות**: התאמת תכנון דינמית על בסיס משוב
#
# ### תכנון מודע למשאבים
# - **הערכת יכולות**: הבנת הכלים הזמינים והמגבלות שלהם
# - **איזון עומסים**: חלוקה אופטימלית של משימות בין משאבים זמינים
# - **ניהול מגבלות**: עבודה במסגרת מגבלות מערכת ו-API
# - **אופטימיזציה ביצועית**: מקסום יעילות ומזעור זמן תגובה
#
# ### תכנון עמיד בפני שגיאות
# - **זיהוי כשלונות**: זיהוי מוקדם של בעיות בתכנון או בביצוע
# - **אסטרטגיות התאוששות**: גיבוי אוטומטי וגישות חלופיות
# - **שימור מצב**: שמירה על התקדמות במהלך התאוששות משגיאות
# - **התדרדרות הדרגתית**: הצלחה חלקית כאשר השלמה מלאה אינה אפשרית
#
# ## 🚀 תכונות תכנון מתקדמות
#
# - **מטא-תכנון**: סוכנים שמתכננים כיצד לתכנן
# - **תכנון שיתופי**: תיאום רב-סוכנים לפרויקטים מורכבים
# - **למידה מניסיון**: שיפור אסטרטגיות תכנון לאורך זמן
# - **התאמה בזמן אמת**: תכנון מחדש דינמי בהתבסס על תנאים משתנים
#
# ## 📊 מקרי שימוש ויישומים
#
# ### אוטומציה של תהליכים עסקיים
# - ניהול פרויקטים ותזמון משימות
# - אופטימיזציה של תהליכי עבודה והקצאת משאבים
# - תכנון אסטרטגי ותמיכה בקבלת החלטות
# - שיפור תהליכים ואוטומציה
#
# ### מחקר וניתוח
# - סקירת ספרות וסינתזה
# - תכנון צינור ניתוח נתונים
# - עיצוב וביצוע ניסויים
# - יצירת דוחות ועיצובם
#
# ### פרויקטים יצירתיים
# - תהליכי יצירת תוכן
# - תיאום פרויקטים מולטימדיה
# - תכנון וביצוע קמפיינים
# - ארגון וניהול אירועים
#
# מוכנים לבנות סוכני תכנון חכמים שיכולים להתמודד עם אתגרים מורכבים ורב-שלביים? בואו נבנה יכולות פתרון בעיות מתוחכמות! 🧠✨

# %%
! pip install agent-framework-core -U

# %%
# 📦 Import Standard Libraries
# os: For environment variable access
# dotenv: For loading environment variables from .env file
import os

from dotenv import load_dotenv

# %%
# 📝 Import Data Modeling Libraries
# Pydantic: For data validation and structured outputs
# BaseModel: Base class for creating data models
# Field: For adding metadata and validation to model fields
# List: Type hint for list collections
from pydantic import BaseModel, Field
from typing import List

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatMessage: For creating structured chat messages
# Role: Enum for message roles (user, assistant, system)
# ChatOptions: Configuration options for chat interactions
# OpenAIChatClient: Client for OpenAI-compatible APIs (GitHub Models)
from agent_framework import ChatMessage, Role, ChatOptions
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# Load configuration from .env file
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎯 Agent Configuration
# Define the agent's name and role

AGENT_NAME = "TravelAgent"

# 📋 System Instructions for Planning Agent
# This agent acts as a coordinator that decides which specialized agents to use
AGENT_INSTRUCTIONS = """You are a planner agent.
    Your job is to decide which agents to run based on the user's request.
    Below are the available agents specialized in different tasks:
    - FlightBooking: For booking flights and providing flight information
    - HotelBooking: For booking hotels and providing hotel information
    - CarRental: For booking cars and providing car rental information
    - ActivitiesBooking: For booking activities and providing activity information
"""

# %%
class SubTask(BaseModel):
    assigned_agent: str = Field(
        description="The specific agent assigned to handle this subtask")
    task_details: str = Field(
        description="Detailed description of what needs to be done for this subtask")


class TravelPlan(BaseModel):
    main_task: str = Field(
        description="The overall travel request from the user")
    subtasks: List[SubTask] = Field(
        description="List of subtasks broken down from the main task, each assigned to a specialized agent")

# %%
options = ChatOptions(response_format=TravelPlan)

# %%
client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
agent =  client.create_agent(name= AGENT_NAME , instructions=AGENT_INSTRUCTIONS)

# %%
messages = [
        ChatMessage(role=Role.USER, text="Create a travel plan for a family of 4, with 2 kids, from Singapore to Melbourne")
    ]

# %%
response = await agent.run(messages,response_format=TravelPlan)

# %%
response.messages[0].text
# Out:
# '{"main_task":"Plan a family trip from Singapore to Melbourne for 4 people, including 2 kids.","subtasks":[{"assigned_agent":"FlightBooking","task_details":"Book one round-trip flight from Singapore to Melbourne for a family of 4, considering family-friendly options."},{"assigned_agent":"HotelBooking","task_details":"Find and book a family-friendly hotel in Melbourne that can accommodate 4 people, including 2 kids."},{"assigned_agent":"CarRental","task_details":"Arrange a car rental in Melbourne for the family to facilitate travel around the city."},{"assigned_agent":"ActivitiesBooking","task_details":"Provide a list of kid-friendly activities and attractions in Melbourne for the family to enjoy."}]}'

# %% [markdown]
# ---
#
# **כתב ויתור**:
# מסמך זה תורגם באמצעות שירות תרגום מבוסס בינה מלאכותית [Co-op Translator](https://github.com/Azure/co-op-translator). למרות שאנו שואפים לדיוק, יש לקחת בחשבון שתרגומים אוטומטיים עשויים להכיל שגיאות או אי דיוקים. המסמך המקורי בשפתו המקורית צריך להיחשב כמקור סמכותי. עבור מידע קריטי, מומלץ להשתמש בתרגום מקצועי על ידי אדם. איננו נושאים באחריות לאי הבנות או לפרשנויות שגויות הנובעות משימוש בתרגום זה.
