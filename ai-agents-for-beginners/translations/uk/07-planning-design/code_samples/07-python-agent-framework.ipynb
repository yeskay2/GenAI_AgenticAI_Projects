# %% [markdown]
# # 🎯 Планування та шаблони дизайну з моделями GitHub (Python)
#
# ## 📋 Навчальні цілі
#
# Цей блокнот демонструє передові методи планування та шаблони дизайну для створення інтелектуальних агентів за допомогою Microsoft Agent Framework з моделями GitHub. Ви навчитеся створювати агентів, які можуть розбивати складні проблеми, планувати багатокрокові рішення та координувати складні робочі процеси.
#
# **Передові можливості, які ви освоїте:**
# - 🧠 **Стратегічне планування**: Розбиття складних завдань на керовані підзадачі
# - 🗺️ **Багатокрокове мислення**: Шаблони послідовного та паралельного виконання завдань
# - 🎯 **Цілеспрямований дизайн**: Агенти, які працюють для досягнення конкретних цілей
# - 🔄 **Адаптивне планування**: Динамічне коригування стратегії залежно від контексту
#
# ## 🎯 Концепції архітектури планування
#
# ### Основні компоненти планування
# - **Декомпозиція завдань**: Розбиття складних проблем на менші, керовані частини
# - **Планування виконання**: Визначення оптимального порядку та залежностей для підзадач
# - **Управління ресурсами**: Ефективний розподіл інструментів і можливостей
# - **Моніторинг прогресу**: Відстеження виконання та адаптація до змін
#
# ### Шаблони дизайну для планування
# - **Шаблон стратегії**: Різні підходи до планування для різних сценаріїв
# - **Ланцюг відповідальності**: Послідовна обробка із запасними варіантами
# - **Шаблон команди**: Інкапсульоване виконання завдань із можливістю скасування/повтору
# - **Шаблон спостерігача**: Відстеження прогресу та оновлення на основі подій
#
# ## 🏗️ Технічна архітектура
#
# ### Компоненти системи планування
# - **Microsoft Agent Framework**: Реалізація на Python із підтримкою передового планування
# - **Інтеграція моделей GitHub**: Високопродуктивне мислення та прийняття рішень
# - **Оркестрація завдань**: Координоване виконання складних робочих процесів
# - **Управління станом**: Постійне відстеження прогресу планування та результатів
#
# ### Потік процесу планування
# ```python
# Complex Goal → Task Analysis → Subtask Decomposition → Execution Planning
#                 ↓                    ↓                    ↓
#          Priority Assessment → Resource Allocation → Sequential Execution
#                 ↓                    ↓                    ↓
#          Progress Monitoring → Adaptive Replanning → Goal Achievement
# ```
#
# ## 🧠 Методології планування
#
# ### 1. **Ієрархічне планування завдань**
# - Декомпозиція складних цілей зверху вниз
# - Вкладені структури цілей із залежностями
# - Рекурсивне планування для підцілей
# - Ефективний розподіл ресурсів на різних рівнях
#
# ### 2. **Послідовне планування**
# - Виконання завдань крок за кроком із чіткими залежностями
# - Обробка помилок і відновлення на кожному етапі
# - Контрольні точки прогресу та перевірка
# - Можливість скасування для невдалих кроків
#
# ### 3. **Паралельне планування**
# - Одночасне виконання незалежних завдань
# - Синхронізація ресурсів і вирішення конфліктів
# - Оптимізація продуктивності через паралелізацію
# - Координоване завершення та агрегування результатів
#
# ## ⚙️ Попередні вимоги та налаштування
#
# **Необхідні залежності:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Конфігурація середовища (.env файл):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Шаблони дизайну планування
#
# ### Цілеспрямоване планування
# - **SMART-цілі**: Конкретні, вимірювані, досяжні, релевантні, обмежені в часі цілі
# - **Відстеження етапів**: Вимірювання прогресу та контрольні точки перевірки
# - **Критерії успіху**: Чітке визначення завершення завдань
# - **Адаптивні стратегії**: Динамічне коригування планування на основі зворотного зв’язку
#
# ### Планування з урахуванням ресурсів
# - **Оцінка можливостей**: Розуміння доступних інструментів і їхніх обмежень
# - **Балансування навантаження**: Оптимальний розподіл завдань між доступними ресурсами
# - **Управління обмеженнями**: Робота в межах системних і API-обмежень
# - **Оптимізація продуктивності**: Максимізація ефективності та мінімізація затримок
#
# ### Планування, стійке до помилок
# - **Виявлення збоїв**: Раннє визначення проблем у плануванні або виконанні
# - **Стратегії відновлення**: Автоматичні запасні варіанти та альтернативні підходи
# - **Збереження стану**: Підтримка прогресу під час відновлення після помилок
# - **Плавна деградація**: Частковий успіх, коли повне завершення неможливе
#
# ## 🚀 Передові функції планування
#
# - **Мета-планування**: Агенти, які планують, як планувати
# - **Спільне планування**: Координація кількох агентів для складних проєктів
# - **Навчання на досвіді**: Покращення стратегій планування з часом
# - **Адаптація в реальному часі**: Динамічне перепланування залежно від змінних умов
#
# ## 📊 Сфери застосування та приклади
#
# ### Автоматизація бізнес-процесів
# - Управління проєктами та розклад завдань
# - Оптимізація робочих процесів і розподіл ресурсів
# - Стратегічне планування та підтримка прийняття рішень
# - Покращення процесів і автоматизація
#
# ### Дослідження та аналіз
# - Огляд літератури та синтез
# - Планування аналізу даних
# - Дизайн експериментів і виконання
# - Генерація звітів і форматування
#
# ### Творчі проєкти
# - Робочі процеси створення контенту
# - Координація мультимедійних проєктів
# - Планування та виконання кампаній
# - Організація та управління заходами
#
# Готові створювати інтелектуальних агентів планування, які можуть вирішувати складні багатокрокові завдання? Давайте спроєктуємо потужні можливості для вирішення проблем! 🧠✨

# %%
! pip install agent-framework-core -U

# %%
# 📦 Import Standard Libraries
# os: For environment variable access
# dotenv: For loading environment variables from .env file
import os

from dotenv import load_dotenv

# %%
# 📝 Import Data Modeling Libraries
# Pydantic: For data validation and structured outputs
# BaseModel: Base class for creating data models
# Field: For adding metadata and validation to model fields
# List: Type hint for list collections
from pydantic import BaseModel, Field
from typing import List

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatMessage: For creating structured chat messages
# Role: Enum for message roles (user, assistant, system)
# ChatOptions: Configuration options for chat interactions
# OpenAIChatClient: Client for OpenAI-compatible APIs (GitHub Models)
from agent_framework import ChatMessage, Role, ChatOptions
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# Load configuration from .env file
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎯 Agent Configuration
# Define the agent's name and role

AGENT_NAME = "TravelAgent"

# 📋 System Instructions for Planning Agent
# This agent acts as a coordinator that decides which specialized agents to use
AGENT_INSTRUCTIONS = """You are a planner agent.
    Your job is to decide which agents to run based on the user's request.
    Below are the available agents specialized in different tasks:
    - FlightBooking: For booking flights and providing flight information
    - HotelBooking: For booking hotels and providing hotel information
    - CarRental: For booking cars and providing car rental information
    - ActivitiesBooking: For booking activities and providing activity information
"""

# %%
class SubTask(BaseModel):
    assigned_agent: str = Field(
        description="The specific agent assigned to handle this subtask")
    task_details: str = Field(
        description="Detailed description of what needs to be done for this subtask")


class TravelPlan(BaseModel):
    main_task: str = Field(
        description="The overall travel request from the user")
    subtasks: List[SubTask] = Field(
        description="List of subtasks broken down from the main task, each assigned to a specialized agent")

# %%
options = ChatOptions(response_format=TravelPlan)

# %%
client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
agent =  client.create_agent(name= AGENT_NAME , instructions=AGENT_INSTRUCTIONS)

# %%
messages = [
        ChatMessage(role=Role.USER, text="Create a travel plan for a family of 4, with 2 kids, from Singapore to Melbourne")
    ]

# %%
response = await agent.run(messages,response_format=TravelPlan)

# %%
response.messages[0].text
# Out:
# '{"main_task":"Plan a family trip from Singapore to Melbourne for 4 people, including 2 kids.","subtasks":[{"assigned_agent":"FlightBooking","task_details":"Book one round-trip flight from Singapore to Melbourne for a family of 4, considering family-friendly options."},{"assigned_agent":"HotelBooking","task_details":"Find and book a family-friendly hotel in Melbourne that can accommodate 4 people, including 2 kids."},{"assigned_agent":"CarRental","task_details":"Arrange a car rental in Melbourne for the family to facilitate travel around the city."},{"assigned_agent":"ActivitiesBooking","task_details":"Provide a list of kid-friendly activities and attractions in Melbourne for the family to enjoy."}]}'

# %% [markdown]
# ---
#
# **Відмова від відповідальності**:
# Цей документ був перекладений за допомогою сервісу автоматичного перекладу [Co-op Translator](https://github.com/Azure/co-op-translator). Хоча ми прагнемо до точності, будь ласка, майте на увазі, що автоматичні переклади можуть містити помилки або неточності. Оригінальний документ на його рідній мові слід вважати авторитетним джерелом. Для критичної інформації рекомендується професійний людський переклад. Ми не несемо відповідальності за будь-які непорозуміння або неправильні тлумачення, що виникають внаслідок використання цього перекладу.
