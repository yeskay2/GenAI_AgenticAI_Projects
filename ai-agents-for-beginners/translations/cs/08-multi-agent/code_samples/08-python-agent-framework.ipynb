# %% [markdown]
# # 🤝 Systémy pracovních postupů s více agenty a modely GitHub (Python)
#
# ## 📋 Cíle učení
#
# Tento notebook ukazuje, jak vytvořit sofistikované systémy s více agenty pomocí Microsoft Agent Framework a modelů GitHub. Naučíte se koordinovat práci několika specializovaných agentů, kteří společně řeší složité problémy prostřednictvím strukturovaných pracovních postupů.
#
# **Schopnosti více agentů, které vytvoříte:**
# - 👥 **Spolupráce agentů**: Více agentů pracujících společně na dosažení společných cílů
# - 🔄 **Orchestrace pracovních postupů**: Strukturovaná koordinace interakcí agentů
# - 🎭 **Specializace rolí**: Agenti s odlišnými osobnostmi a oblastmi odbornosti
# - 📋 **Zajištění kvality**: Kontrola a zdokonalování prostřednictvím spolupráce agentů
#
# ## 🎯 Koncepty architektury více agentů
#
# ### Základní principy více agentů
# - **Rozdělení práce**: Každý agent se specializuje na konkrétní oblast odbornosti
# - **Společné rozhodování**: Agenti kontrolují a zdokonalují práci ostatních
# - **Koordinace pracovních postupů**: Strukturované předávání úkolů a komunikační vzorce
# - **Zlepšení kvality**: Iterativní zdokonalování prostřednictvím analýzy z různých perspektiv
#
# ### Vzorce interakce agentů
# - **Sekvenční zpracování**: Lineární pracovní postup s postupnou účastí agentů
# - **Recenze kolegů**: Agenti ověřují a zlepšují výstupy ostatních
# - **Hierarchická struktura**: Vedoucí agenti koordinující podřízené specialisty
# - **Budování konsensu**: Více agentů přispívajících k finálním rozhodnutím
#
# ## 🏗️ Technická architektura
#
# ### Komponenty systému pracovních postupů
# - **Microsoft Agent Framework**: Implementace v Pythonu s pokročilou podporou pracovních postupů
# - **WorkflowBuilder**: Deklarativní definice pracovních postupů a jejich provádění
# - **Koordinace agentů**: Strukturovaná komunikace a mechanismy předávání úkolů
# - **Zpracování událostí**: Reaktivní provádění pracovních postupů na základě výstupů agentů
#
# ### Procesní tok více agentů
# ```python
# User Request → Agent 1 (Specialist) → Agent 2 (Reviewer) → Quality Check
#                 ↓                      ↓                    ↓
#          Initial Solution → Review & Feedback → Refined Output → Final Result
# ```
#
# ## 🎭 Příklady rolí agentů
#
# ### Systém hotelového concierge
# Tento notebook ukazuje systém doporučení pro cestování se specializovanými rolemi:
#
# #### 🏨 **Agent recepce**
# - **Odbornost**: Doporučení pro cestování a místní znalosti
# - **Osobnost**: Efektivní, zkušený, stručný styl komunikace
# - **Odpovědnosti**: Generování počátečních návrhů na cestování a aktivity
#
# #### 🎩 **Agent concierge**
# - **Odbornost**: Autentické místní zážitky a hodnocení kvality
# - **Osobnost**: Náročný, zaměřený na neturistické doporučení
# - **Odpovědnosti**: Kontrola a zdokonalování návrhů na cestování pro autenticitu
#
# ## 🔧 Technická implementace
#
# ### Architektura pracovních postupů
# - **Definice agentů**: Specializované instrukce a konfigurace osobnosti
# - **Workflow Builder**: Deklarativní definice pracovních postupů s obsluhou událostí
# - **Komunikační protokol**: Strukturované předávání zpráv mezi agenty
# - **Agregace výsledků**: Kombinování výstupů z různých perspektiv agentů
#
# ### Koordinace založená na událostech
# - **WorkflowEvent**: Spouštěcí body pro aktivaci agentů a předávání úkolů
# - **OutputEvent**: Strukturovaná výměna dat mezi agenty
# - **Kontrolní body kvality**: Ověřovací body v procesu pracovního postupu
# - **Smyčky zpětné vazby**: Iterativní zdokonalování prostřednictvím spolupráce agentů
#
# ## ⚙️ Předpoklady a nastavení
#
# **Požadované závislosti:**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **Konfigurace prostředí (.env soubor):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Návrhové vzory více agentů
#
# ### 1. **Vzorec producent-spotřebitel**
# - Specializovaní agenti generují obsah pro kontrolu ostatními
# - Jasné body předávání úkolů a protokoly výměny dat
# - Zajištění kvality prostřednictvím nezávislé kontroly
# - Iterativní cykly zdokonalování a zlepšování
#
# ### 2. **Vzorec komise**
# - Více agentů přispívajících různými perspektivami
# - Budování konsensu prostřednictvím strukturované diskuse
# - Demokratické rozhodování s váženými názory
# - Řešení konfliktů a mechanismy pro rozhodování při rovnosti hlasů
#
# ### 3. **Hierarchický vzorec**
# - Vedoucí agenti koordinující specialisty
# - Jasné struktury autority a tok rozhodování
# - Cesty eskalace pro složitá rozhodnutí
# - Monitorování výkonu a kontrola kvality
#
# ### 4. **Vzorec pipeline**
# - Sekvenční zpracování se specializovanými fázemi
# - Každý agent přidává hodnotu ve své oblasti odbornosti
# - Efektivní průchod díky paralelnímu zpracování
# - Řešení chyb a obnova v každé fázi
#
# ## 🚀 Pokročilé funkce více agentů
#
# ### Orchestrace pracovních postupů
# - **Dynamické směrování**: Výběr a směrování agentů na základě kontextu
# - **Paralelní zpracování**: Současné provádění agentů pro efektivitu
# - **Obnova chyb**: Elegantní řešení selhání agentů a opakování úkolů
# - **Monitorování výkonu**: Sledování provádění pracovních postupů a optimalizace
#
# ### Komunikace agentů
# - **Strukturované zprávy**: Typově bezpečné komunikační protokoly
# - **Zachování kontextu**: Udržování historie konverzace mezi agenty
# - **Předávání metadat**: Bohatá výměna informací nad rámec textového obsahu
# - **Vysílání událostí**: Vzory publikování a odběru pro koordinaci
#
# ### Zajištění kvality
# - **Recenze z více perspektiv**: Různí agenti přinášející jedinečné pohledy
# - **Iterativní zdokonalování**: Postupné zlepšování prostřednictvím spolupráce
# - **Ověřovací body**: Kontrolní body kvality v celém pracovním postupu
# - **Výkonnostní metriky**: Měření efektivity spolupráce
#
# ## 📊 Případy použití a aplikace
#
# ### Automatizace obchodních procesů
# - Pracovní postupy pro kontrolu a schvalování dokumentů
# - Systémy eskalace zákaznických služeb
# - Zajištění kvality a kontrola shody
# - Vícefázová tvorba obsahu a jeho úpravy
#
# ### Výzkum a analýza
# - Systémy recenzí kolegů pro vědecké práce
# - Finanční analýza více analytiky
# - Spolupráce na psaní zpráv a ověřování faktů
# - Recenze a zdokonalování akademických prací
#
# ### Kreativní spolupráce
# - Tvorba obsahu s editory a recenzenty
# - Kreativní brainstorming z různých perspektiv
# - Iterativní návrh a systémy zpětné vazby
# - Spolupráce na vyprávění příběhů a budování světa
#
# Připraveni orchestrálně řídit inteligentní spolupráci více agentů? Pojďme budovat systémy, kde agenti pracují společně jako vysoce výkonný tým! 🌟🤖

# %%
! pip install agent-framework-core -U

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent

# %%
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings

# %%
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# Workflow output: Visit the Louvre Museum for an unparalleled art experience.

# %% [markdown]
# ---
#
# **Upozornění**:
# Tento dokument byl přeložen pomocí služby pro automatický překlad [Co-op Translator](https://github.com/Azure/co-op-translator). I když se snažíme o co největší přesnost, mějte prosím na paměti, že automatické překlady mohou obsahovat chyby nebo nepřesnosti. Za autoritativní zdroj by měl být považován původní dokument v jeho původním jazyce. Pro důležité informace doporučujeme profesionální lidský překlad. Neodpovídáme za žádná nedorozumění nebo nesprávné výklady vyplývající z použití tohoto překladu.
