# %% [markdown]
# # 🎯 Plánování a návrhové vzory s modely GitHub (Python)
#
# ## 📋 Cíle učení
#
# Tento notebook ukazuje pokročilé plánování a návrhové vzory pro vytváření inteligentních agentů pomocí Microsoft Agent Framework s modely GitHub. Naučíte se, jak vytvářet agenty, kteří dokážou rozkládat složité problémy, plánovat vícekroková řešení a koordinovat sofistikované pracovní postupy.
#
# **Pokročilé schopnosti, které si osvojíte:**
# - 🧠 **Strategické plánování**: Rozdělení složitých úkolů na zvládnutelné podúkoly
# - 🗺️ **Vícekrokové uvažování**: Vzory sekvenčního a paralelního provádění úkolů
# - 🎯 **Cílený návrh**: Agenti pracující na dosažení konkrétních cílů
# - 🔄 **Adaptivní plánování**: Dynamické přizpůsobení strategie na základě kontextu
#
# ## 🎯 Koncepty plánovací architektury
#
# ### Základní komponenty plánování
# - **Rozklad úkolů**: Rozdělení složitých problémů na menší, zvládnutelné části
# - **Plánování provádění**: Určení optimálního pořadí a závislostí podúkolů
# - **Správa zdrojů**: Efektivní přidělování nástrojů a schopností
# - **Sledování pokroku**: Monitorování dokončení a přizpůsobení změnám
#
# ### Návrhové vzory pro plánování
# - **Strategický vzor**: Různé přístupy k plánování pro různé scénáře
# - **Řetězec odpovědnosti**: Sekvenční zpracování s možností záložních řešení
# - **Příkazový vzor**: Zapouzdřené provádění úkolů s možností vrácení/obnovení
# - **Pozorovatelský vzor**: Sledování pokroku a aktualizace na základě událostí
#
# ## 🏗️ Technická architektura
#
# ### Komponenty plánovacího systému
# - **Microsoft Agent Framework**: Implementace v Pythonu s pokročilou podporou plánování
# - **Integrace modelů GitHub**: Vysoce výkonné uvažování a rozhodování
# - **Orchestrace úkolů**: Koordinované provádění složitých pracovních postupů
# - **Správa stavu**: Trvalé sledování pokroku plánování a výsledků
#
# ### Tok procesu plánování
# ```python
# Complex Goal → Task Analysis → Subtask Decomposition → Execution Planning
#                 ↓                    ↓                    ↓
#          Priority Assessment → Resource Allocation → Sequential Execution
#                 ↓                    ↓                    ↓
#          Progress Monitoring → Adaptive Replanning → Goal Achievement
# ```
#
# ## 🧠 Metodiky plánování
#
# ### 1. **Hierarchické plánování úkolů**
# - Rozklad složitých cílů shora dolů
# - Vnořené struktury cílů se závislostmi
# - Rekurzivní plánování pro podcíle
# - Efektivní přidělování zdrojů napříč úrovněmi
#
# ### 2. **Sekvenční plánování**
# - Postupné provádění úkolů s jasnými závislostmi
# - Řešení chyb a obnovení v každé fázi
# - Kontrolní body pokroku a validace
# - Možnost vrácení při neúspěšných krocích
#
# ### 3. **Paralelní plánování**
# - Současné provádění nezávislých úkolů
# - Synchronizace zdrojů a řešení konfliktů
# - Optimalizace výkonu prostřednictvím paralelizace
# - Koordinované dokončení a agregace výsledků
#
# ## ⚙️ Předpoklady a nastavení
#
# **Požadované závislosti:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Konfigurace prostředí (.env soubor):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Návrhové vzory plánování
#
# ### Plánování zaměřené na cíle
# - **SMART cíle**: Specifické, měřitelné, dosažitelné, relevantní, časově ohraničené cíle
# - **Sledování milníků**: Měření pokroku a kontrolní body validace
# - **Kritéria úspěchu**: Jasné definice dokončení úkolů
# - **Adaptivní strategie**: Dynamické přizpůsobení plánování na základě zpětné vazby
#
# ### Plánování s ohledem na zdroje
# - **Hodnocení schopností**: Porozumění dostupným nástrojům a jejich omezením
# - **Vyvažování zátěže**: Optimální rozdělení úkolů mezi dostupné zdroje
# - **Správa omezení**: Práce v rámci systémových a API limitů
# - **Optimalizace výkonu**: Maximalizace efektivity a minimalizace latence
#
# ### Plánování odolné vůči chybám
# - **Detekce selhání**: Včasná identifikace problémů při plánování nebo provádění
# - **Strategie obnovy**: Automatické záložní řešení a alternativní přístupy
# - **Zachování stavu**: Udržení pokroku během obnovy po chybě
# - **Postupná degradace**: Částečný úspěch, když není možné úplné dokončení
#
# ## 🚀 Pokročilé funkce plánování
#
# - **Meta-plánování**: Agenti, kteří plánují, jak plánovat
# - **Spolupracující plánování**: Koordinace více agentů pro složité projekty
# - **Učení z praxe**: Zlepšování plánovacích strategií v průběhu času
# - **Adaptace v reálném čase**: Dynamické přeplánování na základě měnících se podmínek
#
# ## 📊 Případy použití a aplikace
#
# ### Automatizace obchodních procesů
# - Řízení projektů a plánování úkolů
# - Optimalizace pracovních postupů a přidělování zdrojů
# - Strategické plánování a podpora rozhodování
# - Zlepšování procesů a automatizace
#
# ### Výzkum a analýza
# - Přehled literatury a syntéza
# - Plánování datových analytických procesů
# - Návrh a provádění experimentů
# - Generování a formátování zpráv
#
# ### Kreativní projekty
# - Pracovní postupy tvorby obsahu
# - Koordinace multimediálních projektů
# - Plánování a realizace kampaní
# - Organizace a řízení událostí
#
# Připraveni vytvořit inteligentní plánovací agenty, kteří zvládnou složité, vícekrokové výzvy? Pojďme navrhnout sofistikované schopnosti řešení problémů! 🧠✨

# %%
! pip install agent-framework-core -U

# %%
# 📦 Import Standard Libraries
# os: For environment variable access
# dotenv: For loading environment variables from .env file
import os

from dotenv import load_dotenv

# %%
# 📝 Import Data Modeling Libraries
# Pydantic: For data validation and structured outputs
# BaseModel: Base class for creating data models
# Field: For adding metadata and validation to model fields
# List: Type hint for list collections
from pydantic import BaseModel, Field
from typing import List

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatMessage: For creating structured chat messages
# Role: Enum for message roles (user, assistant, system)
# ChatOptions: Configuration options for chat interactions
# OpenAIChatClient: Client for OpenAI-compatible APIs (GitHub Models)
from agent_framework import ChatMessage, Role, ChatOptions
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# Load configuration from .env file
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎯 Agent Configuration
# Define the agent's name and role

AGENT_NAME = "TravelAgent"

# 📋 System Instructions for Planning Agent
# This agent acts as a coordinator that decides which specialized agents to use
AGENT_INSTRUCTIONS = """You are a planner agent.
    Your job is to decide which agents to run based on the user's request.
    Below are the available agents specialized in different tasks:
    - FlightBooking: For booking flights and providing flight information
    - HotelBooking: For booking hotels and providing hotel information
    - CarRental: For booking cars and providing car rental information
    - ActivitiesBooking: For booking activities and providing activity information
"""

# %%
class SubTask(BaseModel):
    assigned_agent: str = Field(
        description="The specific agent assigned to handle this subtask")
    task_details: str = Field(
        description="Detailed description of what needs to be done for this subtask")


class TravelPlan(BaseModel):
    main_task: str = Field(
        description="The overall travel request from the user")
    subtasks: List[SubTask] = Field(
        description="List of subtasks broken down from the main task, each assigned to a specialized agent")

# %%
options = ChatOptions(response_format=TravelPlan)

# %%
client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
agent =  client.create_agent(name= AGENT_NAME , instructions=AGENT_INSTRUCTIONS)

# %%
messages = [
        ChatMessage(role=Role.USER, text="Create a travel plan for a family of 4, with 2 kids, from Singapore to Melbourne")
    ]

# %%
response = await agent.run(messages,response_format=TravelPlan)

# %%
response.messages[0].text
# Out:
# '{"main_task":"Plan a family trip from Singapore to Melbourne for 4 people, including 2 kids.","subtasks":[{"assigned_agent":"FlightBooking","task_details":"Book one round-trip flight from Singapore to Melbourne for a family of 4, considering family-friendly options."},{"assigned_agent":"HotelBooking","task_details":"Find and book a family-friendly hotel in Melbourne that can accommodate 4 people, including 2 kids."},{"assigned_agent":"CarRental","task_details":"Arrange a car rental in Melbourne for the family to facilitate travel around the city."},{"assigned_agent":"ActivitiesBooking","task_details":"Provide a list of kid-friendly activities and attractions in Melbourne for the family to enjoy."}]}'

# %% [markdown]
# ---
#
# **Prohlášení**:
# Tento dokument byl přeložen pomocí služby AI pro překlady [Co-op Translator](https://github.com/Azure/co-op-translator). I když se snažíme o přesnost, mějte prosím na paměti, že automatizované překlady mohou obsahovat chyby nebo nepřesnosti. Původní dokument v jeho původním jazyce by měl být považován za autoritativní zdroj. Pro důležité informace doporučujeme profesionální lidský překlad. Neodpovídáme za žádná nedorozumění nebo nesprávné interpretace vyplývající z použití tohoto překladu.
