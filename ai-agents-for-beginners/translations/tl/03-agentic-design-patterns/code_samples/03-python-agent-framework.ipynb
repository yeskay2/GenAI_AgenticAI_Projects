# %% [markdown]
# # 🎨 Mga Pattern ng Disenyo para sa Agentic gamit ang GitHub Models (Python)
#
# ## 📋 Mga Layunin sa Pag-aaral
#
# Ipinapakita ng notebook na ito ang mahahalagang pattern ng disenyo para sa paggawa ng matatalinong ahente gamit ang Microsoft Agent Framework na may integrasyon sa GitHub Models. Matututuhan mo ang mga napatunayang pattern at mga disenyong arkitektura na nagpapahusay sa pagiging matatag, madaling mapanatili, at epektibo ng mga ahente.
#
# **Mga Pangunahing Pattern ng Disenyo na Saklaw:**
# - 🏗️ **Agent Factory Pattern**: Pamantayan sa paggawa at pagsasaayos ng ahente
# - 🔧 **Tool Registry Pattern**: Organisadong paraan ng pamamahala sa kakayahan ng ahente
# - 🧵 **Pamamahala ng Usapan**: Epektibong pattern para sa mga multi-turn na interaksyon
# - 🔄 **Pagproseso ng Tugon**: Mga pinakamahusay na kasanayan sa paghawak ng output ng ahente
#
# ## 🎯 Mga Pangunahing Konsepto ng Arkitektura
#
# ### Mga Prinsipyo ng Disenyo
# - **Paghiwalay ng Mga Alalahanin**: Malinaw na hangganan sa pagitan ng lohika ng ahente, mga tool, at pagsasaayos
# - **Composability**: Paggawa ng mga kumplikadong ahente mula sa mga reusable na bahagi
# - **Extensibility**: Mga pattern na nagpapadali sa pagdaragdag ng mga bagong kakayahan
# - **Testability**: Disenyo para sa madaling unit testing at pagpapatunay
#
# ### Integrasyon ng GitHub Models
# - **API Compatibility**: Paggamit ng mga endpoint na compatible sa OpenAI
# - **Pagpili ng Modelo**: Pagpili ng tamang modelo para sa iba't ibang gamit
# - **Rate Limiting**: Maayos na paghawak sa mga limitasyon ng API
# - **Pagbawi sa Error**: Matatag na paghawak sa error at mga pattern ng pag-retry
#
# ## 🔧 Arkitektura Teknikal
#
# ### Mga Pangunahing Komponent
# - **Microsoft Agent Framework**: Implementasyon sa Python na may suporta sa GitHub Models
# - **GitHub Models API**: Pag-access sa mga makabagong modelo ng wika
# - **OpenAI Client Pattern**: Pamantayan sa mga pattern ng interaksyon sa API
# - **Environment Configuration**: Ligtas at flexible na pamamahala sa pagsasaayos
#
# ### Mga Benepisyo ng Pattern ng Disenyo
# - **Madaling Mapanatili**: Malinaw na organisasyon at istruktura ng code
# - **Scalability**: Mga pattern na lumalago kasabay ng pangangailangan ng aplikasyon
# - **Kahusayan**: Napatunayang mga paraan na humahawak sa mga edge case
# - **Pagganap**: Mahusay na paggamit ng mga mapagkukunan at API
#
# ## ⚙️ Mga Kinakailangan at Setup
#
# **Mga Kinakailangang Dependency:**
# ```bash
#
# pip install agent-framework-core  -U
#
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Pag-access sa GitHub Models:**
# - Account sa GitHub na may access sa Models
# - Personal access token na may tamang mga pahintulot
# - Pag-unawa sa mga limitasyon ng rate at mga pattern ng paggamit
#
# ## 📚 Mga Kategorya ng Pattern ng Disenyo
#
# ### 1. **Creational Patterns**
# - Mga pattern ng agent factory at builder
# - Mga pattern ng pamamahala sa pagsasaayos
# - Dependency injection para sa mga serbisyo ng ahente
#
# ### 2. **Behavioral Patterns**
# - Pagpapatupad at orkestrasyon ng tool
# - Pamamahala ng daloy ng usapan
# - Pagproseso at pag-format ng tugon
#
# ### 3. **Integration Patterns**
# - Integrasyon ng GitHub Models API
# - Paghawak sa error at lohika ng pag-retry
# - Pamamahala sa mapagkukunan at cleanup
#
# ## 🚀 Mga Pinakamahusay na Kasanayan na Ipinakita
#
# - **Malinis na Arkitektura**: Layered na disenyo na may malinaw na responsibilidad
# - **Paghawak sa Error**: Komprehensibong pamamahala sa exception
# - **Pagsasaayos**: Setup na nakabatay sa environment para sa iba't ibang kapaligiran
# - **Pagsubok**: Mga pattern na nagbibigay-daan sa epektibong unit at integration testing
# - **Dokumentasyon**: Self-documenting na code na may malinaw na layunin
#
# Handa ka na bang tuklasin ang mga propesyonal na pattern ng disenyo para sa ahente? Gumawa tayo ng isang bagay na matatag! 🌟

# %%
! pip install agent-framework-core  -U

# %%
# 📦 Import Core Libraries for Agent Design Patterns
import os                     # Environment variable access for configuration management
from random import randint    # Random selection utilities for tool functionality

from dotenv import load_dotenv  # Secure environment configuration loading

# %%
# 🤖 Import Microsoft Agent Framework Components  
# ChatAgent: Core agent orchestration class following factory pattern
# OpenAIChatClient: GitHub Models integration following adapter pattern
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Configuration Loading Pattern
# Implement configuration management pattern for secure credential handling
# This follows the external configuration principle for cloud-native applications
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function Design Pattern
# Implements the Strategy Pattern for pluggable agent capabilities
# This demonstrates clean separation of business logic from agent orchestration
def get_random_destination() -> str:
    """Get a random vacation destination using Repository Pattern.
    
    This function exemplifies several design patterns:
    - Strategy Pattern: Interchangeable algorithm for destination selection
    - Repository Pattern: Encapsulates data access logic
    - Factory Method: Creates destination objects on demand
    
    Returns:
        str: A randomly selected destination following consistent format
    """
    # Data Repository Pattern: Centralized destination data management
    destinations = [
        "Barcelona, Spain",      # Mediterranean cultural hub
        "Paris, France",         # European artistic center
        "Berlin, Germany",       # Historical European capital
        "Tokyo, Japan",          # Asian technology metropolis
        "Sydney, Australia",     # Oceanic coastal city
        "New York, USA",         # American urban center
        "Cairo, Egypt",          # African historical capital
        "Cape Town, South Africa", # African scenic destination
        "Rio de Janeiro, Brazil",  # South American beach city
        "Bali, Indonesia"          # Southeast Asian island paradise
    ]
    
    # Factory Method Pattern: Create destination selection on demand
    return destinations[randint(0, len(destinations) - 1)]

# %%
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
AGENT_NAME ="TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers.

Important: When users specify a destination, always plan for that location. Only suggest random destinations when the user hasn't specified a preference.

When the conversation begins, introduce yourself with this message:
"Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
1. Plan a day trip to a specific location
2. Suggest a random vacation destination
3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
4. Plan an alternative trip if you don't like my first suggestion

What kind of trip would you like me to help you plan today?"

Always prioritize user preferences. If they mention a specific destination like "Bali" or "Paris," focus your planning on that location rather than suggesting alternatives.
"""

# %%
agent = ChatAgent(
        name = AGENT_NAME,
        chat_client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
# 1. Plan a day trip to a specific location
# 2. Suggest a random vacation destination
# 3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
# 4. Plan an alternative trip if you don't like my first suggestion
#
# What kind of trip would you like me to help you plan today? Could you please specify a destination for your day trip?

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# Could you please specify a location or type of vacation you're interested in? This will help me find the perfect place for you!

# %% [markdown]
# ---
#
# **Paunawa**:
# Ang dokumentong ito ay isinalin gamit ang AI translation service na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't sinisikap naming maging tumpak, mangyaring tandaan na ang mga awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa kanyang katutubong wika ang dapat ituring na opisyal na sanggunian. Para sa mahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang hindi pagkakaunawaan o maling interpretasyon na dulot ng paggamit ng pagsasaling ito.
