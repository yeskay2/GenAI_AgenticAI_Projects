# %% [markdown]
# # 🎯 การวางแผนและรูปแบบการออกแบบด้วย GitHub Models (Python)
#
# ## 📋 วัตถุประสงค์การเรียนรู้
#
# โน้ตบุ๊กนี้แสดงตัวอย่างการวางแผนและรูปแบบการออกแบบขั้นสูงสำหรับการสร้างตัวแทนอัจฉริยะโดยใช้ Microsoft Agent Framework ร่วมกับ GitHub Models คุณจะได้เรียนรู้วิธีสร้างตัวแทนที่สามารถแยกปัญหาที่ซับซ้อน วางแผนการแก้ปัญหาแบบหลายขั้นตอน และประสานงานกระบวนการทำงานที่ซับซ้อน
#
# **ความสามารถขั้นสูงที่คุณจะเชี่ยวชาญ:**
# - 🧠 **การวางแผนเชิงกลยุทธ์**: การแบ่งงานที่ซับซ้อนออกเป็นงานย่อยที่จัดการได้
# - 🗺️ **การให้เหตุผลแบบหลายขั้นตอน**: รูปแบบการดำเนินงานแบบลำดับและแบบขนาน
# - 🎯 **การออกแบบที่มุ่งเน้นเป้าหมาย**: ตัวแทนที่ทำงานเพื่อบรรลุวัตถุประสงค์เฉพาะ
# - 🔄 **การวางแผนแบบปรับตัว**: การปรับกลยุทธ์แบบไดนามิกตามบริบท
#
# ## 🎯 แนวคิดสถาปัตยกรรมการวางแผน
#
# ### องค์ประกอบหลักของการวางแผน
# - **การแบ่งงาน**: การแยกปัญหาที่ซับซ้อนออกเป็นส่วนย่อยที่จัดการได้
# - **การวางแผนการดำเนินงาน**: การกำหนดลำดับและความสัมพันธ์ที่เหมาะสมสำหรับงานย่อย
# - **การจัดการทรัพยากร**: การจัดสรรเครื่องมือและความสามารถอย่างมีประสิทธิภาพ
# - **การติดตามความคืบหน้า**: การตรวจสอบความสำเร็จและปรับเปลี่ยนตามสถานการณ์
#
# ### รูปแบบการออกแบบสำหรับการวางแผน
# - **Strategy Pattern**: วิธีการวางแผนหลายรูปแบบสำหรับสถานการณ์ต่าง ๆ
# - **Chain of Responsibility**: การประมวลผลแบบลำดับพร้อมตัวเลือกสำรอง
# - **Command Pattern**: การดำเนินงานที่ถูกห่อหุ้มด้วยความสามารถในการยกเลิก/ทำซ้ำ
# - **Observer Pattern**: การติดตามความคืบหน้าและการอัปเดตแบบขับเคลื่อนด้วยเหตุการณ์
#
# ## 🏗️ สถาปัตยกรรมทางเทคนิค
#
# ### องค์ประกอบของระบบการวางแผน
# - **Microsoft Agent Framework**: การใช้งาน Python พร้อมการสนับสนุนการวางแผนขั้นสูง
# - **GitHub Models Integration**: การให้เหตุผลและการตัดสินใจที่มีประสิทธิภาพสูง
# - **Task Orchestration**: การดำเนินงานที่ประสานกันของกระบวนการทำงานที่ซับซ้อน
# - **State Management**: การติดตามความคืบหน้าและผลลัพธ์ของการวางแผนอย่างต่อเนื่อง
#
# ### กระบวนการการวางแผน
# ```python
# Complex Goal → Task Analysis → Subtask Decomposition → Execution Planning
#                 ↓                    ↓                    ↓
#          Priority Assessment → Resource Allocation → Sequential Execution
#                 ↓                    ↓                    ↓
#          Progress Monitoring → Adaptive Replanning → Goal Achievement
# ```
#
# ## 🧠 วิธีการวางแผน
#
# ### 1. **การวางแผนงานแบบลำดับชั้น**
# - การแบ่งวัตถุประสงค์ที่ซับซ้อนจากบนลงล่าง
# - โครงสร้างเป้าหมายที่ซ้อนกันพร้อมความสัมพันธ์
# - การวางแผนแบบวนซ้ำสำหรับวัตถุประสงค์ย่อย
# - การจัดสรรทรัพยากรอย่างมีประสิทธิภาพในแต่ละระดับ
#
# ### 2. **การวางแผนแบบลำดับ**
# - การดำเนินงานทีละขั้นตอนพร้อมความสัมพันธ์ที่ชัดเจน
# - การจัดการข้อผิดพลาดและการกู้คืนในแต่ละขั้นตอน
# - จุดตรวจสอบความคืบหน้าและการตรวจสอบความถูกต้อง
# - ความสามารถในการย้อนกลับสำหรับขั้นตอนที่ล้มเหลว
#
# ### 3. **การวางแผนแบบขนาน**
# - การดำเนินงานพร้อมกันของงานที่เป็นอิสระ
# - การซิงโครไนซ์ทรัพยากรและการแก้ไขข้อขัดแย้ง
# - การเพิ่มประสิทธิภาพผ่านการดำเนินงานแบบขนาน
# - การประสานงานการเสร็จสิ้นและการรวบรวมผลลัพธ์
#
# ## ⚙️ ข้อกำหนดเบื้องต้นและการตั้งค่า
#
# **Dependencies ที่จำเป็น:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **การตั้งค่าสภาพแวดล้อม (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 รูปแบบการออกแบบการวางแผน
#
# ### การวางแผนที่มุ่งเน้นเป้าหมาย
# - **SMART Goals**: วัตถุประสงค์ที่เฉพาะเจาะจง วัดผลได้ บรรลุได้ มีความเกี่ยวข้อง และมีกรอบเวลา
# - **การติดตามเป้าหมายสำคัญ**: การวัดความคืบหน้าและจุดตรวจสอบการตรวจสอบ
# - **เกณฑ์ความสำเร็จ**: คำจำกัดความที่ชัดเจนของการเสร็จสิ้นงาน
# - **กลยุทธ์แบบปรับตัว**: การปรับแผนแบบไดนามิกตามความคิดเห็น
#
# ### การวางแผนที่คำนึงถึงทรัพยากร
# - **การประเมินความสามารถ**: การทำความเข้าใจเครื่องมือที่มีอยู่และข้อจำกัดของเครื่องมือ
# - **การกระจายโหลด**: การกระจายงานอย่างเหมาะสมในทรัพยากรที่มีอยู่
# - **การจัดการข้อจำกัด**: การทำงานภายใต้ข้อจำกัดของระบบและ API
# - **การเพิ่มประสิทธิภาพ**: การเพิ่มประสิทธิภาพและลดความล่าช้า
#
# ### การวางแผนที่ทนต่อข้อผิดพลาด
# - **การตรวจจับความล้มเหลว**: การระบุปัญหาในการวางแผนหรือการดำเนินงานตั้งแต่เนิ่น ๆ
# - **กลยุทธ์การกู้คืน**: ตัวเลือกสำรองและวิธีการทางเลือกอัตโนมัติ
# - **การรักษาสถานะ**: การรักษาความคืบหน้าในระหว่างการกู้คืนข้อผิดพลาด
# - **การลดผลกระทบอย่างมีประสิทธิภาพ**: ความสำเร็จบางส่วนเมื่อไม่สามารถบรรลุผลสำเร็จทั้งหมดได้
#
# ## 🚀 คุณสมบัติการวางแผนขั้นสูง
#
# - **Meta-Planning**: ตัวแทนที่วางแผนว่าจะวางแผนอย่างไร
# - **Collaborative Planning**: การประสานงานหลายตัวแทนสำหรับโครงการที่ซับซ้อน
# - **การเรียนรู้จากประสบการณ์**: การปรับปรุงกลยุทธ์การวางแผนเมื่อเวลาผ่านไป
# - **การปรับตัวแบบเรียลไทม์**: การปรับแผนแบบไดนามิกตามเงื่อนไขที่เปลี่ยนแปลง
#
# ## 📊 กรณีการใช้งานและแอปพลิเคชัน
#
# ### การทำงานอัตโนมัติในกระบวนการธุรกิจ
# - การจัดการโครงการและการกำหนดตารางงาน
# - การเพิ่มประสิทธิภาพกระบวนการทำงานและการจัดสรรทรัพยากร
# - การวางแผนเชิงกลยุทธ์และการสนับสนุนการตัดสินใจ
# - การปรับปรุงกระบวนการและการทำงานอัตโนมัติ
#
# ### การวิจัยและการวิเคราะห์
# - การทบทวนวรรณกรรมและการสังเคราะห์ข้อมูล
# - การวางแผนกระบวนการวิเคราะห์ข้อมูล
# - การออกแบบและดำเนินการทดลอง
# - การสร้างรายงานและการจัดรูปแบบ
#
# ### โครงการสร้างสรรค์
# - กระบวนการสร้างเนื้อหา
# - การประสานงานโครงการมัลติมีเดีย
# - การวางแผนและดำเนินการแคมเปญ
# - การจัดงานและการบริหารจัดการ
#
# พร้อมที่จะสร้างตัวแทนการวางแผนอัจฉริยะที่สามารถจัดการกับความท้าทายที่ซับซ้อนและหลายขั้นตอนแล้วหรือยัง? มาออกแบบความสามารถในการแก้ปัญหาที่ซับซ้อนกันเถอะ! 🧠✨

# %%
! pip install agent-framework-core -U

# %%
# 📦 Import Standard Libraries
# os: For environment variable access
# dotenv: For loading environment variables from .env file
import os

from dotenv import load_dotenv

# %%
# 📝 Import Data Modeling Libraries
# Pydantic: For data validation and structured outputs
# BaseModel: Base class for creating data models
# Field: For adding metadata and validation to model fields
# List: Type hint for list collections
from pydantic import BaseModel, Field
from typing import List

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatMessage: For creating structured chat messages
# Role: Enum for message roles (user, assistant, system)
# ChatOptions: Configuration options for chat interactions
# OpenAIChatClient: Client for OpenAI-compatible APIs (GitHub Models)
from agent_framework import ChatMessage, Role, ChatOptions
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# Load configuration from .env file
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎯 Agent Configuration
# Define the agent's name and role

AGENT_NAME = "TravelAgent"

# 📋 System Instructions for Planning Agent
# This agent acts as a coordinator that decides which specialized agents to use
AGENT_INSTRUCTIONS = """You are a planner agent.
    Your job is to decide which agents to run based on the user's request.
    Below are the available agents specialized in different tasks:
    - FlightBooking: For booking flights and providing flight information
    - HotelBooking: For booking hotels and providing hotel information
    - CarRental: For booking cars and providing car rental information
    - ActivitiesBooking: For booking activities and providing activity information
"""

# %%
class SubTask(BaseModel):
    assigned_agent: str = Field(
        description="The specific agent assigned to handle this subtask")
    task_details: str = Field(
        description="Detailed description of what needs to be done for this subtask")


class TravelPlan(BaseModel):
    main_task: str = Field(
        description="The overall travel request from the user")
    subtasks: List[SubTask] = Field(
        description="List of subtasks broken down from the main task, each assigned to a specialized agent")

# %%
options = ChatOptions(response_format=TravelPlan)

# %%
client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
agent =  client.create_agent(name= AGENT_NAME , instructions=AGENT_INSTRUCTIONS)

# %%
messages = [
        ChatMessage(role=Role.USER, text="Create a travel plan for a family of 4, with 2 kids, from Singapore to Melbourne")
    ]

# %%
response = await agent.run(messages,response_format=TravelPlan)

# %%
response.messages[0].text
# Out:
# '{"main_task":"Plan a family trip from Singapore to Melbourne for 4 people, including 2 kids.","subtasks":[{"assigned_agent":"FlightBooking","task_details":"Book one round-trip flight from Singapore to Melbourne for a family of 4, considering family-friendly options."},{"assigned_agent":"HotelBooking","task_details":"Find and book a family-friendly hotel in Melbourne that can accommodate 4 people, including 2 kids."},{"assigned_agent":"CarRental","task_details":"Arrange a car rental in Melbourne for the family to facilitate travel around the city."},{"assigned_agent":"ActivitiesBooking","task_details":"Provide a list of kid-friendly activities and attractions in Melbourne for the family to enjoy."}]}'

# %% [markdown]
# ---
#
# **ข้อจำกัดความรับผิดชอบ**:
# เอกสารนี้ได้รับการแปลโดยใช้บริการแปลภาษา AI [Co-op Translator](https://github.com/Azure/co-op-translator) แม้ว่าเราจะพยายามให้การแปลมีความถูกต้องมากที่สุด แต่โปรดทราบว่าการแปลอัตโนมัติอาจมีข้อผิดพลาดหรือความไม่ถูกต้อง เอกสารต้นฉบับในภาษาดั้งเดิมควรถือเป็นแหล่งข้อมูลที่เชื่อถือได้ สำหรับข้อมูลที่สำคัญ ขอแนะนำให้ใช้บริการแปลภาษามนุษย์ที่มีความเชี่ยวชาญ เราไม่รับผิดชอบต่อความเข้าใจผิดหรือการตีความผิดที่เกิดจากการใช้การแปลนี้
