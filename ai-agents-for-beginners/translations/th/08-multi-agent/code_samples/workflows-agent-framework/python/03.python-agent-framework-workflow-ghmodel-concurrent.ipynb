# %% [markdown]
# # ⚡ การทำงานแบบคู่ขนานของ Agent ด้วย GitHub Models (Python)
#
# ## 📋 บทเรียนขั้นสูงเกี่ยวกับการประมวลผลแบบคู่ขนาน
#
# โน้ตบุ๊กนี้แสดงให้เห็นถึง **รูปแบบการทำงานแบบคู่ขนาน** โดยใช้ Microsoft Agent Framework คุณจะได้เรียนรู้วิธีสร้างเวิร์กโฟลว์ที่มีประสิทธิภาพสูง ซึ่ง AI agents หลายตัวสามารถทำงานพร้อมกันได้ ช่วยเพิ่มประสิทธิภาพการทำงานและรองรับกระบวนการทางธุรกิจที่ซับซ้อนแบบมัลติเธรด
#
# ## 🎯 วัตถุประสงค์การเรียนรู้
#
# ### 🚀 **พื้นฐานการประมวลผลแบบคู่ขนาน**
# - **การทำงานของ Agent แบบคู่ขนาน**: รัน agents หลายตัวพร้อมกันเพื่อประสิทธิภาพสูงสุด
# - **การจัดการเวิร์กโฟลว์**: ประสานงานการทำงานแบบคู่ขนานในขณะที่รักษาความสอดคล้องของข้อมูล
# - **การปรับปรุงประสิทธิภาพ**: เพิ่มความเร็วอย่างมีนัยสำคัญผ่านการประมวลผลแบบคู่ขนาน
# - **การจัดการทรัพยากร**: ใช้ทรัพยากรของ AI model อย่างมีประสิทธิภาพในระหว่างการทำงานแบบคู่ขนาน
#
# ### 🏗️ **รูปแบบการทำงานแบบคู่ขนานขั้นสูง**
# - **การประมวลผลแบบ Fork-Join**: แบ่งงานระหว่าง agents หลายตัวและรวมผลลัพธ์
# - **Pipeline Parallelism**: การดำเนินการที่ทับซ้อนกันในแต่ละขั้นตอนเพื่อการทำงานต่อเนื่อง
# - **การกระจายโหลด**: แบ่งงานอย่างเท่าเทียมกันระหว่างทรัพยากรของ agent ที่มีอยู่
# - **จุดซิงโครไนซ์**: ประสานงาน agents ที่ทำงานคู่ขนานในขั้นตอนสำคัญของเวิร์กโฟลว์
#
# ### 🏢 **การใช้งานแบบคู่ขนานในองค์กร**
# - **การประมวลผลเอกสารปริมาณมาก**: ประมวลผลเอกสารหลายฉบับพร้อมกัน
# - **การวิเคราะห์เนื้อหาแบบเรียลไทม์**: วิเคราะห์ข้อมูลที่เข้ามาแบบคู่ขนาน
# - **การปรับปรุงการประมวลผลแบบแบตช์**: เพิ่มประสิทธิภาพการทำงานสำหรับการดำเนินการขนาดใหญ่
# - **การวิเคราะห์แบบหลายรูปแบบ**: ประมวลผลเนื้อหาประเภทต่าง ๆ (ข้อความ, รูปภาพ, ข้อมูล) แบบคู่ขนาน
#
# ## ⚙️ ข้อกำหนดเบื้องต้นและการตั้งค่า
#
# ### 📦 **Dependencies ที่จำเป็น**
#
# ติดตั้ง Agent Framework พร้อมความสามารถในการทำงานแบบคู่ขนาน:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **การตั้งค่า GitHub Models**
#
# **การตั้งค่าสภาพแวดล้อม (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **ข้อควรพิจารณาเกี่ยวกับการประมวลผลแบบคู่ขนาน:**
# - **Rate Limits**: ตรวจสอบข้อจำกัดของ GitHub Models API สำหรับคำขอแบบคู่ขนาน
# - **การใช้งานทรัพยากร**: พิจารณาการใช้หน่วยความจำและ CPU เมื่อมี agents หลายตัวทำงานพร้อมกัน
# - **การจัดการข้อผิดพลาด**: ใช้การกู้คืนข้อผิดพลาดที่มีประสิทธิภาพสำหรับการดำเนินการแบบคู่ขนาน
#
# ### 🏗️ **สถาปัตยกรรมเวิร์กโฟลว์แบบคู่ขนาน**
#
# ```mermaid
# graph TD
#     A[Workflow Start] --> B[Concurrent Execution]
#     B --> C[Agent Pool 1]
#     B --> D[Agent Pool 2]
#     B --> E[Agent Pool 3]
#     C --> F[Result Aggregation]
#     D --> F
#     E --> F
#     F --> G[Final Output]
#
#     H[GitHub Models API] --> C
#     H --> D
#     H --> E
# ```
#
# **ประโยชน์หลัก:**
# - **⚡ ประสิทธิภาพ**: เพิ่มความเร็วอย่างมีนัยสำคัญผ่านการดำเนินการแบบคู่ขนาน
# - **📈 ความสามารถในการขยาย**: รองรับปริมาณงานที่เพิ่มขึ้นโดยไม่เพิ่มเวลาในการดำเนินการ
# - **🔄 ประสิทธิภาพ**: ใช้ทรัพยากรคอมพิวเตอร์ที่มีอยู่ได้ดียิ่งขึ้น
# - **🎯 ผลผลิต**: ประมวลผลงานได้มากขึ้นในเวลาเดียวกัน
#
# ## 🎨 **รูปแบบการออกแบบเวิร์กโฟลว์แบบคู่ขนาน**
#
# ### 🔍 **Pipeline การวิจัยและวิเคราะห์**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **เวิร์กโฟลว์การประมวลผลข้อมูล**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Pipeline การสร้างเนื้อหา**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **การประมวลผลหลายขั้นตอน**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ประโยชน์ด้านประสิทธิภาพในองค์กร**
#
# ### ⚡ **การเพิ่มประสิทธิภาพผลผลิต**
# - **การดำเนินการแบบคู่ขนาน**: agents หลายตัวทำงานพร้อมกัน
# - **การใช้ทรัพยากร**: ใช้ความสามารถของ AI model อย่างมีประสิทธิภาพสูงสุด
# - **การลดเวลา**: ลดเวลาการประมวลผลทั้งหมดอย่างมีนัยสำคัญ
# - **สถาปัตยกรรมที่สามารถขยายได้**: เพิ่ม agents แบบคู่ขนานได้ง่ายตามความต้องการ
#
# ### 🛡️ **ความน่าเชื่อถือและความยืดหยุ่น**
# - **ความทนทานต่อข้อผิดพลาด**: การล้มเหลวของ agent แต่ละตัวไม่ส่งผลต่อเวิร์กโฟลว์ทั้งหมด
# - **การแยกข้อผิดพลาด**: ปัญหาในสาขาคู่ขนานหนึ่งไม่ส่งผลกระทบต่อสาขาอื่น
# - **การลดระดับอย่างมีประสิทธิภาพ**: ระบบยังคงทำงานได้แม้ความสามารถของ agent ลดลง
# - **กลไกการกู้คืน**: การลองใหม่อัตโนมัติและการจัดการข้อผิดพลาดสำหรับการดำเนินการที่ล้มเหลว
#
# ### 📊 **การติดตามและการสังเกตการณ์**
# - **การติดตามการดำเนินการแบบคู่ขนาน**: ตรวจสอบความคืบหน้าของการดำเนินการทั้งหมด
# - **ตัวชี้วัดประสิทธิภาพ**: วัดความเร็วและประสิทธิภาพที่เพิ่มขึ้น
# - **การวิเคราะห์การใช้ทรัพยากร**: ปรับปรุงการจัดสรร agent แบบคู่ขนาน
# - **การระบุคอขวด**: ค้นหาและแก้ไขข้อจำกัดด้านประสิทธิภาพ
#
# มาสร้างเวิร์กโฟลว์ AI แบบคู่ขนานที่มีประสิทธิภาพสูงกันเถอะ! 🚀

# %%
! pip install agent-framework-core -U

# %%
import os
from typing import Any

from agent_framework import ChatMessage, ConcurrentBuilder,WorkflowViz
from agent_framework.openai import OpenAIChatClient

# %%
chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id="gpt-4o" )

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent   = chat_client.create_agent(
        instructions=(
           ResearcherAgentInstructions
        ),
        name=ResearcherAgentName,
    )

plan_agent = chat_client.create_agent(
        instructions=(
            PlanAgentInstructions
        ),
        name=PlanAgentName,
    )

# %%
workflow = ConcurrentBuilder().participants([research_agent, plan_agent]).build()

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
svg_file = viz.export(format="svg")
print(f"SVG file saved to: {svg_file}")
# Out:
# Generating workflow visualization...
# Mermaid string:
# ...
# flowchart TD
#   dispatcher["dispatcher (Start)"];
#   Researcher_Agent["Researcher-Agent"];
#   Plan_Agent["Plan-Agent"];
#   aggregator["aggregator"];
#   fan_in__aggregator__69d73de8((fan-in))
#   Plan_Agent --> fan_in__aggregator__69d73de8;
#   Researcher_Agent --> fan_in__aggregator__69d73de8;
#   fan_in__aggregator__69d73de8 --> aggregator;
#   dispatcher --> Researcher_Agent;
#   dispatcher --> Plan_Agent;
# ...
# DiGraph string:
# ...
# digraph Workflow {
#   rankdir=TD;
#   node [shape=box, style=filled, fillcolor=lightblue];
#   edge [color=black, arrowhead=vee];
#
#   "dispatcher" [fillcolor=lightgreen, label="dispatcher\n(Start)"];
#   "Researcher-Agent" [label="Researcher-Agent"];
#   "Plan-Agent" [label="Plan-Agent"];
#   "aggregator" [label="aggregator"];
#
#   "fan_in::aggregator::69d73de8" [shape=ellipse, fillcolor=lightgoldenrod, label="fan-in"];
#   "Plan-Agent" -> "fan_in::aggregator::69d73de8";
# ...

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")
# Out:
# Attempting to display SVG file at: C:\Users\kinfeylo\AppData\Local\Temp\tmpoq68cqjk.svg

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
        print("===== Final Aggregated Conversation (messages) =====")
        for output in outputs:
            messages: list[ChatMessage] | Any = output
            for i, msg in enumerate(messages, start=1):
                name = msg.author_name if msg.author_name else "user"
                print(f"{'-' * 60}\n\n{i:02d} [{name}]:\n{msg.text}")
# Out:
# ===== Final Aggregated Conversation (messages) =====
# ------------------------------------------------------------
#
# 01 [user]:
# Plan a trip to Seattle in December
# ------------------------------------------------------------
#
# 02 [Researcher-Agent]:
# Seattle is a wonderful place to visit in December, with vibrant winter festivities, seasonal attractions, and gorgeous views of the Pacific Northwest. Despite the chilly weather and occasional rain, Seattle’s charm shines through its indoor and outdoor attractions. Here's a detailed plan for your trip:
#
# ---
#
# ### **Destination Overview: Seattle in December**
# - **Weather**: Expect average highs of around 47°F (8°C) and lows near 37°F (3°C). Rain is frequent, so bring waterproof clothing.
# - **Packing List**:
#   - Warm layers (sweaters, coats, gloves, and hats).
#   - Comfortable walking shoes (water-resistant is ideal).
#   - Umbrella or rain jacket.
#
# ---
#
# ### **Day 1: Exploring Downtown Seattle**
# ...

# %% [markdown]
# ---
#
# **ข้อจำกัดความรับผิดชอบ**:
# เอกสารนี้ได้รับการแปลโดยใช้บริการแปลภาษา AI [Co-op Translator](https://github.com/Azure/co-op-translator) แม้ว่าเราจะพยายามให้การแปลมีความถูกต้องมากที่สุด แต่โปรดทราบว่าการแปลอัตโนมัติอาจมีข้อผิดพลาดหรือความไม่ถูกต้อง เอกสารต้นฉบับในภาษาดั้งเดิมควรถือเป็นแหล่งข้อมูลที่เชื่อถือได้ สำหรับข้อมูลที่สำคัญ ขอแนะนำให้ใช้บริการแปลภาษามนุษย์ที่มีความเชี่ยวชาญ เราไม่รับผิดชอบต่อความเข้าใจผิดหรือการตีความผิดที่เกิดจากการใช้การแปลนี้
