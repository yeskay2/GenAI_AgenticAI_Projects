# %% [markdown]
# # 🤝 ระบบการทำงานแบบหลายตัวแทนด้วยโมเดล GitHub (Python)
#
# ## 📋 วัตถุประสงค์การเรียนรู้
#
# โน้ตบุ๊กนี้แสดงวิธีการสร้างระบบหลายตัวแทนที่ซับซ้อนโดยใช้ Microsoft Agent Framework ร่วมกับโมเดล GitHub คุณจะได้เรียนรู้การจัดการตัวแทนเฉพาะทางหลายตัวที่ทำงานร่วมกันเพื่อแก้ปัญหาที่ซับซ้อนผ่านกระบวนการทำงานที่มีโครงสร้าง
#
# **ความสามารถของระบบหลายตัวแทนที่คุณจะสร้าง:**
# - 👥 **การทำงานร่วมกันของตัวแทน**: ตัวแทนหลายตัวทำงานร่วมกันเพื่อบรรลุเป้าหมายร่วมกัน
# - 🔄 **การจัดการกระบวนการทำงาน**: การประสานงานที่มีโครงสร้างระหว่างการโต้ตอบของตัวแทน
# - 🎭 **ความเชี่ยวชาญเฉพาะด้าน**: ตัวแทนที่มีบุคลิกและความเชี่ยวชาญเฉพาะทาง
# - 📋 **การประกันคุณภาพ**: การตรวจสอบและปรับปรุงผ่านการทำงานร่วมกันของตัวแทน
#
# ## 🎯 แนวคิดสถาปัตยกรรมระบบหลายตัวแทน
#
# ### หลักการสำคัญของระบบหลายตัวแทน
# - **การแบ่งงาน**: ตัวแทนแต่ละตัวมีความเชี่ยวชาญในด้านเฉพาะ
# - **การตัดสินใจร่วมกัน**: ตัวแทนตรวจสอบและปรับปรุงงานของกันและกัน
# - **การประสานงานกระบวนการทำงาน**: การส่งต่อและรูปแบบการสื่อสารที่มีโครงสร้าง
# - **การปรับปรุงคุณภาพ**: การพัฒนาซ้ำผ่านการวิเคราะห์จากหลายมุมมอง
#
# ### รูปแบบการโต้ตอบของตัวแทน
# - **การประมวลผลแบบลำดับ**: กระบวนการทำงานเชิงเส้นที่มีการมีส่วนร่วมของตัวแทนตามลำดับ
# - **การตรวจสอบโดยเพื่อนร่วมงาน**: ตัวแทนตรวจสอบและปรับปรุงผลลัพธ์ของกันและกัน
# - **โครงสร้างแบบลำดับชั้น**: ตัวแทนหลักประสานงานกับผู้เชี่ยวชาญที่อยู่ใต้บังคับบัญชา
# - **การสร้างฉันทามติ**: ตัวแทนหลายตัวมีส่วนร่วมในการตัดสินใจขั้นสุดท้าย
#
# ## 🏗️ สถาปัตยกรรมทางเทคนิค
#
# ### ส่วนประกอบของระบบกระบวนการทำงาน
# - **Microsoft Agent Framework**: การใช้งาน Python พร้อมการสนับสนุนกระบวนการทำงานขั้นสูง
# - **WorkflowBuilder**: เครื่องมือกำหนดและดำเนินการกระบวนการทำงานแบบประกาศ
# - **การประสานงานตัวแทน**: กลไกการสื่อสารและการส่งต่อที่มีโครงสร้าง
# - **การประมวลผลแบบขับเคลื่อนด้วยเหตุการณ์**: การดำเนินการกระบวนการทำงานแบบตอบสนองตามผลลัพธ์ของตัวแทน
#
# ### กระบวนการทำงานของระบบหลายตัวแทน
# ```python
# User Request → Agent 1 (Specialist) → Agent 2 (Reviewer) → Quality Check
#                 ↓                      ↓                    ↓
#          Initial Solution → Review & Feedback → Refined Output → Final Result
# ```
#
# ## 🎭 ตัวอย่างบทบาทของตัวแทน
#
# ### ระบบเจ้าหน้าที่ดูแลโรงแรม
# โน้ตบุ๊กนี้แสดงระบบแนะนำการเดินทางที่มีบทบาทเฉพาะทาง:
#
# #### 🏨 **ตัวแทนแผนกต้อนรับ**
# - **ความเชี่ยวชาญ**: คำแนะนำการเดินทางและความรู้เกี่ยวกับพื้นที่
# - **บุคลิกภาพ**: สื่อสารอย่างมีประสิทธิภาพ มีประสบการณ์ และกระชับ
# - **หน้าที่**: สร้างคำแนะนำการเดินทางและกิจกรรมเบื้องต้น
#
# #### 🎩 **ตัวแทนเจ้าหน้าที่ดูแลแขก**
# - **ความเชี่ยวชาญ**: ประสบการณ์ท้องถิ่นที่แท้จริงและการประเมินคุณภาพ
# - **บุคลิกภาพ**: พิถีพิถัน มุ่งเน้นคำแนะนำที่ไม่ใช่แหล่งท่องเที่ยวทั่วไป
# - **หน้าที่**: ตรวจสอบและปรับปรุงคำแนะนำการเดินทางให้มีความแท้จริง
#
# ## 🔧 การใช้งานทางเทคนิค
#
# ### สถาปัตยกรรมกระบวนการทำงาน
# - **การกำหนดตัวแทน**: คำแนะนำเฉพาะทางและการกำหนดบุคลิกภาพ
# - **Workflow Builder**: การกำหนดกระบวนการทำงานแบบประกาศพร้อมการจัดการเหตุการณ์
# - **โปรโตคอลการสื่อสาร**: การส่งข้อความระหว่างตัวแทนที่มีโครงสร้าง
# - **การรวมผลลัพธ์**: การรวมผลลัพธ์จากมุมมองของตัวแทนหลายตัว
#
# ### การประสานงานแบบขับเคลื่อนด้วยเหตุการณ์
# - **WorkflowEvent**: จุดเริ่มต้นสำหรับการเปิดใช้งานตัวแทนและการส่งต่อ
# - **OutputEvent**: การแลกเปลี่ยนข้อมูลที่มีโครงสร้างระหว่างตัวแทน
# - **Quality Gates**: จุดตรวจสอบความถูกต้องในกระบวนการทำงาน
# - **Feedback Loops**: การปรับปรุงซ้ำผ่านการทำงานร่วมกันของตัวแทน
#
# ## ⚙️ ข้อกำหนดเบื้องต้นและการตั้งค่า
#
# **การพึ่งพาที่จำเป็น:**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **การกำหนดค่าระบบ (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 รูปแบบการออกแบบระบบหลายตัวแทน
#
# ### 1. **รูปแบบผู้ผลิต-ผู้บริโภค**
# - ตัวแทนเฉพาะทางสร้างเนื้อหาเพื่อให้ผู้อื่นตรวจสอบ
# - จุดส่งต่อที่ชัดเจนและโปรโตคอลการแลกเปลี่ยนข้อมูล
# - การประกันคุณภาพผ่านการตรวจสอบโดยอิสระ
# - วงจรการปรับปรุงและพัฒนาซ้ำ
#
# ### 2. **รูปแบบคณะกรรมการ**
# - ตัวแทนหลายตัวมีส่วนร่วมในมุมมองที่แตกต่างกัน
# - การสร้างฉันทามติผ่านการอภิปรายที่มีโครงสร้าง
# - การตัดสินใจแบบประชาธิปไตยด้วยความคิดเห็นที่มีน้ำหนัก
# - กลไกการแก้ไขข้อขัดแย้งและการตัดสินใจในกรณีที่มีคะแนนเท่ากัน
#
# ### 3. **รูปแบบลำดับชั้น**
# - ตัวแทนหลักประสานงานกับผู้เชี่ยวชาญที่อยู่ใต้บังคับบัญชา
# - โครงสร้างอำนาจที่ชัดเจนและการไหลของการตัดสินใจ
# - เส้นทางการส่งต่อสำหรับการตัดสินใจที่ซับซ้อน
# - การตรวจสอบประสิทธิภาพและการควบคุมคุณภาพ
#
# ### 4. **รูปแบบสายงาน**
# - การประมวลผลแบบลำดับขั้นตอนที่มีความเชี่ยวชาญเฉพาะทาง
# - ตัวแทนแต่ละตัวเพิ่มคุณค่าในด้านที่ตนเชี่ยวชาญ
# - การประมวลผลที่มีประสิทธิภาพผ่านการดำเนินการแบบขนาน
# - การจัดการข้อผิดพลาดและการกู้คืนในแต่ละขั้นตอน
#
# ## 🚀 คุณสมบัติขั้นสูงของระบบหลายตัวแทน
#
# ### การจัดการกระบวนการทำงาน
# - **การกำหนดเส้นทางแบบไดนามิก**: การเลือกและกำหนดเส้นทางตัวแทนตามบริบท
# - **การประมวลผลแบบขนาน**: การดำเนินการตัวแทนพร้อมกันเพื่อประสิทธิภาพ
# - **การกู้คืนข้อผิดพลาด**: การจัดการข้อผิดพลาดของตัวแทนและการลองใหม่อย่างราบรื่น
# - **การตรวจสอบประสิทธิภาพ**: การติดตามการดำเนินการกระบวนการทำงานและการปรับปรุง
#
# ### การสื่อสารของตัวแทน
# - **การส่งข้อความที่มีโครงสร้าง**: โปรโตคอลการสื่อสารที่ปลอดภัยต่อประเภทข้อมูล
# - **การรักษาบริบท**: การรักษาประวัติการสนทนาระหว่างตัวแทน
# - **การส่งผ่านเมตาดาต้า**: การแลกเปลี่ยนข้อมูลที่หลากหลายเกินกว่าข้อความ
# - **การกระจายเหตุการณ์**: รูปแบบการเผยแพร่-สมัครสมาชิกสำหรับการประสานงาน
#
# ### การประกันคุณภาพ
# - **การตรวจสอบจากหลายมุมมอง**: ตัวแทนต่าง ๆ นำเสนอมุมมองที่เป็นเอกลักษณ์
# - **การปรับปรุงซ้ำ**: การพัฒนาความก้าวหน้าผ่านการทำงานร่วมกัน
# - **จุดตรวจสอบความถูกต้อง**: จุดตรวจสอบคุณภาพในกระบวนการทำงาน
# - **ตัวชี้วัดประสิทธิภาพ**: การวัดประสิทธิภาพของการทำงานร่วมกัน
#
# ## 📊 กรณีการใช้งานและการประยุกต์ใช้
#
# ### การทำงานอัตโนมัติในกระบวนการธุรกิจ
# - การตรวจสอบเอกสารและกระบวนการอนุมัติ
# - ระบบการส่งต่อบริการลูกค้า
# - การตรวจสอบคุณภาพและการปฏิบัติตามข้อกำหนด
# - การสร้างและแก้ไขเนื้อหาแบบหลายขั้นตอน
#
# ### การวิจัยและการวิเคราะห์
# - ระบบตรวจสอบโดยเพื่อนสำหรับงานวิจัย
# - การวิเคราะห์ทางการเงินโดยนักวิเคราะห์หลายคน
# - การเขียนรายงานร่วมกันและการตรวจสอบข้อเท็จจริง
# - การตรวจสอบและปรับปรุงงานวิชาการ
#
# ### การทำงานร่วมกันเชิงสร้างสรรค์
# - การสร้างเนื้อหาด้วยบรรณาธิการและผู้ตรวจสอบ
# - การระดมความคิดเชิงสร้างสรรค์จากหลายมุมมอง
# - การออกแบบและระบบตอบรับแบบซ้ำ
# - การเล่าเรื่องและการสร้างโลกแบบร่วมมือกัน
#
# พร้อมที่จะจัดการการทำงานร่วมกันของตัวแทนอัจฉริยะแล้วหรือยัง? มาสร้างระบบที่ตัวแทนทำงานร่วมกันเหมือนทีมที่มีประสิทธิภาพสูงกันเถอะ! 🌟🤖

# %%
! pip install agent-framework-core -U

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent

# %%
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings

# %%
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# Workflow output: Visit the Louvre Museum for an unparalleled art experience.

# %% [markdown]
# ---
#
# **ข้อจำกัดความรับผิดชอบ**:
# เอกสารนี้ได้รับการแปลโดยใช้บริการแปลภาษา AI [Co-op Translator](https://github.com/Azure/co-op-translator) แม้ว่าเราจะพยายามให้การแปลมีความถูกต้อง แต่โปรดทราบว่าการแปลโดยอัตโนมัติอาจมีข้อผิดพลาดหรือความไม่ถูกต้อง เอกสารต้นฉบับในภาษาดั้งเดิมควรถือเป็นแหล่งข้อมูลที่เชื่อถือได้ สำหรับข้อมูลที่สำคัญ ขอแนะนำให้ใช้บริการแปลภาษามืออาชีพ เราไม่รับผิดชอบต่อความเข้าใจผิดหรือการตีความผิดที่เกิดจากการใช้การแปลนี้
