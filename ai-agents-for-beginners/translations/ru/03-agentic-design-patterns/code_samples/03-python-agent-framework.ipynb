# %% [markdown]
# # 🎨 Агентные шаблоны проектирования с моделями GitHub (Python)
#
# ## 📋 Цели обучения
#
# Этот ноутбук демонстрирует ключевые шаблоны проектирования для создания интеллектуальных агентов с использованием Microsoft Agent Framework и интеграции моделей GitHub. Вы узнаете проверенные подходы и архитектурные решения, которые делают агентов более надежными, удобными для сопровождения и эффективными.
#
# **Основные шаблоны проектирования:**
# - 🏗️ **Шаблон фабрики агентов**: Стандартизированное создание и настройка агентов
# - 🔧 **Шаблон реестра инструментов**: Организованный подход к управлению возможностями агентов
# - 🧵 **Управление диалогом**: Эффективные шаблоны для взаимодействий с несколькими ходами
# - 🔄 **Обработка ответов**: Лучшие практики для работы с выводами агентов
#
# ## 🎯 Основные архитектурные концепции
#
# ### Принципы проектирования
# - **Разделение обязанностей**: Четкое разграничение логики агента, инструментов и конфигурации
# - **Композиционность**: Создание сложных агентов из повторно используемых компонентов
# - **Расширяемость**: Шаблоны, позволяющие легко добавлять новые возможности
# - **Тестируемость**: Проектирование для удобного модульного тестирования и проверки
#
# ### Интеграция моделей GitHub
# - **Совместимость API**: Использование конечных точек, совместимых с OpenAI
# - **Выбор модели**: Подбор подходящих моделей для различных сценариев
# - **Ограничение скорости**: Грамотное управление ограничениями API
# - **Восстановление после ошибок**: Надежная обработка ошибок и шаблоны повторных попыток
#
# ## 🔧 Техническая архитектура
#
# ### Основные компоненты
# - **Microsoft Agent Framework**: Реализация на Python с поддержкой моделей GitHub
# - **API моделей GitHub**: Доступ к передовым языковым моделям
# - **Шаблон клиента OpenAI**: Стандартизированные шаблоны взаимодействия с API
# - **Конфигурация окружения**: Безопасное и гибкое управление настройками
#
# ### Преимущества шаблонов проектирования
# - **Удобство сопровождения**: Четкая организация и структура кода
# - **Масштабируемость**: Шаблоны, которые растут вместе с потребностями приложения
# - **Надежность**: Проверенные подходы для обработки крайних случаев
# - **Производительность**: Эффективное использование ресурсов и API
#
# ## ⚙️ Предварительные требования и настройка
#
# **Необходимые зависимости:**
# ```bash
#
# pip install agent-framework-core  -U
#
# ```
#
# **Конфигурация окружения (.env файл):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Доступ к моделям GitHub:**
# - Аккаунт GitHub с доступом к моделям
# - Личный токен доступа с соответствующими разрешениями
# - Понимание ограничений скорости и шаблонов использования
#
# ## 📚 Категории шаблонов проектирования
#
# ### 1. **Шаблоны создания**
# - Шаблоны фабрики и построителя агентов
# - Шаблоны управления конфигурацией
# - Внедрение зависимостей для сервисов агентов
#
# ### 2. **Поведенческие шаблоны**
# - Выполнение и оркестрация инструментов
# - Управление потоком диалога
# - Обработка и форматирование ответов
#
# ### 3. **Шаблоны интеграции**
# - Интеграция с API моделей GitHub
# - Обработка ошибок и логика повторных попыток
# - Управление ресурсами и очистка
#
# ## 🚀 Демонстрируемые лучшие практики
#
# - **Чистая архитектура**: Слоистый дизайн с четкими обязанностями
# - **Обработка ошибок**: Комплексное управление исключениями
# - **Конфигурация**: Настройка на основе окружения для различных сред
# - **Тестирование**: Шаблоны, позволяющие эффективно проводить модульное и интеграционное тестирование
# - **Документация**: Самодокументируемый код с ясным намерением
#
# Готовы изучить профессиональные шаблоны проектирования агентов? Давайте создадим что-то надежное! 🌟

# %%
! pip install agent-framework-core  -U

# %%
# 📦 Import Core Libraries for Agent Design Patterns
import os                     # Environment variable access for configuration management
from random import randint    # Random selection utilities for tool functionality

from dotenv import load_dotenv  # Secure environment configuration loading

# %%
# 🤖 Import Microsoft Agent Framework Components  
# ChatAgent: Core agent orchestration class following factory pattern
# OpenAIChatClient: GitHub Models integration following adapter pattern
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Configuration Loading Pattern
# Implement configuration management pattern for secure credential handling
# This follows the external configuration principle for cloud-native applications
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function Design Pattern
# Implements the Strategy Pattern for pluggable agent capabilities
# This demonstrates clean separation of business logic from agent orchestration
def get_random_destination() -> str:
    """Get a random vacation destination using Repository Pattern.
    
    This function exemplifies several design patterns:
    - Strategy Pattern: Interchangeable algorithm for destination selection
    - Repository Pattern: Encapsulates data access logic
    - Factory Method: Creates destination objects on demand
    
    Returns:
        str: A randomly selected destination following consistent format
    """
    # Data Repository Pattern: Centralized destination data management
    destinations = [
        "Barcelona, Spain",      # Mediterranean cultural hub
        "Paris, France",         # European artistic center
        "Berlin, Germany",       # Historical European capital
        "Tokyo, Japan",          # Asian technology metropolis
        "Sydney, Australia",     # Oceanic coastal city
        "New York, USA",         # American urban center
        "Cairo, Egypt",          # African historical capital
        "Cape Town, South Africa", # African scenic destination
        "Rio de Janeiro, Brazil",  # South American beach city
        "Bali, Indonesia"          # Southeast Asian island paradise
    ]
    
    # Factory Method Pattern: Create destination selection on demand
    return destinations[randint(0, len(destinations) - 1)]

# %%
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
AGENT_NAME ="TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers.

Important: When users specify a destination, always plan for that location. Only suggest random destinations when the user hasn't specified a preference.

When the conversation begins, introduce yourself with this message:
"Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
1. Plan a day trip to a specific location
2. Suggest a random vacation destination
3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
4. Plan an alternative trip if you don't like my first suggestion

What kind of trip would you like me to help you plan today?"

Always prioritize user preferences. If they mention a specific destination like "Bali" or "Paris," focus your planning on that location rather than suggesting alternatives.
"""

# %%
agent = ChatAgent(
        name = AGENT_NAME,
        chat_client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
# 1. Plan a day trip to a specific location
# 2. Suggest a random vacation destination
# 3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
# 4. Plan an alternative trip if you don't like my first suggestion
#
# What kind of trip would you like me to help you plan today? Could you please specify a destination for your day trip?

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# Could you please specify a location or type of vacation you're interested in? This will help me find the perfect place for you!

# %% [markdown]
# ---
#
# **Отказ от ответственности**:
# Этот документ был переведен с использованием сервиса автоматического перевода [Co-op Translator](https://github.com/Azure/co-op-translator). Несмотря на наши усилия обеспечить точность, автоматические переводы могут содержать ошибки или неточности. Оригинальный документ на его родном языке следует считать авторитетным источником. Для получения критически важной информации рекомендуется профессиональный перевод человеком. Мы не несем ответственности за любые недоразумения или неправильные интерпретации, возникшие в результате использования данного перевода.
