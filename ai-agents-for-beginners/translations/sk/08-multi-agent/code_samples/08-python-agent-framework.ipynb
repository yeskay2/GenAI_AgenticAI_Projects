# %% [markdown]
# # 🤝 Systémy pracovných postupov s viacerými agentmi pomocou GitHub modelov (Python)
#
# ## 📋 Ciele učenia
#
# Tento notebook ukazuje, ako vytvoriť sofistikované systémy s viacerými agentmi pomocou Microsoft Agent Framework a GitHub modelov. Naučíte sa koordinovať viacerých špecializovaných agentov, ktorí spolupracujú na riešení zložitých problémov prostredníctvom štruktúrovaných pracovných postupov.
#
# **Schopnosti viacerých agentov, ktoré si osvojíte:**
# - 👥 **Spolupráca agentov**: Viacerí agenti pracujúci spoločne na dosiahnutí spoločných cieľov
# - 🔄 **Orchestrácia pracovných postupov**: Štruktúrovaná koordinácia interakcií agentov
# - 🎭 **Špecializácia rolí**: Agenti s odlišnými osobnosťami a oblasťami odbornosti
# - 📋 **Zabezpečenie kvality**: Kontrola a zdokonaľovanie prostredníctvom spolupráce agentov
#
# ## 🎯 Koncepty architektúry viacerých agentov
#
# ### Základné princípy viacerých agentov
# - **Rozdelenie práce**: Každý agent sa špecializuje na konkrétnu oblasť odbornosti
# - **Spoločné rozhodovanie**: Agenti kontrolujú a zdokonaľujú prácu jeden druhého
# - **Koordinácia pracovných postupov**: Štruktúrované odovzdávanie a komunikačné vzory
# - **Zlepšovanie kvality**: Iteratívne zdokonaľovanie prostredníctvom analýzy z viacerých perspektív
#
# ### Vzory interakcie agentov
# - **Sekvenčné spracovanie**: Lineárny pracovný postup s usporiadanou účasťou agentov
# - **Recenzia kolegov**: Agenti overujú a zlepšujú výstupy jeden druhého
# - **Hierarchická štruktúra**: Vedúci agenti koordinujú podriadených špecialistov
# - **Budovanie konsenzu**: Viacerí agenti prispievajú k finálnym rozhodnutiam
#
# ## 🏗️ Technická architektúra
#
# ### Komponenty systému pracovných postupov
# - **Microsoft Agent Framework**: Implementácia v Pythone s pokročilou podporou pracovných postupov
# - **WorkflowBuilder**: Deklaratívny nástroj na definovanie a vykonávanie pracovných postupov
# - **Koordinácia agentov**: Štruktúrovaná komunikácia a mechanizmy odovzdávania
# - **Spracovanie na základe udalostí**: Reaktívne vykonávanie pracovných postupov na základe výstupov agentov
#
# ### Procesný tok viacerých agentov
# ```python
# User Request → Agent 1 (Specialist) → Agent 2 (Reviewer) → Quality Check
#                 ↓                      ↓                    ↓
#          Initial Solution → Review & Feedback → Refined Output → Final Result
# ```
#
# ## 🎭 Príklady rolí agentov
#
# ### Systém hotelového concierge
# Tento notebook demonštruje systém odporúčaní na cestovanie so špecializovanými rolami:
#
# #### 🏨 **Agent recepcie**
# - **Odbornosť**: Odporúčania na cestovanie a miestne znalosti
# - **Osobnosť**: Efektívny, skúsený, stručný štýl komunikácie
# - **Zodpovednosti**: Generovanie počiatočných návrhov na cestovanie a aktivity
#
# #### 🎩 **Agent concierge**
# - **Odbornosť**: Autentické miestne zážitky a hodnotenie kvality
# - **Osobnosť**: Náročný, zameraný na odporúčania mimo turistických trás
# - **Zodpovednosti**: Kontrola a zdokonaľovanie návrhov na cestovanie z hľadiska autenticity
#
# ## 🔧 Technická implementácia
#
# ### Architektúra pracovných postupov
# - **Definícia agentov**: Špecializované pokyny a konfigurácia osobnosti
# - **Workflow Builder**: Deklaratívne definovanie pracovných postupov s obsluhou udalostí
# - **Komunikačný protokol**: Štruktúrované odovzdávanie správ medzi agentmi
# - **Agregácia výsledkov**: Kombinovanie výstupov z viacerých perspektív agentov
#
# ### Koordinácia na základe udalostí
# - **WorkflowEvent**: Spúšťacie body pre aktiváciu agentov a odovzdávanie
# - **OutputEvent**: Štruktúrovaná výmena údajov medzi agentmi
# - **Kontrolné body kvality**: Validačné kontrolné body v procese pracovného postupu
# - **Slučky spätnej väzby**: Iteratívne zdokonaľovanie prostredníctvom spolupráce agentov
#
# ## ⚙️ Predpoklady a nastavenie
#
# **Požadované závislosti:**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **Konfigurácia prostredia (.env súbor):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Vzory návrhu viacerých agentov
#
# ### 1. **Vzory producent-spotrebiteľ**
# - Špecializovaní agenti generujú obsah na kontrolu ostatnými
# - Jasné body odovzdávania a protokoly výmeny údajov
# - Zabezpečenie kvality prostredníctvom nezávislej kontroly
# - Iteratívne zdokonaľovanie a cykly zlepšovania
#
# ### 2. **Vzory komisie**
# - Viacerí agenti prispievajúci rôznymi perspektívami
# - Budovanie konsenzu prostredníctvom štruktúrovanej diskusie
# - Demokratické rozhodovanie s váženými názormi
# - Riešenie konfliktov a mechanizmy na prekonanie nerozhodnosti
#
# ### 3. **Hierarchické vzory**
# - Vedúci agenti koordinujúci špecializovaných podriadených
# - Jasné štruktúry autority a tok rozhodovania
# - Cesty eskalácie pre zložité rozhodnutia
# - Monitorovanie výkonu a kontrola kvality
#
# ### 4. **Vzory pipeline**
# - Sekvenčné spracovanie so špecializovanými etapami
# - Každý agent pridáva hodnotu vo svojej oblasti odbornosti
# - Efektívny prenos prostredníctvom paralelného spracovania
# - Riešenie chýb a obnova v každej etape
#
# ## 🚀 Pokročilé funkcie viacerých agentov
#
# ### Orchestrácia pracovných postupov
# - **Dynamické smerovanie**: Výber a smerovanie agentov na základe kontextu
# - **Paralelné spracovanie**: Súbežné vykonávanie agentov pre efektivitu
# - **Obnova chýb**: Elegantné riešenie zlyhaní agentov a opakovanie
# - **Monitorovanie výkonu**: Sledovanie vykonávania pracovných postupov a optimalizácia
#
# ### Komunikácia agentov
# - **Štruktúrované správy**: Typovo bezpečné komunikačné protokoly
# - **Zachovanie kontextu**: Udržiavanie histórie konverzácie medzi agentmi
# - **Prenos metadát**: Bohatá výmena informácií nad rámec textového obsahu
# - **Vysielanie udalostí**: Vzory publikovania a odberu na koordináciu
#
# ### Zabezpečenie kvality
# - **Recenzia z viacerých perspektív**: Rôzni agenti prinášajú jedinečné pohľady
# - **Iteratívne zdokonaľovanie**: Postupné zlepšovanie prostredníctvom spolupráce
# - **Validačné kontrolné body**: Kontrolné body kvality v celom pracovnom postupe
# - **Výkonnostné metriky**: Meranie efektívnosti spolupráce
#
# ## 📊 Použitie a aplikácie
#
# ### Automatizácia obchodných procesov
# - Pracovné postupy na kontrolu a schvaľovanie dokumentov
# - Systémy eskalácie zákazníckych služieb
# - Zabezpečenie kvality a kontrola súladu
# - Viacstupňová tvorba obsahu a jeho úprava
#
# ### Výskum a analýza
# - Systémy recenzie kolegov pre výskumné práce
# - Finančná analýza viacerých analytikov
# - Spoločné písanie správ a kontrola faktov
# - Recenzia a zlepšovanie akademických prác
#
# ### Kreatívna spolupráca
# - Tvorba obsahu s editormi a recenzentmi
# - Kreatívne brainstormingy z viacerých perspektív
# - Iteratívne návrhy a systémy spätnej väzby
# - Spoločné rozprávanie príbehov a budovanie sveta
#
# Pripravení orchestrovať inteligentnú spoluprácu viacerých agentov? Poďme budovať systémy, kde agenti spolupracujú ako vysoko výkonný tím! 🌟🤖

# %%
! pip install agent-framework-core -U

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent

# %%
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings

# %%
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# Workflow output: Visit the Louvre Museum for an unparalleled art experience.

# %% [markdown]
# ---
#
# **Upozornenie**:
# Tento dokument bol preložený pomocou služby AI prekladu [Co-op Translator](https://github.com/Azure/co-op-translator). Aj keď sa snažíme o presnosť, prosím, berte na vedomie, že automatizované preklady môžu obsahovať chyby alebo nepresnosti. Pôvodný dokument v jeho rodnom jazyku by mal byť považovaný za autoritatívny zdroj. Pre kritické informácie sa odporúča profesionálny ľudský preklad. Nenesieme zodpovednosť za akékoľvek nedorozumenia alebo nesprávne interpretácie vyplývajúce z použitia tohto prekladu.
