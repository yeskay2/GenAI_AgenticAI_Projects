# %% [markdown]
# # ಉದಾಹರಣೆ ಮಾದರಿ ಹೋಟೆಲ್ ಮತ್ತು ವಿಮಾನ ಬುಕ್ಕರ್ ಏಜೆಂಟ್
#
# ಈ ಪರಿಹಾರವು ನಿಮಗೆ ವಿಮಾನ ಟಿಕೆಟ್‌ಗಳು ಮತ್ತು ಹೋಟೆಲ್ ಬುಕ್ ಮಾಡಲು ಸಹಾಯ ಮಾಡುತ್ತದೆ. ಪರಿಸ್ಥಿತಿ ಲಂಡನ್ ಹೀಥ್ರೋ (LHR) ನಿಂದ ನ್ಯೂಯಾರ್ಕ್ (JFK) ಗೆ ಫೆಬ್ರವರಿ 20, 2024 ರಂದು ಪ್ರಯಾಣ, ಫೆಬ್ರವರಿ 27, 2025 ರಂದು ವಾಪಸ್, ಬ್ರಿಟಿಷ್ ಏರ್‌ವೇಸ್ ಮೂಲಕ ಮಾತ್ರ ಆರ್ಥಿಕ ವರ್ಗದಲ್ಲಿ. ನಾನು ನ್ಯೂಯಾರ್ಕ್‌ನಲ್ಲಿ ಹಿಲ್ಟನ್ ಹೋಟೆಲ್‌ನಲ್ಲಿ ವಾಸಿಸಲು ಬಯಸುತ್ತೇನೆ, ದಯವಿಟ್ಟು ವಿಮಾನ ಮತ್ತು ಹೋಟೆಲ್‌ಗಾಗಿ ವೆಚ್ಚಗಳನ್ನು ಒದಗಿಸಿ.

# %% [markdown]
# # Azure AI Agent Service ಅನ್ನು ಪ್ರಾರಂಭಿಸಿ ಮತ್ತು **.env** ನಿಂದ ಸಂರಚನಾ ಮಾಹಿತಿಯನ್ನು ಪಡೆಯಿರಿ
#
# ### **.env**
#
# .env ಫೈಲ್ ಅನ್ನು ರಚಿಸಿ
#
# **.env** ನಲ್ಲಿ Azure AI Agent Service ನ ಸಂಪರ್ಕ ಸ್ಟ್ರಿಂಗ್, AOAI ಬಳಸುವ ಮಾದರಿ, ಮತ್ತು ಸಂಬಂಧಿತ Google API Search ಸೇವೆಯ API, ENDPOINT ಇತ್ಯಾದಿ ಒಳಗೊಂಡಿರುತ್ತದೆ.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "ನಿಮ್ಮ Azure AI Agent Service Model Deployment Name"
#
# [**NOTE**] ನಿಮಗೆ 100,000 Rate Limit (Tokens per minute) ಮತ್ತು 600 (Request per minute) Rate Limit ಇರುವ ಮಾದರಿ ಬೇಕಾಗುತ್ತದೆ.
#
#   ನೀವು ಮಾದರಿಯನ್ನು Azure AI Foundry - Model ಮತ್ತು Endpoint ನಲ್ಲಿ ಪಡೆಯಬಹುದು.
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "ನಿಮ್ಮ Azure AI Agent Service Project Connection String"
#
#   ನೀವು AI ​​Foundry Portal Screen ನಲ್ಲಿ ನಿಮ್ಮ ಪ್ರಾಜೆಕ್ಟ್ ಓವರ್‌ವ್ಯೂನಲ್ಲಿ ಪ್ರಾಜೆಕ್ಟ್ ಸಂಪರ್ಕ ಸ್ಟ್ರಿಂಗ್ ಅನ್ನು ಪಡೆಯಬಹುದು.
#
# - **SERPAPI_SEARCH_API_KEY** = "ನಿಮ್ಮ SERPAPI Search API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "ನಿಮ್ಮ SERPAPI Search Endpoint"
#
# Azure AI Agent Service ನ Model Deployment Name ಮತ್ತು Project Connection String ಅನ್ನು ಪಡೆಯಲು, ನೀವು Azure AI Agent Service ಅನ್ನು ರಚಿಸಬೇಕು. [ಈ ಟೆಂಪ್ಲೇಟನ್ನು](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) ನೇರವಾಗಿ ರಚಿಸಲು ಬಳಸಲು ಶಿಫಾರಸು ಮಾಡಲಾಗಿದೆ （***ಗಮನಿಸಿ:*** Azure AI Agent Service ಪ್ರಸ್ತುತ ಸೀಮಿತ ಪ್ರದೇಶದಲ್ಲಿ ಹೊಂದಿಸಲಾಗಿದೆ. [ಈ ಲಿಂಕ್](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) ಅನ್ನು ಉಲ್ಲೇಖಿಸಲು ಶಿಫಾರಸು ಮಾಡಲಾಗಿದೆ).
#
# Agent ಗೆ SERPAPI ಗೆ ಪ್ರವೇಶ ಬೇಕಾಗುತ್ತದೆ. [ಈ ಲಿಂಕ್](https://serpapi.com/searches) ಅನ್ನು ಬಳಸಿಕೊಂಡು ನೋಂದಾಯಿಸಲು ಶಿಫಾರಸು ಮಾಡಲಾಗಿದೆ. ನೋಂದಾಯಿಸಿದ ನಂತರ, ನೀವು ವಿಶಿಷ್ಟ API KEY ಮತ್ತು ENDPOINT ಅನ್ನು ಪಡೆಯಬಹುದು.

# %% [markdown]
# # ಸೆಟಪ್
#
# ಈ ನೋಟ್ಬುಕ್ ಅನ್ನು ಚಲಾಯಿಸಲು, ನೀವು `pip install -r requirements.txt` ಅನ್ನು ರನ್ ಮಾಡಿ ಅಗತ್ಯವಾದ ಲೈಬ್ರರಿಗಳನ್ನು ಸ್ಥಾಪಿಸಿರುವುದನ್ನು ಖಚಿತಪಡಿಸಿಕೊಳ್ಳಬೇಕು.

# %%
from semantic_kernel import __version__

__version__

# %% [markdown]
# ನಿಮ್ಮ ಸೆಮಾಂಟಿಕ್ ಕರ್ಣ ಆವೃತ್ತಿ ಕನಿಷ್ಠ 1.27.2 ಇರಬೇಕು.

# %% [markdown]
# ನಿಮ್ಮ .env ಫೈಲ್ ಸೆಟ್ಟಿಂಗ್ ಮತ್ತು ಸಂಪತ್ತನ್ನು ಲೋಡ್ ಮಾಡಿ, ದಯವಿಟ್ಟು ನೀವು ನಿಮ್ಮ ಕೀಗಳು ಮತ್ತು ಸೆಟ್ಟಿಂಗ್ ಅನ್ನು ಸೇರಿಸಿದ್ದೀರಿ ಮತ್ತು ಸ್ಥಳೀಯ .env ಫೈಲ್ ಅನ್ನು ರಚಿಸಿದ್ದೀರಿ ಎಂದು ಖಚಿತಪಡಿಸಿಕೊಳ್ಳಿ.

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # ಆಜೂರ್‌ಗೆ ಲಾಗಿನ್ ಆಗಿ
#
# ಈಗ ನೀವು ಆಜೂರ್‌ಗೆ ಲಾಗಿನ್ ಆಗಬೇಕಾಗಿದೆ. ಟರ್ಮಿನಲ್ ತೆರೆಯಿ ಮತ್ತು ಕೆಳಗಿನ ಕಮಾಂಡ್ ಅನ್ನು ರನ್ ಮಾಡಿ:
#
# ```bash
# az login
# ```
#
# ಈ ಕಮಾಂಡ್ ನಿಮ್ಮನ್ನು ಆಜೂರ್ ಕ್ರೆಡೆನ್ಷಿಯಲ್ಸ್ ನಮೂದಿಸಲು ಪ್ರೇರೇಪಿಸುತ್ತದೆ, ಇದರಿಂದ ಆಜೂರ್ AI ಏಜೆಂಟ್ ಸೇವೆ ಸರಿಯಾಗಿ ಕಾರ್ಯನಿರ್ವಹಿಸಲು ಸಾಧ್ಯವಾಗುತ್ತದೆ.

# %% [markdown]
# # ವಿವರಣೆ:
# ಇದು SERP (ಸರ್ಚ್ ಎಂಜಿನ್ ರಿಸಲ್ಟ್ಸ್ ಪೇಜ್) API ಸೇವೆಯನ್ನು ಪ್ರವೇಶಿಸಲು API ಕೀ ಅನ್ನು ಸಂಗ್ರಹಿಸುವ ವ್ಯಾರಿಯಬಲ್. API ಕೀ ನಿಮ್ಮ ಖಾತೆಗೆ ಸಂಬಂಧಿಸಿದ ವಿನಂತಿಗಳನ್ನು ದೃಢೀಕರಿಸಲು ಬಳಸುವ ವಿಶಿಷ್ಟ ಗುರುತಿನ ಚಿಹ್ನೆ.
#
# ಉದ್ದೇಶ: ಈ ಸಾಲಿನ ಉದ್ದೇಶ API ಕೀ ಅನ್ನು ವ್ಯಾರಿಯಬಲ್‌ನಲ್ಲಿ ಸಂಗ್ರಹಿಸುವುದು, ಇದನ್ನು SERP API ಸೇವೆಗೆ ವಿನಂತಿಗಳನ್ನು ದೃಢೀಕರಿಸಲು ಬಳಸಬಹುದು. ಸೇವೆಯನ್ನು ಪ್ರವೇಶಿಸಲು ಮತ್ತು ಹುಡುಕಾಟಗಳನ್ನು ನಡೆಸಲು API ಕೀ ಅಗತ್ಯವಿದೆ.
# SERP API ಕೀ ಪಡೆಯುವ ವಿಧಾನ: SERP API ಕೀ ಪಡೆಯಲು, https://serpapi.com ನಲ್ಲಿ ಈ ಸಾಮಾನ್ಯ ಹಂತಗಳನ್ನು ಅನುಸರಿಸಿ (ನೀವು ಬಳಸುತ್ತಿರುವ ವಿಶೇಷ SERP API ಸೇವೆಯ ಪ್ರಕಾರ ಹಂತಗಳು ಬದಲಾಗಬಹುದು):
#
# SERP API ಸೇವೆಯನ್ನು ಆಯ್ಕೆಮಾಡಿ: SerpAPI, Google Custom Search JSON API ಮತ್ತು ಇತರವುಗಳಂತಹ ಹಲವಾರು SERP API ಸೇವೆಗಳು ಲಭ್ಯವಿವೆ. ನಿಮ್ಮ ಅಗತ್ಯಗಳಿಗೆ ಸೂಕ್ತವಾದ ಸೇವೆಯನ್ನು ಆಯ್ಕೆಮಾಡಿ.
#
# ಖಾತೆಗೆ ಸೈನ್ ಅಪ್ ಮಾಡಿ: ಆಯ್ಕೆಮಾಡಿದ SERP API ಸೇವೆಯ ವೆಬ್‌ಸೈಟ್‌ಗೆ ಹೋಗಿ ಮತ್ತು ಖಾತೆಗೆ ಸೈನ್ ಅಪ್ ಮಾಡಿ. ನೀವು ಕೆಲವು ಮೂಲಭೂತ ಮಾಹಿತಿಯನ್ನು ಒದಗಿಸಲು ಮತ್ತು ನಿಮ್ಮ ಇಮೇಲ್ ವಿಳಾಸವನ್ನು ದೃಢೀಕರಿಸಲು ಅಗತ್ಯವಿರಬಹುದು.
#
# API ಕೀ ರಚಿಸಿ: ಸೈನ್ ಅಪ್ ಮಾಡಿದ ನಂತರ, ನಿಮ್ಮ ಖಾತೆಗೆ ಲಾಗಿನ್ ಮಾಡಿ ಮತ್ತು API ವಿಭಾಗ ಅಥವಾ ಡ್ಯಾಶ್‌ಬೋರ್ಡ್‌ಗೆ ಹೋಗಿ. ಹೊಸ API ಕೀ ರಚಿಸಲು ಅಥವಾ ಉತ್ಪಾದಿಸಲು ಆಯ್ಕೆಯನ್ನು ಹುಡುಕಿ.
# API ಕೀ ಅನ್ನು ನಿಮ್ಮ .env ಫೈಲ್‌ಗೆ ನಕಲಿಸಿ.

# %%
SERP_API_KEY='SERPAPI_SEARCH_API_KEY'

# %% [markdown]
# # ವಿವರಣೆ:
# BASE_URL: ಇದು SERP API ಎಂಡ್ಪಾಯಿಂಟ್‌ಗಾಗಿ ಮೂಲ URL ಅನ್ನು ಸಂಗ್ರಹಿಸುವ ಚರಾಂಶವಾಗಿದೆ. BASE_URL ಎಂಬ ಚರಾಂಶದ ಹೆಸರು API ವಿನಂತಿಗಳನ್ನು ಮಾಡಲು ಈ URL ಪ್ರಾರಂಭ ಬಿಂದು ಎಂದು ಸೂಚಿಸಲು ಬಳಸುವ ಸಂಪ್ರದಾಯವಾಗಿದೆ.
# 'https://serpapi.com/search':
#
# ಇದು BASE_URL ಚರಾಂಶಕ್ಕೆ ನಿಯೋಜಿಸಲಾದ ನಿಜವಾದ URL ಸ್ಟ್ರಿಂಗ್ ಆಗಿದೆ. ಇದು SERP API ಬಳಸಿ ಹುಡುಕಾಟ ಪ್ರಶ್ನೆಗಳನ್ನು ನಡೆಸುವ ಎಂಡ್ಪಾಯಿಂಟ್ ಅನ್ನು ಪ್ರತಿನಿಧಿಸುತ್ತದೆ.
#
# # ಉದ್ದೇಶ:
# ಈ ಸಾಲಿನ ಉದ್ದೇಶ SERP APIಗೆ ಮೂಲ URL ಅನ್ನು ಹೊಂದಿರುವ ಸ್ಥಿರಾಂಶವನ್ನು ವ್ಯಾಖ್ಯಾನಿಸುವುದು. API ವಿನಂತಿಗಳನ್ನು ರಚಿಸಲು ಮತ್ತು ಹುಡುಕಾಟ ಕಾರ್ಯಾಚರಣೆಗಳನ್ನು ನಡೆಸಲು ಈ URL ಪ್ರಾರಂಭ ಬಿಂದು ಆಗಿರುತ್ತದೆ.
#
# # ಬಳಕೆ:
# ಮೂಲ URL ಅನ್ನು ಚರಾಂಶದಲ್ಲಿ ವ್ಯಾಖ್ಯಾನಿಸುವ ಮೂಲಕ, SERP APIಗೆ ವಿನಂತಿಗಳನ್ನು ಮಾಡಲು ನಿಮ್ಮ ಕೋಡ್‌ನಲ್ಲಿ ಇದನ್ನು ಸುಲಭವಾಗಿ ಪುನಃ ಬಳಸಬಹುದು. ಇದು ನಿಮ್ಮ ಕೋಡ್ ಅನ್ನು ಹೆಚ್ಚು ನಿರ್ವಹಣೀಯವಾಗಿಸುತ್ತದೆ ಮತ್ತು URL ಅನ್ನು ಹಲವಾರು ಸ್ಥಳಗಳಲ್ಲಿ ಹಾರ್ಡ್‌ಕೋಡ್ ಮಾಡುವ ದೋಷಗಳ ಅಪಾಯವನ್ನು ಕಡಿಮೆ ಮಾಡುತ್ತದೆ. ಪ್ರಸ್ತುತ ಉದಾಹರಣೆ https://serpapi.com/search?engine=bing ಆಗಿದ್ದು Bing ಹುಡುಕಾಟ API ಅನ್ನು ಬಳಸುತ್ತಿದೆ. ವಿಭಿನ್ನ API ಅನ್ನು https://Serpapi.com ನಲ್ಲಿ ಆಯ್ಕೆ ಮಾಡಬಹುದು.

# %%
BASE_URL = 'https://serpapi.com/search?engine=bing'

# %% [markdown]
# # ವಿವರಣೆ:
#
# ಇದು ನಿಮ್ಮ ಪ್ಲಗಿನ್ ಕೋಡ್ ಇರುವ ಸ್ಥಳ.
#
# ವರ್ಗದ ವ್ಯಾಖ್ಯಾನ: `class BookingPlugin`: BookingPlugin ಎಂಬ ಹೆಸರಿನ ವರ್ಗವನ್ನು ವ್ಯಾಖ್ಯಾನಿಸುತ್ತದೆ, ಇದು ಹೋಟೆಲ್ ಮತ್ತು ವಿಮಾನಗಳನ್ನು ಬುಕ್ ಮಾಡಲು ವಿಧಾನಗಳನ್ನು ಹೊಂದಿದೆ.
#
# ಹೋಟೆಲ್ ಬುಕ್ಕಿಂಗ್ ವಿಧಾನ:
#
# - `@kernel_function(description="booking hotel")`: ಹೋಟೆಲ್ ಬುಕ್ಕಿಂಗ್ kernel function ಎಂದು ಕಾರ್ಯವನ್ನು ವಿವರಿಸುವ ಡೆಕೊರೇಟರ್.
# - `def booking_hotel(self, query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-out Time"]) -> Annotated[str, "Return the result of booking hotel information"]:`: ವ್ಯಾಖ್ಯಾನಿತ ಪ್ಯಾರಾಮೀಟರ್‌ಗಳು ಮತ್ತು ರಿಟರ್ನ್ ಪ್ರಕಾರದೊಂದಿಗೆ ಹೋಟೆಲ್ ಬುಕ್ ಮಾಡಲು ವಿಧಾನವನ್ನು ವ್ಯಾಖ್ಯಾನಿಸುತ್ತದೆ.
#
# ಈ ವಿಧಾನವು ಹೋಟೆಲ್ ಬುಕ್ಕಿಂಗ್ ವಿನಂತಿಗಾಗಿ ಪ್ಯಾರಾಮೀಟರ್‌ಗಳ ಡಿಕ್ಷನರಿ ರಚಿಸುತ್ತದೆ ಮತ್ತು SERP API ಗೆ GET ವಿನಂತಿಯನ್ನು ಕಳುಹಿಸುತ್ತದೆ. ಇದು ಪ್ರತಿಕ್ರಿಯೆಯ ಸ್ಥಿತಿಯನ್ನು ಪರಿಶೀಲಿಸುತ್ತದೆ ಮತ್ತು ಯಶಸ್ವಿಯಾದರೆ ಹೋಟೆಲ್ ಗುಣಲಕ್ಷಣಗಳನ್ನು ಹಿಂತಿರುಗಿಸುತ್ತದೆ, ಅಥವಾ ವಿನಂತಿ ವಿಫಲವಾದರೆ None ಅನ್ನು ಹಿಂತಿರುಗಿಸುತ್ತದೆ.
#
# ವಿಮಾನ ಬುಕ್ಕಿಂಗ್ ವಿಧಾನ:
#
# - `@kernel_function(description="booking flight")`: ವಿಮಾನ ಬುಕ್ಕಿಂಗ್ kernel function ಎಂದು ಕಾರ್ಯವನ್ನು ವಿವರಿಸುವ ಡೆಕೊರೇಟರ್.
# - `def booking_flight(self, origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"]) -> Annotated[str, "Return the result of booking flight information"]:`: ವ್ಯಾಖ್ಯಾನಿತ ಪ್ಯಾರಾಮೀಟರ್‌ಗಳು ಮತ್ತು ರಿಟರ್ನ್ ಪ್ರಕಾರದೊಂದಿಗೆ ವಿಮಾನ ಬುಕ್ ಮಾಡಲು ವಿಧಾನವನ್ನು ವ್ಯಾಖ್ಯಾನಿಸುತ್ತದೆ.
#
# ಈ ವಿಧಾನವು ಹೊರಹೋಗುವ ಮತ್ತು ಹಿಂತಿರುಗುವ ವಿಮಾನ ವಿನಂತಿಗಳ ಪ್ಯಾರಾಮೀಟರ್‌ಗಳ ಡಿಕ್ಷನರಿಗಳನ್ನು ರಚಿಸುತ್ತದೆ ಮತ್ತು SERP API ಗೆ GET ವಿನಂತಿಗಳನ್ನು ಕಳುಹಿಸುತ್ತದೆ. ಇದು ಪ್ರತಿಕ್ರಿಯೆಯ ಸ್ಥಿತಿಯನ್ನು ಪರಿಶೀಲಿಸುತ್ತದೆ ಮತ್ತು ಯಶಸ್ವಿಯಾದರೆ ವಿಮಾನ ಮಾಹಿತಿಯನ್ನು ಫಲಿತಾಂಶ ಸ್ಟ್ರಿಂಗ್‌ಗೆ ಸೇರಿಸುತ್ತದೆ, ಅಥವಾ ವಿನಂತಿ ವಿಫಲವಾದರೆ ದೋಷ ಸಂದೇಶವನ್ನು ಮುದ್ರಿಸುತ್ತದೆ. ಈ ವಿಧಾನವು ವಿಮಾನ ಮಾಹಿತಿಯನ್ನು ಹೊಂದಿರುವ ಫಲಿತಾಂಶ ಸ್ಟ್ರಿಂಗ್ ಅನ್ನು ಹಿಂತಿರುಗಿಸುತ್ತದೆ.

# %%
import requests

from typing import Annotated

from semantic_kernel.functions import kernel_function

# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""

    @kernel_function(description="booking hotel")
    def booking_hotel(
        self, 
        query: Annotated[str, "The name of the city"], 
        check_in_date: Annotated[str, "Hotel Check-in Time"], 
        check_out_date: Annotated[str, "Hotel Check-out Time"],
    ) -> Annotated[str, "Return the result of booking hotel information"]:
        """
        Function to book a hotel.
        Parameters:
        - query: The name of the city
        - check_in_date: Hotel Check-in Time
        - check_out_date: Hotel Check-out Time
        Returns:
        - The result of booking hotel information
        """

        # Define the parameters for the hotel booking request
        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "1",
            "currency": "GBP",
            "gl": "uk",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request to the SERP API
        response = requests.get(BASE_URL, params=params)

        # Check if the request was successful
        if response.status_code == 200:
            # Parse the response content as JSON
            response = response.json()
            # Return the properties from the response
            return response["properties"]
        else:
            # Return None if the request failed
            return None

    @kernel_function(description="booking flight")
    def booking_flight(
        self, 
        origin: Annotated[str, "The name of Departure"], 
        destination: Annotated[str, "The name of Destination"], 
        outbound_date: Annotated[str, "The date of outbound"], 
        return_date: Annotated[str, "The date of Return_date"],
    ) -> Annotated[str, "Return the result of booking flight information"]:
        """
        Function to book a flight.
        Parameters:
        - origin: The name of Departure
        - destination: The name of Destination
        - outbound_date: The date of outbound
        - return_date: The date of Return_date
        - airline: The preferred airline carrier
        - hotel_brand: The preferred hotel brand
        Returns:
        - The result of booking flight information
        """
        
        # Define the parameters for the outbound flight request
        go_params = {
            "engine": "google_flights",
            "departure_id": "destination",
            "arrival_id": "origin",
            "outbound_date": "outbound_date",
            "return_date": "return_date",
            "currency": "GBP",
            "hl": "en",
            "airline": "airline",
            "hotel_brand": "hotel_brand",
            "api_key": "SERP_API_KEY"
        }
 
        print(go_params)

        # Send the GET request for the outbound flight
        go_response = requests.get(BASE_URL, params=go_params)

        # Initialize the result string
        result = ''

        # Check if the outbound flight request was successful
        if go_response.status_code == 200:
            # Parse the response content as JSON
            response = go_response.json()
            # Append the outbound flight information to the result
            result += "# outbound \n " + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Define the parameters for the return flight request
        back_params = {
            #"engine": "google_flights",
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": outbound_date,
            "return_date": return_date,
            "currency": "GBP",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request for the return flight
        back_response = requests.get(BASE_URL, params=back_params)

        # Check if the return flight request was successful
        if back_response.status_code == 200:
            # Parse the response content as JSON
            response = back_response.json()
            # Append the return flight information to the result
            result += "\n # return \n" + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Print the result
        print(result)

        # Return the result
        return result

# %% [markdown]
# # ವಿವರಣೆ:
# ಆಮದು ಹೇಳಿಕೆಗಳು: ಆಜೂರ್ ಕ್ರೆಡೆನ್ಷಿಯಲ್ಸ್, AI ಏಜೆಂಟ್, ಚಾಟ್ ಸಂದೇಶ ವಿಷಯ, ಲೇಖಕನ ಪಾತ್ರ, ಮತ್ತು ಕೆರ್ನಲ್ ಫಂಕ್ಷನ್ ಡೆಕೊರೇಟರ್‌ಗಾಗಿ ಅಗತ್ಯವಾದ ಮಾಸುಲುಗಳನ್ನು ಆಮದು ಮಾಡಿಕೊಳ್ಳಿ.
#
# ಅಸಿಂಕ್ರೋನಸ್ ಕಾಂಟೆಕ್ಸ್ಟ್ ಮ್ಯಾನೇಜರ್: `async with (DefaultAzureCredential() as creds, AzureAIAgent.create_client(credential=creds, conn_str="...") as client,)`: ಇದು ಆಜೂರ್ ಕ್ರೆಡೆನ್ಷಿಯಲ್ಸ್ ಅನ್ನು ನಿರ್ವಹಿಸಲು ಮತ್ತು AI ಏಜೆಂಟ್ ಕ್ಲೈಂಟ್ ಅನ್ನು ರಚಿಸಲು ಅಸಿಂಕ್ರೋನಸ್ ಕಾಂಟೆಕ್ಸ್ಟ್ ಮ್ಯಾನೇಜರ್ ಅನ್ನು ಹೊಂದಿಸುತ್ತದೆ.
#
# ಏಜೆಂಟ್ ಹೆಸರು ಮತ್ತು ಸೂಚನೆಗಳು:
# - `AGENT_NAME = "BookingAgent"`: ಏಜೆಂಟ್‌ನ ಹೆಸರನ್ನು ವ್ಯಾಖ್ಯಾನಿಸುತ್ತದೆ.
# - `AGENT_INSTRUCTIONS = """..."""`: ಬುಕಿಂಗ್ ವಿನಂತಿಗಳನ್ನು ಹೇಗೆ ನಿರ್ವಹಿಸಬೇಕು ಎಂಬುದರ ಕುರಿತು ಏಜೆಂಟ್‌ಗೆ ವಿವರವಾದ ಸೂಚನೆಗಳನ್ನು ಒದಗಿಸುತ್ತದೆ.
#
# ಏಜೆಂಟ್ ವ್ಯಾಖ್ಯಾನವನ್ನು ರಚಿಸಿ: `agent_definition = await client.agents.create_agent(...)`: ನಿರ್ದಿಷ್ಟ ಮಾದರಿ, ಹೆಸರು, ಮತ್ತು ಸೂಚನೆಗಳೊಂದಿಗೆ ಏಜೆಂಟ್ ವ್ಯಾಖ್ಯಾನವನ್ನು ರಚಿಸುತ್ತದೆ.
#
# ಆಜೂರ್ AI ಏಜೆಂಟ್ ರಚನೆ: `agent = AzureAIAgent(...)`: ಕ್ಲೈಂಟ್, ಏಜೆಂಟ್ ವ್ಯಾಖ್ಯಾನ, ಮತ್ತು ವ್ಯಾಖ್ಯಾನಿತ ಪ್ಲಗಿನ್ ಬಳಸಿ ಆಜೂರ್ AI ಏಜೆಂಟ್ ಅನ್ನು ರಚಿಸುತ್ತದೆ.
#
# ಥ್ರೆಡ್ ರಚನೆ: `thread: AzureAIAgentThread | None = None`: ಏಜೆಂಟ್‌ಗಾಗಿ ಒಂದು ಥ್ರೆಡ್ ರಚಿಸಿ. ಮೊದಲು ಥ್ರೆಡ್ ರಚಿಸುವ ಅಗತ್ಯವಿಲ್ಲ - `None` ಮೌಲ್ಯವನ್ನು ಒದಗಿಸಿದರೆ, ಮೊದಲ ಕರೆಯ ಸಮಯದಲ್ಲಿ ಹೊಸ ಥ್ರೆಡ್ ರಚಿಸಲಾಗುತ್ತದೆ ಮತ್ತು ಪ್ರತಿಕ್ರಿಯೆಯ ಭಾಗವಾಗಿ ಮರಳಿಸಲಾಗುತ್ತದೆ.
#
# ಬಳಕೆದಾರರ ಇನ್‌ಪುಟ್‌ಗಳು: `user_inputs = ["..."]`: ಏಜೆಂಟ್ ಪ್ರಕ್ರಿಯೆಗೊಳಿಸಲು ಬಳಕೆದಾರರ ಇನ್‌ಪುಟ್‌ಗಳ ಪಟ್ಟಿಯನ್ನು ವ್ಯಾಖ್ಯಾನಿಸುತ್ತದೆ.
#
# ಕೊನೆಗೆ ಬ್ಲಾಕ್‌ನಲ್ಲಿ, ಸಂಪತ್ತನ್ನು ಸ್ವಚ್ಛಗೊಳಿಸಲು ಥ್ರೆಡ್ ಮತ್ತು ಏಜೆಂಟ್ ಅನ್ನು ಅಳಿಸಿ.

# %% [markdown]
# # ಪ್ರಾಮಾಣೀಕರಣ
#
# `DefaultAzureCredential` ವರ್ಗವು Python ಗೆ ಹೊಂದಿರುವ Azure SDK ಭಾಗವಾಗಿದೆ. ಇದು Azure ಸೇವೆಗಳೊಂದಿಗೆ ಪ್ರಾಮಾಣೀಕರಣ ಮಾಡಲು ಡೀಫಾಲ್ಟ್ ವಿಧಾನವನ್ನು ಒದಗಿಸುತ್ತದೆ. ಇದು ನಿರ್ದಿಷ್ಟ ಕ್ರಮದಲ್ಲಿ ಅನೇಕ ವಿಧಾನಗಳನ್ನು ಬಳಸಿಕೊಂಡು ಪ್ರಾಮಾಣೀಕರಣ ಮಾಡಲು ಪ್ರಯತ್ನಿಸುತ್ತದೆ, ಉದಾಹರಣೆಗೆ ಪರಿಸರ ವ್ಯತ್ಯಾಸಗಳು, ನಿರ್ವಹಿತ ಗುರುತಿನ ಚಿಹ್ನೆ, ಮತ್ತು Azure CLI ಕ್ರೆಡೆನ್ಷಿಯಲ್ಸ್.
#
# ಅಸಿಂಕ್ರೋನಸ್ ಕಾರ್ಯಾಚರಣೆಗಳು: aio ಮೋಡ್ಯೂಲ್ DefaultAzureCredential ವರ್ಗವು ಅಸಿಂಕ್ರೋನಸ್ ಕಾರ್ಯಾಚರಣೆಗಳನ್ನು ಬೆಂಬಲಿಸುತ್ತದೆ ಎಂಬುದನ್ನು ಸೂಚಿಸುತ್ತದೆ. ಇದು ನೀವು asyncio ನೊಂದಿಗೆ ಬಳಸಿಕೊಂಡು ಅಡ್ಡಿ ರಹಿತ ಪ್ರಾಮಾಣೀಕರಣ ವಿನಂತಿಗಳನ್ನು ನಿರ್ವಹಿಸಲು ಸಾಧ್ಯವಾಗುತ್ತದೆ.

# %%
# Import necessary modules
from azure.identity.aio import DefaultAzureCredential
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings, AzureAIAgentThread

ai_agent_settings = AzureAIAgentSettings.create()

# Azure AI Setting
async with (
     DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):    
    
    # Define the agent's name and instructions
    AGENT_NAME = "BookingAgent"
    AGENT_INSTRUCTIONS = """
    You are a booking agent, help me to book flights or hotels.

    Thought: Understand the user's intention and confirm whether to use the reservation system to complete the task.

    Action:
    - If booking a flight, convert the departure name and destination name into airport codes.
    - If booking a hotel or flight, use the corresponding API to call. Ensure that the necessary parameters are available. If any parameters are missing, use default values or assumptions to proceed.
    - If it is not a hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
    - For flight bookings, separate the outbound and return contents and list them in the order of Departure_airport Name | Airline | Flight Number | Departure Time | Arrival_airport Name | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
    - For hotel bookings, list them in the order of Properties Name | Properties description | check_in_time | check_out_time | prices | nearby_places | hotel_class | gps_coordinates.
    """

    # Create agent definition with the specified model, name, and instructions
    agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=AGENT_NAME,
        instructions=AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent using the client and agent definition
    agent = AzureAIAgent(
        client=client,
        definition=agent_definition,
        plugins=[BookingPlugin()]
    )

    # Create a new thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: AzureAIAgentThread | None = None

    # This is your prompt for the activity or task you want to complete 
    # Define user inputs for the agent to process we have provided some example prompts to test and validate 
    user_inputs = [
        # "Can you tell me the round-trip air ticket from  London to New York JFK aiport, the departure time is February 17, 2025, and the return time is February 23, 2025"
        # "Book a hotel in New York from Feb 20,2025 to Feb 24,2025"
        "Help me book flight tickets and hotel for the following trip London Heathrow LHR Feb 20th 2025 to New York JFK returning Feb 27th 2025 flying economy with British Airways only. I want a stay in a Hilton hotel in New York please provide costs for the flight and hotel"
        # "I have a business trip from London LHR to New York JFK on Feb 20th 2025 to Feb 27th 2025, can you help me to book a hotel and flight tickets"
    ]

    try:
        # Process each user input
        for user_input in user_inputs:
            print(f"# User: '{user_input}'")
            # Get the agent's response for the specified thread
            response = await agent.get_response(
                messages=user_input,
                thread=thread,
            )
            thread = response.thread
            # Print the agent's response
            print(f"{response.name}: '{response.content}'")
    finally:
        # Clean up by deleting the thread and agent
        await thread.delete() if thread else None
        await client.agents.delete_agent(agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ಅಸಮೀಕ್ಷೆ**:
# ಈ ದಾಖಲೆ AI ಅನುವಾದ ಸೇವೆ [Co-op Translator](https://github.com/Azure/co-op-translator) ಬಳಸಿ ಅನುವಾದಿಸಲಾಗಿದೆ. ನಾವು ಖಚಿತತೆಯಿಗಾಗಿ ಪ್ರಯತ್ನಿಸುತ್ತಿದ್ದರೂ, ದಯವಿಟ್ಟು ಗಮನಿಸಿ, ಸ್ವಯಂಚಾಲಿತ ಅನುವಾದಗಳಲ್ಲಿ ದೋಷಗಳು ಅಥವಾ ಅಸಮರ್ಪಕತೆಗಳು ಇರಬಹುದು. ಮೂಲ ಭಾಷೆಯಲ್ಲಿರುವ ಮೂಲ ದಾಖಲೆ ಪ್ರಾಮಾಣಿಕ ಮೂಲವೆಂದು ಪರಿಗಣಿಸಬೇಕು. ಪ್ರಮುಖ ಮಾಹಿತಿಗಾಗಿ, ವೃತ್ತಿಪರ ಮಾನವ ಅನುವಾದವನ್ನು ಶಿಫಾರಸು ಮಾಡಲಾಗುತ್ತದೆ. ಈ ಅನುವಾದದ ಬಳಕೆಯಿಂದ ಉಂಟಾಗುವ ಯಾವುದೇ ತಪ್ಪುಅರ್ಥಗಳು ಅಥವಾ ತಪ್ಪುಅರ್ಥೈಸುವಿಕೆಗೆ ನಾವು ಹೊಣೆಗಾರರಾಗುವುದಿಲ್ಲ.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
