# %% [markdown]
# # 🎯 Planavimas ir dizaino šablonai su GitHub modeliais (Python)
#
# ## 📋 Mokymosi tikslai
#
# Šiame užrašų knygelėje pateikiami pažangūs planavimo ir dizaino šablonai, skirti kurti intelektualius agentus naudojant „Microsoft Agent Framework“ su GitHub modeliais. Sužinosite, kaip kurti agentus, kurie gali suskaidyti sudėtingas problemas, planuoti daugiapakopius sprendimus ir koordinuoti sudėtingus darbo procesus.
#
# **Pažangūs gebėjimai, kuriuos įvaldysite:**
# - 🧠 **Strateginis planavimas**: Sudėtingų užduočių skaidymas į valdomas dalis
# - 🗺️ **Daugiapakopis mąstymas**: Nuoseklaus ir lygiagretaus užduočių vykdymo šablonai
# - 🎯 **Tikslų orientuotas dizainas**: Agentai, dirbantys siekdami konkrečių tikslų
# - 🔄 **Adaptacinis planavimas**: Dinaminis strategijos koregavimas pagal kontekstą
#
# ## 🎯 Planavimo architektūros koncepcijos
#
# ### Pagrindiniai planavimo komponentai
# - **Užduočių skaidymas**: Sudėtingų problemų skaidymas į mažesnes, valdomas dalis
# - **Vykdymo planavimas**: Optimalios tvarkos ir priklausomybių nustatymas subtikslams
# - **Išteklių valdymas**: Efektyvus įrankių ir galimybių paskirstymas
# - **Progreso stebėjimas**: Užduočių užbaigimo sekimas ir prisitaikymas prie pokyčių
#
# ### Dizaino šablonai planavimui
# - **Strategijos šablonas**: Skirtingi planavimo metodai įvairioms situacijoms
# - **Atsakomybės grandinė**: Nuoseklus apdorojimas su atsarginiais sprendimais
# - **Komandos šablonas**: Užduočių vykdymo kapsuliavimas su atšaukimo/atstatymo galimybėmis
# - **Stebėtojo šablonas**: Progreso stebėjimas ir įvykiais pagrįsti atnaujinimai
#
# ## 🏗️ Techninė architektūra
#
# ### Planavimo sistemos komponentai
# - **Microsoft Agent Framework**: Python įgyvendinimas su pažangiu planavimo palaikymu
# - **GitHub modelių integracija**: Aukštos kokybės mąstymas ir sprendimų priėmimas
# - **Užduočių orkestracija**: Koordinuotas sudėtingų darbo procesų vykdymas
# - **Būsenos valdymas**: Nuolatinis planavimo progreso ir rezultatų stebėjimas
#
# ### Planavimo proceso eiga
# ```python
# Complex Goal → Task Analysis → Subtask Decomposition → Execution Planning
#                 ↓                    ↓                    ↓
#          Priority Assessment → Resource Allocation → Sequential Execution
#                 ↓                    ↓                    ↓
#          Progress Monitoring → Adaptive Replanning → Goal Achievement
# ```
#
# ## 🧠 Planavimo metodologijos
#
# ### 1. **Hierarchinis užduočių planavimas**
# - Kompleksinių tikslų skaidymas iš viršaus į apačią
# - Įdėtinės tikslų struktūros su priklausomybėmis
# - Rekursinis subtikslų planavimas
# - Efektyvus išteklių paskirstymas tarp lygių
#
# ### 2. **Nuoseklus planavimas**
# - Žingsnis po žingsnio užduočių vykdymas su aiškiomis priklausomybėmis
# - Klaidų tvarkymas ir atkūrimas kiekviename etape
# - Progreso kontrolės punktai ir validacija
# - Atšaukimo galimybės nepavykus žingsniui
#
# ### 3. **Lygiagretus planavimas**
# - Nepriklausomų užduočių vykdymas vienu metu
# - Išteklių sinchronizavimas ir konfliktų sprendimas
# - Našumo optimizavimas per lygiagretumą
# - Koordinuotas užbaigimas ir rezultatų agregavimas
#
# ## ⚙️ Reikalavimai ir nustatymai
#
# **Reikalingos priklausomybės:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Aplinkos konfigūracija (.env failas):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Planavimo dizaino šablonai
#
# ### Tikslų orientuotas planavimas
# - **SMART tikslai**: Konkretūs, išmatuojami, pasiekiami, aktualūs, laiko riboti tikslai
# - **Etapų stebėjimas**: Progreso matavimas ir kontrolės punktai
# - **Sėkmės kriterijai**: Aiškūs užduočių užbaigimo apibrėžimai
# - **Adaptacinės strategijos**: Dinaminis planavimo koregavimas pagal grįžtamąjį ryšį
#
# ### Išteklių sąmoningas planavimas
# - **Galimybių vertinimas**: Supratimas apie turimus įrankius ir jų apribojimus
# - **Krovos balansavimas**: Optimalus užduočių paskirstymas tarp turimų išteklių
# - **Apribojimų valdymas**: Darbas pagal sistemos ir API apribojimus
# - **Našumo optimizavimas**: Efektyvumo didinimas ir vėlavimo mažinimas
#
# ### Atsparus klaidoms planavimas
# - **Klaidų aptikimas**: Ankstyvas planavimo ar vykdymo problemų nustatymas
# - **Atkūrimo strategijos**: Automatiniai atsarginiai sprendimai ir alternatyvūs metodai
# - **Būsenos išsaugojimas**: Progreso išlaikymas klaidų atkūrimo metu
# - **Grakštus degradavimas**: Dalinė sėkmė, kai visiškas užbaigimas neįmanomas
#
# ## 🚀 Pažangios planavimo funkcijos
#
# - **Meta-planavimas**: Agentai, kurie planuoja, kaip planuoti
# - **Bendradarbiavimo planavimas**: Daugelio agentų koordinacija sudėtingiems projektams
# - **Mokymasis iš patirties**: Planavimo strategijų tobulinimas laikui bėgant
# - **Realaus laiko adaptacija**: Dinaminis persiplanavimas pagal besikeičiančias sąlygas
#
# ## 📊 Naudojimo atvejai ir taikymas
#
# ### Verslo procesų automatizavimas
# - Projektų valdymas ir užduočių planavimas
# - Darbo procesų optimizavimas ir išteklių paskirstymas
# - Strateginis planavimas ir sprendimų palaikymas
# - Procesų tobulinimas ir automatizavimas
#
# ### Tyrimai ir analizė
# - Literatūros apžvalga ir sintezė
# - Duomenų analizės proceso planavimas
# - Eksperimentų dizainas ir vykdymas
# - Ataskaitų generavimas ir formatavimas
#
# ### Kūrybiniai projektai
# - Turinio kūrimo darbo procesai
# - Daugiaterpių projektų koordinavimas
# - Kampanijų planavimas ir vykdymas
# - Renginių organizavimas ir valdymas
#
# Pasiruošę kurti intelektualius planavimo agentus, galinčius spręsti sudėtingus, daugiapakopius iššūkius? Sukurkime pažangias problemų sprendimo galimybes! 🧠✨

# %%
! pip install agent-framework-core -U

# %%
# 📦 Import Standard Libraries
# os: For environment variable access
# dotenv: For loading environment variables from .env file
import os

from dotenv import load_dotenv

# %%
# 📝 Import Data Modeling Libraries
# Pydantic: For data validation and structured outputs
# BaseModel: Base class for creating data models
# Field: For adding metadata and validation to model fields
# List: Type hint for list collections
from pydantic import BaseModel, Field
from typing import List

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatMessage: For creating structured chat messages
# Role: Enum for message roles (user, assistant, system)
# ChatOptions: Configuration options for chat interactions
# OpenAIChatClient: Client for OpenAI-compatible APIs (GitHub Models)
from agent_framework import ChatMessage, Role, ChatOptions
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# Load configuration from .env file
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎯 Agent Configuration
# Define the agent's name and role

AGENT_NAME = "TravelAgent"

# 📋 System Instructions for Planning Agent
# This agent acts as a coordinator that decides which specialized agents to use
AGENT_INSTRUCTIONS = """You are a planner agent.
    Your job is to decide which agents to run based on the user's request.
    Below are the available agents specialized in different tasks:
    - FlightBooking: For booking flights and providing flight information
    - HotelBooking: For booking hotels and providing hotel information
    - CarRental: For booking cars and providing car rental information
    - ActivitiesBooking: For booking activities and providing activity information
"""

# %%
class SubTask(BaseModel):
    assigned_agent: str = Field(
        description="The specific agent assigned to handle this subtask")
    task_details: str = Field(
        description="Detailed description of what needs to be done for this subtask")


class TravelPlan(BaseModel):
    main_task: str = Field(
        description="The overall travel request from the user")
    subtasks: List[SubTask] = Field(
        description="List of subtasks broken down from the main task, each assigned to a specialized agent")

# %%
options = ChatOptions(response_format=TravelPlan)

# %%
client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
agent =  client.create_agent(name= AGENT_NAME , instructions=AGENT_INSTRUCTIONS)

# %%
messages = [
        ChatMessage(role=Role.USER, text="Create a travel plan for a family of 4, with 2 kids, from Singapore to Melbourne")
    ]

# %%
response = await agent.run(messages,response_format=TravelPlan)

# %%
response.messages[0].text
# Out:
# '{"main_task":"Plan a family trip from Singapore to Melbourne for 4 people, including 2 kids.","subtasks":[{"assigned_agent":"FlightBooking","task_details":"Book one round-trip flight from Singapore to Melbourne for a family of 4, considering family-friendly options."},{"assigned_agent":"HotelBooking","task_details":"Find and book a family-friendly hotel in Melbourne that can accommodate 4 people, including 2 kids."},{"assigned_agent":"CarRental","task_details":"Arrange a car rental in Melbourne for the family to facilitate travel around the city."},{"assigned_agent":"ActivitiesBooking","task_details":"Provide a list of kid-friendly activities and attractions in Melbourne for the family to enjoy."}]}'

# %% [markdown]
# ---
#
# **Atsakomybės atsisakymas**:
# Šis dokumentas buvo išverstas naudojant AI vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba turėtų būti laikomas autoritetingu šaltiniu. Dėl svarbios informacijos rekomenduojama profesionali žmogaus vertimo paslauga. Mes neprisiimame atsakomybės už nesusipratimus ar neteisingus aiškinimus, kylančius dėl šio vertimo naudojimo.
