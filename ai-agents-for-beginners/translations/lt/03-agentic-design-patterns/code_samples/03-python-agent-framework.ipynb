# %% [markdown]
# # 🎨 Agentinio dizaino šablonai su GitHub modeliais (Python)
#
# ## 📋 Mokymosi tikslai
#
# Šiame užrašų knygelėje pateikiami pagrindiniai dizaino šablonai, skirti kurti intelektualius agentus naudojant „Microsoft Agent Framework“ su GitHub modelių integracija. Sužinosite patikrintus šablonus ir architektūrinius metodus, kurie padaro agentus patikimesnius, lengviau prižiūrimus ir efektyvesnius.
#
# **Pagrindiniai aptariami dizaino šablonai:**
# - 🏗️ **Agentų gamyklos šablonas**: Standartizuotas agentų kūrimas ir konfigūravimas
# - 🔧 **Įrankių registracijos šablonas**: Organizacinis požiūris į agento galimybių valdymą
# - 🧵 **Pokalbių valdymas**: Efektyvūs daugiapakopių sąveikų šablonai
# - 🔄 **Atsakymų apdorojimas**: Geriausia praktika, kaip tvarkyti agento išvestis
#
# ## 🎯 Pagrindinės architektūrinės sąvokos
#
# ### Dizaino principai
# - **Atsakomybės atskyrimas**: Aiškios ribos tarp agento logikos, įrankių ir konfigūracijos
# - **Komponuojamumas**: Sudėtingų agentų kūrimas iš pakartotinai naudojamų komponentų
# - **Išplečiamumas**: Šablonai, leidžiantys lengvai pridėti naujas galimybes
# - **Testuojamumas**: Dizainas, leidžiantis lengvai atlikti vienetinius testus ir patikrą
#
# ### GitHub modelių integracija
# - **API suderinamumas**: Naudojimasis OpenAI suderinamais galiniais taškais
# - **Modelio pasirinkimas**: Tinkamų modelių parinkimas skirtingiems naudojimo atvejams
# - **Kainų ribojimas**: API apribojimų valdymas
# - **Klaidų atkūrimas**: Patikimas klaidų tvarkymas ir pakartojimo šablonai
#
# ## 🔧 Techninė architektūra
#
# ### Pagrindiniai komponentai
# - **Microsoft Agent Framework**: Python įgyvendinimas su GitHub modelių palaikymu
# - **GitHub Models API**: Prieiga prie pažangiausių kalbos modelių
# - **OpenAI klientų šablonas**: Standartizuoti API sąveikos šablonai
# - **Aplinkos konfigūracija**: Saugus ir lankstus konfigūracijos valdymas
#
# ### Dizaino šablonų privalumai
# - **Prižiūrimumas**: Aiški kodo organizacija ir struktūra
# - **Mastelio keičiamumas**: Šablonai, kurie auga kartu su jūsų programos poreikiais
# - **Patikimumas**: Patikrinti metodai, kurie tvarko kraštutinius atvejus
# - **Našumas**: Efektyvus išteklių naudojimas ir API naudojimas
#
# ## ⚙️ Reikalavimai ir paruošimas
#
# **Reikalingos priklausomybės:**
# ```bash
#
# pip install agent-framework-core  -U
#
# ```
#
# **Aplinkos konfigūracija (.env failas):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **GitHub modelių prieiga:**
# - GitHub paskyra su modelių prieiga
# - Asmeninis prieigos raktas su tinkamais leidimais
# - Kainų ribų ir naudojimo šablonų supratimas
#
# ## 📚 Dizaino šablonų kategorijos
#
# ### 1. **Kūrimo šablonai**
# - Agentų gamyklos ir kūrimo šablonai
# - Konfigūracijos valdymo šablonai
# - Priklausomybių injekcija agentų paslaugoms
#
# ### 2. **Elgsenos šablonai**
# - Įrankių vykdymas ir koordinavimas
# - Pokalbių srauto valdymas
# - Atsakymų apdorojimas ir formatavimas
#
# ### 3. **Integracijos šablonai**
# - GitHub Models API integracija
# - Klaidos tvarkymas ir pakartojimo logika
# - Išteklių valdymas ir valymas
#
# ## 🚀 Demonstruojama geriausia praktika
#
# - **Švari architektūra**: Sluoksniuotas dizainas su aiškiomis atsakomybėmis
# - **Klaidų tvarkymas**: Išsamus išimčių valdymas
# - **Konfigūracija**: Aplinkos pagrindu sukurta sąranka skirtingoms aplinkoms
# - **Testavimas**: Šablonai, leidžiantys efektyviai atlikti vienetinius ir integracinius testus
# - **Dokumentacija**: Savarankiškai dokumentuojantis kodas su aiškia paskirtimi
#
# Pasiruošę tyrinėti profesionalius agentų dizaino šablonus? Sukurkime kažką patikimo! 🌟

# %%
! pip install agent-framework-core  -U

# %%
# 📦 Import Core Libraries for Agent Design Patterns
import os                     # Environment variable access for configuration management
from random import randint    # Random selection utilities for tool functionality

from dotenv import load_dotenv  # Secure environment configuration loading

# %%
# 🤖 Import Microsoft Agent Framework Components  
# ChatAgent: Core agent orchestration class following factory pattern
# OpenAIChatClient: GitHub Models integration following adapter pattern
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Configuration Loading Pattern
# Implement configuration management pattern for secure credential handling
# This follows the external configuration principle for cloud-native applications
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function Design Pattern
# Implements the Strategy Pattern for pluggable agent capabilities
# This demonstrates clean separation of business logic from agent orchestration
def get_random_destination() -> str:
    """Get a random vacation destination using Repository Pattern.
    
    This function exemplifies several design patterns:
    - Strategy Pattern: Interchangeable algorithm for destination selection
    - Repository Pattern: Encapsulates data access logic
    - Factory Method: Creates destination objects on demand
    
    Returns:
        str: A randomly selected destination following consistent format
    """
    # Data Repository Pattern: Centralized destination data management
    destinations = [
        "Barcelona, Spain",      # Mediterranean cultural hub
        "Paris, France",         # European artistic center
        "Berlin, Germany",       # Historical European capital
        "Tokyo, Japan",          # Asian technology metropolis
        "Sydney, Australia",     # Oceanic coastal city
        "New York, USA",         # American urban center
        "Cairo, Egypt",          # African historical capital
        "Cape Town, South Africa", # African scenic destination
        "Rio de Janeiro, Brazil",  # South American beach city
        "Bali, Indonesia"          # Southeast Asian island paradise
    ]
    
    # Factory Method Pattern: Create destination selection on demand
    return destinations[randint(0, len(destinations) - 1)]

# %%
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
AGENT_NAME ="TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers.

Important: When users specify a destination, always plan for that location. Only suggest random destinations when the user hasn't specified a preference.

When the conversation begins, introduce yourself with this message:
"Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
1. Plan a day trip to a specific location
2. Suggest a random vacation destination
3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
4. Plan an alternative trip if you don't like my first suggestion

What kind of trip would you like me to help you plan today?"

Always prioritize user preferences. If they mention a specific destination like "Bali" or "Paris," focus your planning on that location rather than suggesting alternatives.
"""

# %%
agent = ChatAgent(
        name = AGENT_NAME,
        chat_client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
# 1. Plan a day trip to a specific location
# 2. Suggest a random vacation destination
# 3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
# 4. Plan an alternative trip if you don't like my first suggestion
#
# What kind of trip would you like me to help you plan today? Could you please specify a destination for your day trip?

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# Could you please specify a location or type of vacation you're interested in? This will help me find the perfect place for you!

# %% [markdown]
# ---
#
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas naudojant dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba turėtų būti laikomas autoritetingu šaltiniu. Kritinei informacijai rekomenduojama naudoti profesionalų žmogaus vertimą. Mes neprisiimame atsakomybės už nesusipratimus ar neteisingus aiškinimus, atsiradusius dėl šio vertimo naudojimo.
