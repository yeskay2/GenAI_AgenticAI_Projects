# %% [markdown]
# # 🎨 Σχεδιαστικά Πρότυπα Πρακτόρων με Μοντέλα GitHub (Python)
#
# ## 📋 Στόχοι Μάθησης
#
# Αυτό το σημειωματάριο παρουσιάζει βασικά σχεδιαστικά πρότυπα για τη δημιουργία έξυπνων πρακτόρων χρησιμοποιώντας το Microsoft Agent Framework με ενσωμάτωση Μοντέλων GitHub. Θα μάθετε δοκιμασμένα πρότυπα και αρχιτεκτονικές προσεγγίσεις που κάνουν τους πράκτορες πιο ανθεκτικούς, ευέλικτους και αποτελεσματικούς.
#
# **Κύρια Σχεδιαστικά Πρότυπα που Καλύπτονται:**
# - 🏗️ **Πρότυπο Εργοστασίου Πρακτόρων**: Τυποποιημένη δημιουργία και διαμόρφωση πρακτόρων
# - 🔧 **Πρότυπο Καταχώρησης Εργαλείων**: Οργανωμένη προσέγγιση στη διαχείριση δυνατοτήτων πρακτόρων
# - 🧵 **Διαχείριση Συνομιλίας**: Αποτελεσματικά πρότυπα για αλληλεπιδράσεις πολλαπλών γύρων
# - 🔄 **Επεξεργασία Απαντήσεων**: Βέλτιστες πρακτικές για τη διαχείριση εξόδων πρακτόρων
#
# ## 🎯 Βασικές Αρχιτεκτονικές Έννοιες
#
# ### Αρχές Σχεδιασμού
# - **Διαχωρισμός Αρμοδιοτήτων**: Σαφή όρια μεταξύ λογικής πρακτόρων, εργαλείων και διαμόρφωσης
# - **Συνθεσιμότητα**: Δημιουργία σύνθετων πρακτόρων από επαναχρησιμοποιήσιμα στοιχεία
# - **Επεκτασιμότητα**: Πρότυπα που επιτρέπουν την εύκολη προσθήκη νέων δυνατοτήτων
# - **Δοκιμασιμότητα**: Σχεδιασμός για εύκολη μονάδα δοκιμών και επικύρωση
#
# ### Ενσωμάτωση Μοντέλων GitHub
# - **Συμβατότητα API**: Αξιοποίηση σημείων τερματισμού συμβατών με OpenAI
# - **Επιλογή Μοντέλων**: Επιλογή κατάλληλων μοντέλων για διαφορετικές περιπτώσεις χρήσης
# - **Περιορισμός Ρυθμού**: Χειρισμός περιορισμών API με χάρη
# - **Ανάκτηση Σφαλμάτων**: Ανθεκτικός χειρισμός σφαλμάτων και πρότυπα επαναπροσπάθειας
#
# ## 🔧 Τεχνική Αρχιτεκτονική
#
# ### Βασικά Στοιχεία
# - **Microsoft Agent Framework**: Υλοποίηση Python με υποστήριξη Μοντέλων GitHub
# - **GitHub Models API**: Πρόσβαση σε προηγμένα γλωσσικά μοντέλα
# - **Πρότυπο Πελάτη OpenAI**: Τυποποιημένα πρότυπα αλληλεπίδρασης API
# - **Διαμόρφωση Περιβάλλοντος**: Ασφαλής και ευέλικτη διαχείριση διαμόρφωσης
#
# ### Οφέλη Σχεδιαστικών Προτύπων
# - **Ευκολία Συντήρησης**: Σαφής οργάνωση και δομή κώδικα
# - **Επεκτασιμότητα**: Πρότυπα που αναπτύσσονται με τις ανάγκες της εφαρμογής σας
# - **Αξιοπιστία**: Δοκιμασμένες προσεγγίσεις που χειρίζονται ακραίες περιπτώσεις
# - **Απόδοση**: Αποτελεσματική χρήση πόρων και API
#
# ## ⚙️ Προαπαιτούμενα & Ρύθμιση
#
# **Απαιτούμενες Εξαρτήσεις:**
# ```bash
#
# pip install agent-framework-core  -U
#
# ```
#
# **Διαμόρφωση Περιβάλλοντος (.env αρχείο):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Πρόσβαση σε Μοντέλα GitHub:**
# - Λογαριασμός GitHub με πρόσβαση σε Μοντέλα
# - Προσωπικό διακριτικό πρόσβασης με κατάλληλες άδειες
# - Κατανόηση περιορισμών ρυθμού και προτύπων χρήσης
#
# ## 📚 Κατηγορίες Σχεδιαστικών Προτύπων
#
# ### 1. **Δημιουργικά Πρότυπα**
# - Πρότυπα εργοστασίου και δημιουργίας πρακτόρων
# - Πρότυπα διαχείρισης διαμόρφωσης
# - Εισαγωγή εξαρτήσεων για υπηρεσίες πρακτόρων
#
# ### 2. **Συμπεριφορικά Πρότυπα**
# - Εκτέλεση και ορχήστρα εργαλείων
# - Διαχείριση ροής συνομιλίας
# - Επεξεργασία και μορφοποίηση απαντήσεων
#
# ### 3. **Πρότυπα Ενσωμάτωσης**
# - Ενσωμάτωση API Μοντέλων GitHub
# - Χειρισμός σφαλμάτων και λογική επαναπροσπάθειας
# - Διαχείριση πόρων και καθαρισμός
#
# ## 🚀 Βέλτιστες Πρακτικές που Παρουσιάζονται
#
# - **Καθαρή Αρχιτεκτονική**: Σχεδιασμός με στρώσεις και σαφείς αρμοδιότητες
# - **Χειρισμός Σφαλμάτων**: Ολοκληρωμένη διαχείριση εξαιρέσεων
# - **Διαμόρφωση**: Ρύθμιση βάσει περιβάλλοντος για διαφορετικά περιβάλλοντα
# - **Δοκιμές**: Πρότυπα που επιτρέπουν αποτελεσματικές μονάδες και δοκιμές ενσωμάτωσης
# - **Τεκμηρίωση**: Κώδικας που τεκμηριώνεται από μόνος του με σαφή πρόθεση
#
# Έτοιμοι να εξερευνήσετε επαγγελματικά σχεδιαστικά πρότυπα πρακτόρων; Ας δημιουργήσουμε κάτι ανθεκτικό! 🌟

# %%
! pip install agent-framework-core  -U

# %%
# 📦 Import Core Libraries for Agent Design Patterns
import os                     # Environment variable access for configuration management
from random import randint    # Random selection utilities for tool functionality

from dotenv import load_dotenv  # Secure environment configuration loading

# %%
# 🤖 Import Microsoft Agent Framework Components  
# ChatAgent: Core agent orchestration class following factory pattern
# OpenAIChatClient: GitHub Models integration following adapter pattern
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Configuration Loading Pattern
# Implement configuration management pattern for secure credential handling
# This follows the external configuration principle for cloud-native applications
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function Design Pattern
# Implements the Strategy Pattern for pluggable agent capabilities
# This demonstrates clean separation of business logic from agent orchestration
def get_random_destination() -> str:
    """Get a random vacation destination using Repository Pattern.
    
    This function exemplifies several design patterns:
    - Strategy Pattern: Interchangeable algorithm for destination selection
    - Repository Pattern: Encapsulates data access logic
    - Factory Method: Creates destination objects on demand
    
    Returns:
        str: A randomly selected destination following consistent format
    """
    # Data Repository Pattern: Centralized destination data management
    destinations = [
        "Barcelona, Spain",      # Mediterranean cultural hub
        "Paris, France",         # European artistic center
        "Berlin, Germany",       # Historical European capital
        "Tokyo, Japan",          # Asian technology metropolis
        "Sydney, Australia",     # Oceanic coastal city
        "New York, USA",         # American urban center
        "Cairo, Egypt",          # African historical capital
        "Cape Town, South Africa", # African scenic destination
        "Rio de Janeiro, Brazil",  # South American beach city
        "Bali, Indonesia"          # Southeast Asian island paradise
    ]
    
    # Factory Method Pattern: Create destination selection on demand
    return destinations[randint(0, len(destinations) - 1)]

# %%
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
AGENT_NAME ="TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers.

Important: When users specify a destination, always plan for that location. Only suggest random destinations when the user hasn't specified a preference.

When the conversation begins, introduce yourself with this message:
"Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
1. Plan a day trip to a specific location
2. Suggest a random vacation destination
3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
4. Plan an alternative trip if you don't like my first suggestion

What kind of trip would you like me to help you plan today?"

Always prioritize user preferences. If they mention a specific destination like "Bali" or "Paris," focus your planning on that location rather than suggesting alternatives.
"""

# %%
agent = ChatAgent(
        name = AGENT_NAME,
        chat_client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
# 1. Plan a day trip to a specific location
# 2. Suggest a random vacation destination
# 3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
# 4. Plan an alternative trip if you don't like my first suggestion
#
# What kind of trip would you like me to help you plan today? Could you please specify a destination for your day trip?

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# Could you please specify a location or type of vacation you're interested in? This will help me find the perfect place for you!

# %% [markdown]
# ---
#
# **Αποποίηση ευθύνης**:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία αυτόματης μετάφρασης [Co-op Translator](https://github.com/Azure/co-op-translator). Παρόλο που καταβάλλουμε προσπάθειες για ακρίβεια, παρακαλούμε να έχετε υπόψη ότι οι αυτοματοποιημένες μεταφράσεις ενδέχεται να περιέχουν λάθη ή ανακρίβειες. Το πρωτότυπο έγγραφο στη γλώσσα του θα πρέπει να θεωρείται η αυθεντική πηγή. Για κρίσιμες πληροφορίες, συνιστάται επαγγελματική ανθρώπινη μετάφραση. Δεν φέρουμε ευθύνη για τυχόν παρεξηγήσεις ή εσφαλμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
