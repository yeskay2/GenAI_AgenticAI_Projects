# %% [markdown]
# # ⚡ Παράλληλες Ροές Εργασίας Πρακτόρων με Μοντέλα GitHub (Python)
#
# ## 📋 Προχωρημένο Εκπαιδευτικό Υλικό για Παράλληλη Επεξεργασία
#
# Αυτό το σημειωματάριο παρουσιάζει **μοτίβα παράλληλων ροών εργασίας** χρησιμοποιώντας το Microsoft Agent Framework. Θα μάθετε πώς να δημιουργείτε ροές εργασίας υψηλής απόδοσης, όπου πολλοί AI πράκτορες εκτελούνται ταυτόχρονα, βελτιώνοντας δραματικά τη διακίνηση και επιτρέποντας σύνθετες επιχειρηματικές διαδικασίες πολλαπλών νημάτων.
#
# ## 🎯 Στόχοι Μάθησης
#
# ### 🚀 **Βασικές Αρχές Παράλληλης Επεξεργασίας**
# - **Παράλληλη Εκτέλεση Πρακτόρων**: Εκτελέστε πολλούς πράκτορες ταυτόχρονα για μέγιστη αποδοτικότητα
# - **Ορχήστρωση Ροής Εργασίας**: Συντονίστε παράλληλες λειτουργίες διατηρώντας τη συνέπεια των δεδομένων
# - **Βελτιστοποίηση Απόδοσης**: Επιτύχετε σημαντική επιτάχυνση μέσω παράλληλης επεξεργασίας
# - **Διαχείριση Πόρων**: Χρησιμοποιήστε αποτελεσματικά τους πόρους των μοντέλων AI σε παράλληλες λειτουργίες
#
# ### 🏗️ **Προχωρημένα Μοτίβα Παράλληλης Επεξεργασίας**
# - **Επεξεργασία Fork-Join**: Διαχωρίστε την εργασία σε πολλούς πράκτορες και συγχωνεύστε τα αποτελέσματα
# - **Παράλληλη Επεξεργασία Σωληνώσεων**: Επικάλυψη σταδίων εκτέλεσης για συνεχή διακίνηση
# - **Εξισορρόπηση Φορτίου**: Κατανομή της εργασίας ομοιόμορφα στους διαθέσιμους πόρους πρακτόρων
# - **Σημεία Συγχρονισμού**: Συντονισμός παράλληλων πρακτόρων σε κρίσιμα στάδια της ροής εργασίας
#
# ### 🏢 **Επιχειρηματικές Εφαρμογές Παράλληλης Επεξεργασίας**
# - **Επεξεργασία Εγγράφων Υψηλού Όγκου**: Επεξεργασία πολλών εγγράφων ταυτόχρονα
# - **Ανάλυση Περιεχομένου σε Πραγματικό Χρόνο**: Παράλληλη ανάλυση εισερχόμενων ροών δεδομένων
# - **Βελτιστοποίηση Μαζικής Επεξεργασίας**: Μέγιστη διακίνηση για λειτουργίες μεγάλης κλίμακας
# - **Πολυτροπική Ανάλυση**: Παράλληλη επεξεργασία διαφορετικών τύπων περιεχομένου (κείμενο, εικόνες, δεδομένα)
#
# ## ⚙️ Προαπαιτούμενα & Ρύθμιση
#
# ### 📦 **Απαιτούμενες Εξαρτήσεις**
#
# Εγκαταστήστε το Agent Framework με δυνατότητες παράλληλης ροής εργασίας:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Ρύθμιση Μοντέλων GitHub**
#
# **Ρύθμιση Περιβάλλοντος (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Παράγοντες Παράλληλης Επεξεργασίας:**
# - **Όρια Ρυθμού**: Παρακολουθήστε τα όρια ρυθμού API των Μοντέλων GitHub για παράλληλα αιτήματα
# - **Χρήση Πόρων**: Λάβετε υπόψη τη χρήση μνήμης και CPU με πολλούς παράλληλους πράκτορες
# - **Διαχείριση Σφαλμάτων**: Εφαρμόστε ανθεκτική ανάκτηση σφαλμάτων για παράλληλες λειτουργίες
#
# ### 🏗️ **Αρχιτεκτονική Παράλληλης Ροής Εργασίας**
#
# ```mermaid
# graph TD
#     A[Workflow Start] --> B[Concurrent Execution]
#     B --> C[Agent Pool 1]
#     B --> D[Agent Pool 2]
#     B --> E[Agent Pool 3]
#     C --> F[Result Aggregation]
#     D --> F
#     E --> F
#     F --> G[Final Output]
#
#     H[GitHub Models API] --> C
#     H --> D
#     H --> E
# ```
#
# **Κύρια Οφέλη:**
# - **⚡ Απόδοση**: Σημαντική επιτάχυνση μέσω παράλληλης εκτέλεσης
# - **📈 Επεκτασιμότητα**: Αντιμετώπιση αυξημένων φορτίων χωρίς ανάλογη αύξηση χρόνου
# - **🔄 Αποδοτικότητα**: Καλύτερη αξιοποίηση των διαθέσιμων υπολογιστικών πόρων
# - **🎯 Διακίνηση**: Επεξεργασία περισσότερης εργασίας στον ίδιο χρόνο
#
# ## 🎨 **Μοτίβα Σχεδιασμού Παράλληλης Ροής Εργασίας**
#
# ### 🔍 **Σωλήνας Έρευνας & Ανάλυσης**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Ροή Εργασίας Επεξεργασίας Δεδομένων**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Σωλήνας Δημιουργίας Περιεχομένου**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Πολυσταδιακή Επεξεργασία**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Επιχειρηματικά Οφέλη Απόδοσης**
#
# ### ⚡ **Βελτιστοποίηση Διακίνησης**
# - **Παράλληλη Εκτέλεση**: Πολλοί πράκτορες που εργάζονται ταυτόχρονα
# - **Χρήση Πόρων**: Μέγιστη αποδοτικότητα της διαθέσιμης χωρητικότητας μοντέλων AI
# - **Μείωση Χρόνου**: Σημαντική μείωση του συνολικού χρόνου επεξεργασίας
# - **Επεκτάσιμη Αρχιτεκτονική**: Εύκολη προσθήκη περισσότερων παράλληλων πρακτόρων όταν χρειάζεται
#
# ### 🛡️ **Αξιοπιστία & Ανθεκτικότητα**
# - **Ανοχή Σφαλμάτων**: Αποτυχίες μεμονωμένων πρακτόρων δεν σταματούν τη συνολική ροή εργασίας
# - **Απομόνωση Σφαλμάτων**: Προβλήματα σε έναν παράλληλο κλάδο δεν επηρεάζουν τους άλλους
# - **Ομαλή Υποβάθμιση**: Το σύστημα συνεχίζει να λειτουργεί ακόμα και με μειωμένη χωρητικότητα πρακτόρων
# - **Μηχανισμοί Ανάκτησης**: Αυτόματη επαναπροσπάθεια και διαχείριση σφαλμάτων για αποτυχημένες λειτουργίες
#
# ### 📊 **Παρακολούθηση & Παρατηρησιμότητα**
# - **Παρακολούθηση Παράλληλης Εκτέλεσης**: Παρακολούθηση της προόδου όλων των παράλληλων λειτουργιών
# - **Μετρήσεις Απόδοσης**: Μέτρηση επιτάχυνσης και κερδών αποδοτικότητας
# - **Ανάλυση Χρήσης Πόρων**: Βελτιστοποίηση κατανομής παράλληλων πρακτόρων
# - **Εντοπισμός Στενωμάτων**: Εύρεση και επίλυση περιορισμών απόδοσης
#
# Ας δημιουργήσουμε ροές εργασίας AI υψηλής απόδοσης! 🚀

# %%
! pip install agent-framework-core -U

# %%
import os
from typing import Any

from agent_framework import ChatMessage, ConcurrentBuilder,WorkflowViz
from agent_framework.openai import OpenAIChatClient

# %%
chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id="gpt-4o" )

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent   = chat_client.create_agent(
        instructions=(
           ResearcherAgentInstructions
        ),
        name=ResearcherAgentName,
    )

plan_agent = chat_client.create_agent(
        instructions=(
            PlanAgentInstructions
        ),
        name=PlanAgentName,
    )

# %%
workflow = ConcurrentBuilder().participants([research_agent, plan_agent]).build()

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
svg_file = viz.export(format="svg")
print(f"SVG file saved to: {svg_file}")
# Out:
# Generating workflow visualization...
# Mermaid string:
# ...
# flowchart TD
#   dispatcher["dispatcher (Start)"];
#   Researcher_Agent["Researcher-Agent"];
#   Plan_Agent["Plan-Agent"];
#   aggregator["aggregator"];
#   fan_in__aggregator__69d73de8((fan-in))
#   Plan_Agent --> fan_in__aggregator__69d73de8;
#   Researcher_Agent --> fan_in__aggregator__69d73de8;
#   fan_in__aggregator__69d73de8 --> aggregator;
#   dispatcher --> Researcher_Agent;
#   dispatcher --> Plan_Agent;
# ...
# DiGraph string:
# ...
# digraph Workflow {
#   rankdir=TD;
#   node [shape=box, style=filled, fillcolor=lightblue];
#   edge [color=black, arrowhead=vee];
#
#   "dispatcher" [fillcolor=lightgreen, label="dispatcher\n(Start)"];
#   "Researcher-Agent" [label="Researcher-Agent"];
#   "Plan-Agent" [label="Plan-Agent"];
#   "aggregator" [label="aggregator"];
#
#   "fan_in::aggregator::69d73de8" [shape=ellipse, fillcolor=lightgoldenrod, label="fan-in"];
#   "Plan-Agent" -> "fan_in::aggregator::69d73de8";
# ...

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")
# Out:
# Attempting to display SVG file at: C:\Users\kinfeylo\AppData\Local\Temp\tmpoq68cqjk.svg

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
        print("===== Final Aggregated Conversation (messages) =====")
        for output in outputs:
            messages: list[ChatMessage] | Any = output
            for i, msg in enumerate(messages, start=1):
                name = msg.author_name if msg.author_name else "user"
                print(f"{'-' * 60}\n\n{i:02d} [{name}]:\n{msg.text}")
# Out:
# ===== Final Aggregated Conversation (messages) =====
# ------------------------------------------------------------
#
# 01 [user]:
# Plan a trip to Seattle in December
# ------------------------------------------------------------
#
# 02 [Researcher-Agent]:
# Seattle is a wonderful place to visit in December, with vibrant winter festivities, seasonal attractions, and gorgeous views of the Pacific Northwest. Despite the chilly weather and occasional rain, Seattle’s charm shines through its indoor and outdoor attractions. Here's a detailed plan for your trip:
#
# ---
#
# ### **Destination Overview: Seattle in December**
# - **Weather**: Expect average highs of around 47°F (8°C) and lows near 37°F (3°C). Rain is frequent, so bring waterproof clothing.
# - **Packing List**:
#   - Warm layers (sweaters, coats, gloves, and hats).
#   - Comfortable walking shoes (water-resistant is ideal).
#   - Umbrella or rain jacket.
#
# ---
#
# ### **Day 1: Exploring Downtown Seattle**
# ...

# %% [markdown]
# ---
#
# **Αποποίηση ευθύνης**:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία αυτόματης μετάφρασης [Co-op Translator](https://github.com/Azure/co-op-translator). Παρόλο που καταβάλλουμε προσπάθειες για ακρίβεια, παρακαλούμε να έχετε υπόψη ότι οι αυτόματες μεταφράσεις ενδέχεται να περιέχουν λάθη ή ανακρίβειες. Το πρωτότυπο έγγραφο στη μητρική του γλώσσα θα πρέπει να θεωρείται η αυθεντική πηγή. Για κρίσιμες πληροφορίες, συνιστάται επαγγελματική ανθρώπινη μετάφραση. Δεν φέρουμε ευθύνη για τυχόν παρεξηγήσεις ή εσφαλμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
