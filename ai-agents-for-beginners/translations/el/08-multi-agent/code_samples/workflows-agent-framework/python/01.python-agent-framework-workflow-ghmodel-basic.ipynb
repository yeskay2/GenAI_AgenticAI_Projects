# %% [markdown]
# # 🔄 Βασικές Ροές Εργασίας Πρακτόρων με Μοντέλα GitHub (Python)
#
# ## 📋 Εκμάθηση Ορχήστρωσης Ροής Εργασίας
#
# Αυτό το σημειωματάριο παρουσιάζει τις ισχυρές δυνατότητες του **Workflow Builder** του Microsoft Agent Framework. Μάθετε πώς να δημιουργείτε εξελιγμένες, πολυβήματες ροές εργασίας πρακτόρων που μπορούν να διαχειριστούν σύνθετες επιχειρηματικές διαδικασίες και να συντονίσουν πολλαπλές λειτουργίες AI με ευκολία.
#
# ## 🎯 Στόχοι Εκμάθησης
#
# ### 🏗️ **Αρχιτεκτονική Ροής Εργασίας**
# - **Workflow Builder**: Σχεδιάστε και οργανώστε σύνθετες πολυβήματες διαδικασίες
# - **Εκτέλεση βάσει Συμβάντων**: Διαχειριστείτε συμβάντα ροής εργασίας και μεταβάσεις κατάστασης
# - **Οπτικός Σχεδιασμός Ροής Εργασίας**: Δημιουργήστε και οπτικοποιήστε δομές ροής εργασίας
# - **Ενσωμάτωση Μοντέλων GitHub**: Αξιοποιήστε μοντέλα AI στο πλαίσιο των ροών εργασίας
#
# ### 🔄 **Ορχήστρωση Διαδικασιών**
# - **Διαδοχικές Λειτουργίες**: Συνδέστε πολλαπλές εργασίες πρακτόρων σε λογική σειρά
# - **Λογική Υπό Συνθήκες**: Εφαρμόστε σημεία αποφάσεων και διακλαδώσεις ροών εργασίας
# - **Διαχείριση Σφαλμάτων**: Ανάκτηση από σφάλματα και ανθεκτικότητα ροής εργασίας
# - **Διαχείριση Κατάστασης**: Παρακολουθήστε και διαχειριστείτε την κατάσταση εκτέλεσης της ροής εργασίας
#
# ### 📊 **Πρότυπα Ροής Εργασίας για Επιχειρήσεις**
# - **Αυτοματοποίηση Επιχειρηματικών Διαδικασιών**: Αυτοματοποιήστε σύνθετες οργανωτικές ροές εργασίας
# - **Συντονισμός Πολλαπλών Πρακτόρων**: Συντονίστε πολλούς εξειδικευμένους πράκτορες
# - **Κλιμακούμενη Εκτέλεση**: Σχεδιάστε ροές εργασίας για λειτουργίες σε κλίμακα επιχείρησης
# - **Παρακολούθηση & Παρατηρησιμότητα**: Παρακολουθήστε την απόδοση και τα αποτελέσματα της ροής εργασίας
#
# ## ⚙️ Προαπαιτούμενα & Ρύθμιση
#
# ### 📦 **Απαιτούμενες Εξαρτήσεις**
#
# Εγκαταστήστε το Agent Framework με δυνατότητες ροής εργασίας:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Ρύθμιση Μοντέλων GitHub**
#
# **Ρύθμιση Περιβάλλοντος (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ### 🏢 **Χρήσεις για Επιχειρήσεις**
#
# **Παραδείγματα Επιχειρηματικών Διαδικασιών:**
# - **Εγγραφή Πελατών**: Ροές εργασίας πολλαπλών βημάτων για επαλήθευση και ρύθμιση
# - **Διαδικασία Περιεχομένου**: Αυτοματοποιημένη δημιουργία, ανασκόπηση και δημοσίευση περιεχομένου
# - **Επεξεργασία Δεδομένων**: Ροές ETL με AI για μετασχηματισμό δεδομένων
# - **Διασφάλιση Ποιότητας**: Αυτοματοποιημένες διαδικασίες δοκιμών και επαλήθευσης
#
# **Οφέλη Ροής Εργασίας:**
# - 🎯 **Αξιοπιστία**: Ντετερμινιστική εκτέλεση με ανάκτηση από σφάλματα
# - 📈 **Κλιμακούμενη Απόδοση**: Διαχείριση αυτοματοποίησης διαδικασιών υψηλού όγκου
# - 🔍 **Παρατηρησιμότητα**: Πλήρη ίχνη ελέγχου και παρακολούθηση
# - 🔧 **Ευκολία Συντήρησης**: Οπτικός σχεδιασμός και αρθρωτά στοιχεία
#
# ## 🎨 Πρότυπα Σχεδιασμού Ροής Εργασίας
#
# ### Βασική Δομή Ροής Εργασίας
# ```mermaid
# graph TD
#     A[Start] --> B[Agent Task 1]
#     B --> C{Decision Point}
#     C -->|Success| D[Agent Task 2]
#     C -->|Failure| E[Error Handler]
#     D --> F[End]
#     E --> F
# ```
#
# **Βασικά Στοιχεία:**
# - **WorkflowBuilder**: Κύρια μηχανή ορχήστρωσης
# - **WorkflowEvent**: Διαχείριση συμβάντων και επικοινωνία
# - **WorkflowViz**: Οπτική αναπαράσταση και αποσφαλμάτωση ροής εργασίας
#
# Ας δημιουργήσουμε την πρώτη σας έξυπνη ροή εργασίας! 🚀

# %%
! pip install agent-framework-core -U
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# 🔄 Import Workflow and Agent Framework Components
# Core components for building sophisticated agent workflows

from agent_framework.openai import OpenAIChatClient    # 🤖 GitHub Models client integration
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz  # 🏗️ Workflow orchestration tools

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load GitHub Models API credentials from .env file
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize GitHub Models Chat Client for Workflow Operations
# Create the AI client that will power agents within our workflow
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # 🌐 GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # 🔑 Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # 🎯 Selected AI model
)
# Out:
# ---------------------------------------------------------------------------
# ServiceInitializationError                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # 🔗 Initialize GitHub Models Chat Client for Workflow Operations
#       2 # Create the AI client that will power agents within our workflow
# ----> 3 chat_client = OpenAIChatClient(
#       4     base_url=os.environ.get("GITHUB_ENDPOINT"),    # 🌐 GitHub Models API endpoint
#       5     api_key=os.environ.get("GITHUB_TOKEN"),        # 🔑 Authentication token
#       6     model_id=os.environ.get("GITHUB_MODEL_ID")  # 🎯 Selected AI model
#       7 )
#
# File ~/ai-agents-for-beginners/.venv/lib/python3.12/site-packages/agent_framework/openai/_chat_client.py:536, in OpenAIChatClient.__init__(self, model_id, api_key, org_id, default_headers, async_client, instruction_role, base_url, env_file_path, env_file_encoding)
#     532     raise ServiceInitializationError(
# ...

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent   = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

front_desk_agent = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(front_desk_agent).add_edge(front_desk_agent, reviewer_agent).build()

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
svg_file = viz.export(format="svg")
print(f"SVG file saved to: {svg_file}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
result =''
async for event in workflow.run_stream('I would like to go to Paris.'):
    if isinstance(event, DatabaseEvent):
        print(f"{event}")
    if isinstance(event, WorkflowEvent):
        result += str(event.data)
        # print(f"Workflow output: {event.data}")

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# **Αποποίηση ευθύνης**:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία αυτόματης μετάφρασης [Co-op Translator](https://github.com/Azure/co-op-translator). Παρόλο που καταβάλλουμε προσπάθειες για ακρίβεια, παρακαλούμε να έχετε υπόψη ότι οι αυτοματοποιημένες μεταφράσεις ενδέχεται να περιέχουν λάθη ή ανακρίβειες. Το πρωτότυπο έγγραφο στη μητρική του γλώσσα θα πρέπει να θεωρείται η αυθεντική πηγή. Για κρίσιμες πληροφορίες, συνιστάται επαγγελματική ανθρώπινη μετάφραση. Δεν φέρουμε ευθύνη για τυχόν παρεξηγήσεις ή εσφαλμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
