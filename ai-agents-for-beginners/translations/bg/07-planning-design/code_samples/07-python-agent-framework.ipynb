# %% [markdown]
# # 🎯 Планиране и шаблони за дизайн с GitHub модели (Python)
#
# ## 📋 Цели на обучението
#
# Този ноутбук демонстрира усъвършенствани методи за планиране и шаблони за дизайн при изграждането на интелигентни агенти с помощта на Microsoft Agent Framework и GitHub модели. Ще научите как да създавате агенти, които могат да разбиват сложни проблеми, да планират решения на няколко стъпки и да координират сложни работни процеси.
#
# **Усъвършенствани способности, които ще овладеете:**
# - 🧠 **Стратегическо планиране**: Разбиване на сложни задачи на управляеми подзадачи
# - 🗺️ **Многостъпково разсъждение**: Модели за последователно и паралелно изпълнение на задачи
# - 🎯 **Дизайн, ориентиран към целите**: Агенти, които работят за постигане на конкретни цели
# - 🔄 **Адаптивно планиране**: Динамично коригиране на стратегията според контекста
#
# ## 🎯 Концепции за архитектура на планиране
#
# ### Основни компоненти на планирането
# - **Разбиване на задачи**: Разделяне на сложни проблеми на по-малки, управляеми части
# - **Планиране на изпълнението**: Определяне на оптимален ред и зависимости за подзадачите
# - **Управление на ресурсите**: Ефективно разпределение на инструменти и възможности
# - **Мониторинг на напредъка**: Проследяване на изпълнението и адаптиране към промените
#
# ### Шаблони за дизайн при планиране
# - **Шаблон "Стратегия"**: Различни подходи за планиране в различни сценарии
# - **Шаблон "Верига на отговорност"**: Последователна обработка с резервни опции
# - **Шаблон "Команда"**: Инкапсулирано изпълнение на задачи с възможности за отмяна/повторение
# - **Шаблон "Наблюдател"**: Проследяване на напредъка и актуализации, базирани на събития
#
# ## 🏗️ Техническа архитектура
#
# ### Компоненти на системата за планиране
# - **Microsoft Agent Framework**: Python имплементация с поддръжка за усъвършенствано планиране
# - **Интеграция с GitHub модели**: Високоефективно разсъждение и вземане на решения
# - **Оркестрация на задачи**: Координирано изпълнение на сложни работни процеси
# - **Управление на състоянието**: Постоянно проследяване на напредъка и резултатите от планирането
#
# ### Поток на процеса на планиране
# ```python
# Complex Goal → Task Analysis → Subtask Decomposition → Execution Planning
#                 ↓                    ↓                    ↓
#          Priority Assessment → Resource Allocation → Sequential Execution
#                 ↓                    ↓                    ↓
#          Progress Monitoring → Adaptive Replanning → Goal Achievement
# ```
#
# ## 🧠 Методи за планиране
#
# ### 1. **Йерархично планиране на задачи**
# - Разбиване отгоре надолу на сложни цели
# - Вложени структури на цели с зависимости
# - Рекурсивно планиране за подцели
# - Ефективно разпределение на ресурси на различни нива
#
# ### 2. **Последователно планиране**
# - Стъпка по стъпка изпълнение на задачи с ясни зависимости
# - Обработка на грешки и възстановяване на всяка стъпка
# - Контролни точки за напредък и валидиране
# - Възможности за връщане назад при неуспешни стъпки
#
# ### 3. **Паралелно планиране**
# - Едновременно изпълнение на независими задачи
# - Синхронизация на ресурси и разрешаване на конфликти
# - Оптимизация на производителността чрез паралелизация
# - Координирано завършване и обобщаване на резултатите
#
# ## ⚙️ Предпоставки и настройка
#
# **Необходими зависимости:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Конфигурация на средата (.env файл):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Шаблони за дизайн при планиране
#
# ### Планиране, ориентирано към целите
# - **SMART цели**: Специфични, измерими, постижими, релевантни, ограничени във времето
# - **Проследяване на етапи**: Измерване на напредъка и контролни точки за валидиране
# - **Критерии за успех**: Ясни дефиниции за завършване на задачи
# - **Адаптивни стратегии**: Динамично коригиране на планирането въз основа на обратна връзка
#
# ### Планиране, съобразено с ресурсите
# - **Оценка на възможностите**: Разбиране на наличните инструменти и техните ограничения
# - **Баланс на натоварването**: Оптимално разпределение на задачи между наличните ресурси
# - **Управление на ограниченията**: Работа в рамките на системни и API ограничения
# - **Оптимизация на производителността**: Максимизиране на ефективността и минимизиране на латентността
#
# ### Планиране, устойчиво на грешки
# - **Откриване на грешки**: Ранно идентифициране на проблеми при планиране или изпълнение
# - **Стратегии за възстановяване**: Автоматични резервни и алтернативни подходи
# - **Запазване на състоянието**: Поддържане на напредъка по време на възстановяване от грешки
# - **Постепенно влошаване**: Частичен успех, когато пълното завършване не е възможно
#
# ## 🚀 Усъвършенствани функции за планиране
#
# - **Мета-планиране**: Агенти, които планират как да планират
# - **Съвместно планиране**: Координация между множество агенти за сложни проекти
# - **Учене от опит**: Подобряване на стратегиите за планиране с времето
# - **Адаптация в реално време**: Динамично препланиране при променящи се условия
#
# ## 📊 Приложения и случаи на употреба
#
# ### Автоматизация на бизнес процеси
# - Управление на проекти и планиране на задачи
# - Оптимизация на работни процеси и разпределение на ресурси
# - Стратегическо планиране и подкрепа при вземане на решения
# - Подобрение и автоматизация на процеси
#
# ### Изследвания и анализ
# - Преглед и синтез на литература
# - Планиране на анализ на данни
# - Дизайн и изпълнение на експерименти
# - Генериране и форматиране на доклади
#
# ### Креативни проекти
# - Работни процеси за създаване на съдържание
# - Координация на мултимедийни проекти
# - Планиране и изпълнение на кампании
# - Организация и управление на събития
#
# Готови ли сте да изградите интелигентни агенти за планиране, които могат да се справят със сложни, многостъпкови предизвикателства? Нека създадем усъвършенствани способности за решаване на проблеми! 🧠✨

# %%
! pip install agent-framework-core -U

# %%
# 📦 Import Standard Libraries
# os: For environment variable access
# dotenv: For loading environment variables from .env file
import os

from dotenv import load_dotenv

# %%
# 📝 Import Data Modeling Libraries
# Pydantic: For data validation and structured outputs
# BaseModel: Base class for creating data models
# Field: For adding metadata and validation to model fields
# List: Type hint for list collections
from pydantic import BaseModel, Field
from typing import List

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatMessage: For creating structured chat messages
# Role: Enum for message roles (user, assistant, system)
# ChatOptions: Configuration options for chat interactions
# OpenAIChatClient: Client for OpenAI-compatible APIs (GitHub Models)
from agent_framework import ChatMessage, Role, ChatOptions
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# Load configuration from .env file
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎯 Agent Configuration
# Define the agent's name and role

AGENT_NAME = "TravelAgent"

# 📋 System Instructions for Planning Agent
# This agent acts as a coordinator that decides which specialized agents to use
AGENT_INSTRUCTIONS = """You are a planner agent.
    Your job is to decide which agents to run based on the user's request.
    Below are the available agents specialized in different tasks:
    - FlightBooking: For booking flights and providing flight information
    - HotelBooking: For booking hotels and providing hotel information
    - CarRental: For booking cars and providing car rental information
    - ActivitiesBooking: For booking activities and providing activity information
"""

# %%
class SubTask(BaseModel):
    assigned_agent: str = Field(
        description="The specific agent assigned to handle this subtask")
    task_details: str = Field(
        description="Detailed description of what needs to be done for this subtask")


class TravelPlan(BaseModel):
    main_task: str = Field(
        description="The overall travel request from the user")
    subtasks: List[SubTask] = Field(
        description="List of subtasks broken down from the main task, each assigned to a specialized agent")

# %%
options = ChatOptions(response_format=TravelPlan)

# %%
client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
agent =  client.create_agent(name= AGENT_NAME , instructions=AGENT_INSTRUCTIONS)

# %%
messages = [
        ChatMessage(role=Role.USER, text="Create a travel plan for a family of 4, with 2 kids, from Singapore to Melbourne")
    ]

# %%
response = await agent.run(messages,response_format=TravelPlan)

# %%
response.messages[0].text
# Out:
# '{"main_task":"Plan a family trip from Singapore to Melbourne for 4 people, including 2 kids.","subtasks":[{"assigned_agent":"FlightBooking","task_details":"Book one round-trip flight from Singapore to Melbourne for a family of 4, considering family-friendly options."},{"assigned_agent":"HotelBooking","task_details":"Find and book a family-friendly hotel in Melbourne that can accommodate 4 people, including 2 kids."},{"assigned_agent":"CarRental","task_details":"Arrange a car rental in Melbourne for the family to facilitate travel around the city."},{"assigned_agent":"ActivitiesBooking","task_details":"Provide a list of kid-friendly activities and attractions in Melbourne for the family to enjoy."}]}'

# %% [markdown]
# ---
#
# **Отказ от отговорност**:
# Този документ е преведен с помощта на AI услуга за превод [Co-op Translator](https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, моля, имайте предвид, че автоматизираните преводи може да съдържат грешки или неточности. Оригиналният документ на неговия изходен език трябва да се счита за авторитетен източник. За критична информация се препоръчва професионален превод от човек. Ние не носим отговорност за каквито и да е недоразумения или погрешни интерпретации, произтичащи от използването на този превод.
