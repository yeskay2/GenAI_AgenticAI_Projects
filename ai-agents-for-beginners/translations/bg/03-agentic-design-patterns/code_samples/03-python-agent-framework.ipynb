# %% [markdown]
# # 🎨 Агентични дизайнерски модели с GitHub модели (Python)
#
# ## 📋 Учебни цели
#
# Тази тетрадка демонстрира основни дизайнерски модели за изграждане на интелигентни агенти, използвайки Microsoft Agent Framework с интеграция на GitHub модели. Ще научите доказани модели и архитектурни подходи, които правят агентите по-стабилни, поддържани и ефективни.
#
# **Основни обхванати дизайнерски модели:**
# - 🏗️ **Модел на фабрика за агенти**: Стандартизирано създаване и конфигуриране на агенти
# - 🔧 **Модел на регистър на инструменти**: Организиран подход за управление на възможностите на агентите
# - 🧵 **Управление на разговори**: Ефективни модели за взаимодействия с множество завои
# - 🔄 **Обработка на отговори**: Най-добри практики за управление на изходите на агентите
#
# ## 🎯 Основни архитектурни концепции
#
# ### Принципи на дизайна
# - **Разделяне на отговорностите**: Ясни граници между логиката на агента, инструментите и конфигурацията
# - **Композиционност**: Изграждане на сложни агенти от многократно използваеми компоненти
# - **Разширяемост**: Модели, които позволяват лесно добавяне на нови възможности
# - **Тестируемост**: Дизайн за лесно модулно тестване и валидиране
#
# ### Интеграция с GitHub модели
# - **Съвместимост с API**: Използване на крайни точки, съвместими с OpenAI
# - **Избор на модели**: Избиране на подходящи модели за различни случаи на употреба
# - **Ограничения на скоростта**: Гъвкаво управление на ограниченията на API
# - **Възстановяване от грешки**: Стабилно управление на грешки и модели за повторение
#
# ## 🔧 Техническа архитектура
#
# ### Основни компоненти
# - **Microsoft Agent Framework**: Python имплементация с поддръжка на GitHub модели
# - **GitHub Models API**: Достъп до най-съвременни езикови модели
# - **Модел на клиент за OpenAI**: Стандартизирани модели за взаимодействие с API
# - **Конфигурация на средата**: Сигурно и гъвкаво управление на конфигурацията
#
# ### Ползи от дизайнерските модели
# - **Поддържане**: Ясна организация и структура на кода
# - **Мащабируемост**: Модели, които растат с нуждите на приложението
# - **Надеждност**: Доказани подходи за управление на гранични случаи
# - **Производителност**: Ефективно използване на ресурси и API
#
# ## ⚙️ Предварителни условия и настройка
#
# **Необходими зависимости:**
# ```bash
#
# pip install agent-framework-core  -U
#
# ```
#
# **Конфигурация на средата (.env файл):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Достъп до GitHub модели:**
# - GitHub акаунт с достъп до модели
# - Личен токен за достъп с подходящи разрешения
# - Разбиране на ограниченията на скоростта и моделите на употреба
#
# ## 📚 Категории на дизайнерските модели
#
# ### 1. **Създаващи модели**
# - Модели на фабрика и строител за агенти
# - Модели за управление на конфигурацията
# - Инжектиране на зависимости за услуги на агенти
#
# ### 2. **Поведенчески модели**
# - Изпълнение и оркестрация на инструменти
# - Управление на потока на разговорите
# - Обработка и форматиране на отговори
#
# ### 3. **Интеграционни модели**
# - Интеграция с GitHub Models API
# - Управление на грешки и логика за повторение
# - Управление на ресурси и почистване
#
# ## 🚀 Демонстрирани най-добри практики
#
# - **Чиста архитектура**: Слоест дизайн с ясни отговорности
# - **Управление на грешки**: Цялостно управление на изключения
# - **Конфигурация**: Настройка, базирана на средата, за различни среди
# - **Тестване**: Модели, които позволяват ефективно модулно и интеграционно тестване
# - **Документация**: Самодокументиращ се код с ясна цел
#
# Готови ли сте да изследвате професионални дизайнерски модели за агенти? Нека изградим нещо стабилно! 🌟

# %%
! pip install agent-framework-core  -U

# %%
# 📦 Import Core Libraries for Agent Design Patterns
import os                     # Environment variable access for configuration management
from random import randint    # Random selection utilities for tool functionality

from dotenv import load_dotenv  # Secure environment configuration loading

# %%
# 🤖 Import Microsoft Agent Framework Components  
# ChatAgent: Core agent orchestration class following factory pattern
# OpenAIChatClient: GitHub Models integration following adapter pattern
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Configuration Loading Pattern
# Implement configuration management pattern for secure credential handling
# This follows the external configuration principle for cloud-native applications
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function Design Pattern
# Implements the Strategy Pattern for pluggable agent capabilities
# This demonstrates clean separation of business logic from agent orchestration
def get_random_destination() -> str:
    """Get a random vacation destination using Repository Pattern.
    
    This function exemplifies several design patterns:
    - Strategy Pattern: Interchangeable algorithm for destination selection
    - Repository Pattern: Encapsulates data access logic
    - Factory Method: Creates destination objects on demand
    
    Returns:
        str: A randomly selected destination following consistent format
    """
    # Data Repository Pattern: Centralized destination data management
    destinations = [
        "Barcelona, Spain",      # Mediterranean cultural hub
        "Paris, France",         # European artistic center
        "Berlin, Germany",       # Historical European capital
        "Tokyo, Japan",          # Asian technology metropolis
        "Sydney, Australia",     # Oceanic coastal city
        "New York, USA",         # American urban center
        "Cairo, Egypt",          # African historical capital
        "Cape Town, South Africa", # African scenic destination
        "Rio de Janeiro, Brazil",  # South American beach city
        "Bali, Indonesia"          # Southeast Asian island paradise
    ]
    
    # Factory Method Pattern: Create destination selection on demand
    return destinations[randint(0, len(destinations) - 1)]

# %%
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
AGENT_NAME ="TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers.

Important: When users specify a destination, always plan for that location. Only suggest random destinations when the user hasn't specified a preference.

When the conversation begins, introduce yourself with this message:
"Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
1. Plan a day trip to a specific location
2. Suggest a random vacation destination
3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
4. Plan an alternative trip if you don't like my first suggestion

What kind of trip would you like me to help you plan today?"

Always prioritize user preferences. If they mention a specific destination like "Bali" or "Paris," focus your planning on that location rather than suggesting alternatives.
"""

# %%
agent = ChatAgent(
        name = AGENT_NAME,
        chat_client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
# 1. Plan a day trip to a specific location
# 2. Suggest a random vacation destination
# 3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
# 4. Plan an alternative trip if you don't like my first suggestion
#
# What kind of trip would you like me to help you plan today? Could you please specify a destination for your day trip?

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# Could you please specify a location or type of vacation you're interested in? This will help me find the perfect place for you!

# %% [markdown]
# ---
#
# **Отказ от отговорност**:
# Този документ е преведен с помощта на AI услуга за превод [Co-op Translator](https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, моля, имайте предвид, че автоматизираните преводи може да съдържат грешки или неточности. Оригиналният документ на неговия роден език трябва да се счита за авторитетен източник. За критична информация се препоръчва професионален човешки превод. Ние не носим отговорност за недоразумения или погрешни интерпретации, произтичащи от използването на този превод.
