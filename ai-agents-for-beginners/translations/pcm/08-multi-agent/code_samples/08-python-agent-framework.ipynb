# %% [markdown]
# # 🤝 Multi-Agent Workflow Systems wit GitHub Models (Python)
#
# ## 📋 Wetin You Go Learn
#
# Dis notebook go show you how to build beta multi-agent systems wit Microsoft Agent Framework and GitHub Models. You go sabi how to make plenty agents wey sabi different tins work together to solve big problems wit organized workflows.
#
# **Multi-Agent Tins We Go Build:**
# - 👥 **Agent Collaboration**: Plenty agents go dey work together to achieve one goal
# - 🔄 **Workflow Orchestration**: Arrange how agents go dey interact well well
# - 🎭 **Role Specialization**: Agents go get dia own personality and area wey dem sabi
# - 📋 **Quality Assurance**: Agents go dey review and correct each other work
#
# ## 🎯 Multi-Agent Architecture Tins
#
# ### Main Tins About Multi-Agent
# - **Division of Labor**: Each agent go sabi one area well well
# - **Collaborative Decision Making**: Agents go dey check and correct each other work
# - **Workflow Coordination**: Arrange how agents go dey pass work and communicate
# - **Quality Enhancement**: Agents go dey improve work step by step wit different ideas
#
# ### How Agents Go Interact
# - **Sequential Processing**: Agents go dey work one after the other
# - **Peer Review**: Agents go dey check and make each other work better
# - **Hierarchical Structure**: Lead agents go dey direct other agents
# - **Consensus Building**: Plenty agents go dey contribute to final decision
#
# ## 🏗️ Technical Architecture
#
# ### Workflow System Tins
# - **Microsoft Agent Framework**: Python implementation wey get beta workflow support
# - **WorkflowBuilder**: Define workflow and make am run well
# - **Agent Coordination**: Arrange how agents go dey communicate and pass work
# - **Event-Driven Processing**: Workflow go dey react based on wetin agents do
#
# ### How Multi-Agent Process Go Flow
# ```python
# User Request → Agent 1 (Specialist) → Agent 2 (Reviewer) → Quality Check
#                 ↓                      ↓                    ↓
#          Initial Solution → Review & Feedback → Refined Output → Final Result
# ```
#
# ## 🎭 Agent Role Examples
#
# ### Hotel Concierge System
# Dis notebook go show travel recommendation system wey get agents wit special roles:
#
# #### 🏨 **Front Desk Agent**
# - **Wetin E Sabi**: Travel recommendations and local area knowledge
# - **Personality**: E dey quick, sabi well, and dey talk straight to the point
# - **Responsibility**: E go dey give first travel suggestions and activities
#
# #### 🎩 **Concierge Agent**
# - **Wetin E Sabi**: E dey focus on real local experience and quality check
# - **Personality**: E dey picky, no dey like touristy tins
# - **Responsibility**: E go dey review and make travel suggestions better
#
# ## 🔧 Technical Implementation
#
# ### Workflow Architecture
# - **Agent Definition**: Give agents special instructions and personality
# - **Workflow Builder**: Define workflow and handle events
# - **Communication Protocol**: Arrange how agents go dey pass message
# - **Result Aggregation**: Combine wetin different agents talk
#
# ### Event-Driven Coordination
# - **WorkflowEvent**: Points wey go make agents start work or pass work
# - **OutputEvent**: Arrange how agents go dey exchange data
# - **Quality Gates**: Checkpoints to make sure work dey correct
# - **Feedback Loops**: Agents go dey improve work step by step
#
# ## ⚙️ Wetin You Need & Setup
#
#
# **Dependencies We You Need:**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Multi-Agent Design Patterns
#
# ### 1. **Producer-Consumer Pattern**
# - Agents go dey create content wey other agents go review
# - Clear points to pass work and exchange data
# - Quality assurance wit independent review
# - Step by step improvement
#
# ### 2. **Committee Pattern**
# - Plenty agents go dey contribute different ideas
# - Build agreement wit organized discussion
# - Decision go dey democratic wit weighted opinions
# - Solve problem and break tie if dem no agree
#
# ### 3. **Hierarchical Pattern**
# - Lead agents go dey direct other agents wey sabi one area
# - Clear authority and decision flow
# - Escalate complex decisions to lead agents
# - Monitor performance and check quality
#
# ### 4. **Pipeline Pattern**
# - Agents go dey work one after the other wit special stages
# - Each agent go add value for wetin e sabi
# - Work go dey fast wit parallel processing
# - Handle error and fix am for each stage
#
# ## 🚀 Advanced Multi-Agent Features
#
# ### Workflow Orchestration
# - **Dynamic Routing**: Choose agent based on wetin dey happen
# - **Parallel Processing**: Agents go dey work at the same time for efficiency
# - **Error Recovery**: Handle agent failure and retry work
# - **Performance Monitoring**: Track workflow and make am better
#
# ### Agent Communication
# - **Structured Messaging**: Arrange how agents go dey pass message well
# - **Context Preservation**: Keep conversation history between agents
# - **Metadata Passing**: Share rich information beyond text
# - **Event Broadcasting**: Publish-subscribe pattern for coordination
#
# ### Quality Assurance
# - **Multi-Perspective Review**: Different agents go bring dia own ideas
# - **Iterative Refinement**: Step by step improvement wit collaboration
# - **Validation Checkpoints**: Check quality for different points
# - **Performance Metrics**: Measure how agents dey work together
#
# ## 📊 Use Cases & Applications
#
# ### Business Process Automation
# - Review and approve documents
# - Customer service escalation systems
# - Quality assurance and compliance checking
# - Multi-stage content creation and editing
#
# ### Research & Analysis
# - Peer review systems for research papers
# - Multi-analyst financial analysis
# - Collaborative report writing and fact-checking
# - Academic paper review and improvement
#
# ### Creative Collaboration
# - Content creation wit editors and reviewers
# - Multi-perspective creative brainstorming
# - Step by step design and feedback systems
# - Collaborative storytelling and world-building
#
# Ready to make smart multi-agent collaborations? Make we build systems wey agents go dey work together like beta team! 🌟🤖

# %%
! pip install agent-framework-core -U

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent

# %%
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings

# %%
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# Workflow output: Visit the Louvre Museum for an unparalleled art experience.

# %% [markdown]
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Disclaimer**:
# Dis dokyument don use AI translation service [Co-op Translator](https://github.com/Azure/co-op-translator) do di translation. Even as we dey try make am correct, abeg sabi say machine translation fit get mistake or no dey accurate well. Di original dokyument wey dey for im native language na di main source wey you go trust. For important information, e better make professional human translation dey use. We no go fit take blame for any misunderstanding or wrong interpretation wey fit happen because you use dis translation.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
