# %% [markdown]
# # 🛠️ GitHub മോഡലുകൾ ഉപയോഗിച്ച് ഉയർന്ന തലത്തിലുള്ള ടൂൾ ഉപയോഗം (Python)
#
# ## 📋 പഠന ലക്ഷ്യങ്ങൾ
#
# ഈ നോട്ട്‌ബുക്ക് Microsoft Agent Framework ഉപയോഗിച്ച് GitHub മോഡലുകൾ ഉപയോഗിച്ച് ഉയർന്ന തലത്തിലുള്ള ടൂൾ ഇന്റഗ്രേഷൻ മാതൃകകൾ പ്രദർശിപ്പിക്കുന്നു. നിരവധി ടൂളുകൾ സൃഷ്ടിച്ച്, നിയന്ത്രിച്ച്, ഏകീകരിച്ച്, സങ്കീർണ്ണമായ ഏജന്റ് കഴിവുകൾ നിർമ്മിക്കുന്നതിനെക്കുറിച്ച് നിങ്ങൾ പഠിക്കും.
#
# **നിങ്ങൾ കൈവരിക്കുന്നതെന്താണ്:**
# - 🔧 **മൾട്ടി-ടൂൾ ആർക്കിടെക്ചർ**: നിരവധി പ്രത്യേക ടൂളുകളുള്ള ഏജന്റുമാരെ നിർമ്മിക്കൽ
# - 🎯 **ടൂൾ തിരഞ്ഞെടുക്കൽ ലജിക്**: ഓരോ ജോലിക്കും ശരിയായ ടൂൾ എങ്ങനെ തിരഞ്ഞെടുക്കാം
# - 📊 **ഡാറ്റാ പ്രോസസ്സിംഗ് ടൂളുകൾ**: വ്യത്യസ്ത ഡാറ്റാ തരം കൈകാര്യം ചെയ്യുന്ന ടൂളുകൾ സൃഷ്ടിക്കൽ
# - 🔗 **ടൂൾ കോമ്പോസിഷൻ**: സങ്കീർണ്ണമായ പ്രവൃത്തികൾക്കായി ടൂളുകൾ സംയോജിപ്പിക്കൽ
#
# ## 🎯 പ്രധാന ടൂൾ മാതൃകകൾ
#
# ### ടൂൾ ഡിസൈൻ പ്രിൻസിപ്പിളുകൾ
# - **സിംഗിൾ റെസ്പോൺസിബിലിറ്റി**: ഓരോ ടൂളിനും വ്യക്തമായ, കേന്ദ്രീകൃത ലക്ഷ്യം
# - **ടൈപ്പ് സേഫ്റ്റി**: വിശ്വസനീയമായ ടൂൾ പ്രവർത്തനത്തിനായി ശക്തമായ ടൈപ്പിംഗ്
# - **എറർ ഹാൻഡ്ലിംഗ്**: സുന്ദരമായ പരാജയവും വീണ്ടെടുക്കൽ മാതൃകകളും
# - **കോമ്പോസബിലിറ്റി**: പരസ്പരം നല്ല രീതിയിൽ പ്രവർത്തിക്കുന്ന ടൂളുകൾ
#
# ### ഉയർന്ന തലത്തിലുള്ള ടൂൾ സവിശേഷതകൾ
# - **കോണ്റ്റെക്സ്റ്റ് അവരനസ്**: സംഭാഷണ സാഹചര്യത്തെ മനസ്സിലാക്കുന്ന ടൂളുകൾ
# - **ഡാറ്റാ വാലിഡേഷൻ**: ഇൻപുട്ട് ശുദ്ധീകരണവും ഔട്ട്പുട്ട് പരിശോധനയും
# - **പെർഫോമൻസ് ഓപ്റ്റിമൈസേഷൻ**: കാര്യക്ഷമമായ ടൂൾ പ്രവർത്തന മാതൃകകൾ
# - **എക്സ്റ്റെൻസിബിലിറ്റി**: പുതിയ ടൂൾ കഴിവുകൾ എളുപ്പത്തിൽ ചേർക്കുക
#
# ## 🔧 സാങ്കേതിക ആർക്കിടെക്ചർ
#
# ### പ്രധാന ഘടകങ്ങൾ
# - **Microsoft Agent Framework**: ഉയർന്ന തലത്തിലുള്ള ടൂൾ പിന്തുണയുള്ള Python നടപ്പാക്കൽ
# - **GitHub Models Integration**: ഉയർന്ന പ്രകടനമുള്ള ഭാഷാ മോഡൽ ആക്സസ്
# - **Tool Registry System**: ഏജന്റ് കഴിവുകളുടെ ക്രമീകരിച്ച മാനേജ്മെന്റ്
# - **Error Recovery Patterns**: ടൂൾ പ്രവർത്തന പരാജയങ്ങൾ ശക്തമായി കൈകാര്യം ചെയ്യൽ
#
# ### ടൂൾ ഇന്റഗ്രേഷൻ ഫ്ലോ
# ```python
# User Request → Agent Analysis → Tool Selection → Tool Execution → Response Synthesis
# ```
#
# ## 🛠️ പ്രദർശിപ്പിച്ച ടൂൾ വിഭാഗങ്ങൾ
#
# ### 1. **ഡാറ്റാ ജനറേഷൻ ടൂളുകൾ**
# - റാൻഡം ഡെസ്റ്റിനേഷൻ ജനറേറ്റർ
# - കാലാവസ്ഥാ വിവരങ്ങൾ നൽകുന്ന ടൂൾ
# - യാത്ര ചെലവ് കണക്കാക്കുന്ന ടൂൾ
# - പ്രവർത്തന ശുപാർശ എഞ്ചിൻ
#
# ### 2. **പ്രോസസ്സിംഗ് ടൂളുകൾ**
# - ടെക്സ്റ്റ് ഫോർമാറ്റിംഗ്, വാലിഡേഷൻ
# - ഡാറ്റാ ട്രാൻസ്ഫോർമേഷൻ ഉപകരണങ്ങൾ
# - ഉള്ളടക്കം വിശകലന ഫംഗ്ഷനുകൾ
# - പ്രതികരണ മെച്ചപ്പെടുത്തൽ ടൂളുകൾ
#
# ### 3. **ഇന്റഗ്രേഷൻ ടൂളുകൾ**
# - ബാഹ്യ API കണക്റ്ററുകൾ
# - ഫയൽ സിസ്റ്റം പ്രവർത്തനങ്ങൾ
# - ഡാറ്റാബേസ് ക്വറി ഇന്റർഫേസുകൾ
# - വെബ് സ്ക്രാപ്പിംഗ് ഉപകരണങ്ങൾ
#
# ## ⚙️ മുൻകൂർ ആവശ്യങ്ങൾ & സജ്ജീകരണം
#
# **ആവശ്യമായ ഡിപെൻഡൻസികൾ:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **പരിസ്ഥിതി കോൺഫിഗറേഷൻ (.env ഫയൽ):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **ഓപ്ഷണൽ APIകൾ:**
# - കാലാവസ്ഥാ സേവന API കീ (കാലാവസ്ഥാ ടൂളുകൾക്കായി)
# - കറൻസി കൺവേഴ്ഷൻ API ആക്സസ്
# - യാത്രാ വിവര സേവന ക്രെഡൻഷ്യലുകൾ
#
# ## 🎨 ഡിസൈൻ മാതൃകകൾ
#
# ### Tool Factory Pattern
# - ടൂൾ സൃഷ്ടിയും കോൺഫിഗറേഷനും കേന്ദ്രീകരിച്ച രീതിയിൽ
# - സ്ഥിരതയുള്ള ടൂൾ ഇന്റർഫേസ് ഡിസൈൻ
# - ടൂൾ രജിസ്ട്രേഷൻ, കണ്ടെത്തൽ എളുപ്പത്തിൽ
#
# ### Command Pattern
# - ടൂൾ പ്രവർത്തന ലജിക് എൻകാപ്സുലേറ്റ് ചെയ്യുക
# - സങ്കീർണ്ണമായ പ്രവർത്തനങ്ങൾക്ക് Undo/Redo ഫംഗ്ഷനാലിറ്റി
# - ടൂൾ ഉപയോഗത്തിനുള്ള ഓഡിറ്റ് ലോഗിംഗ്
#
# ### Observer Pattern
# - ടൂൾ പ്രവർത്തന നിരീക്ഷണം
# - പ്രകടന മെട്രിക് ശേഖരണം
# - പിഴവുകൾ റിപ്പോർട്ട് ചെയ്യൽ, അലർട്ടുകൾ
#
# ## 🚀 മികച്ച രീതികൾ
#
# - **ടൂൾ ഡോക്യുമെന്റേഷൻ**: ഏജന്റുമാർക്ക് വ്യക്തമായ വിവരണങ്ങൾ
# - **ഇൻപുട്ട് വാലിഡേഷൻ**: ശക്തമായ പാരാമീറ്റർ പരിശോധനയും ശുദ്ധീകരണവും
# - **ഔട്ട്പുട്ട് ഫോർമാറ്റിംഗ്**: സ്ഥിരതയുള്ള, പാഴ്സുചെയ്യാവുന്ന ടൂൾ പ്രതികരണങ്ങൾ
# - **എറർ മെസേജുകൾ**: ഡീബഗിംഗിനുള്ള സഹായകരമായ പിഴവു വിവരങ്ങൾ
# - **പെർഫോമൻസ്**: പ്രതികരണക്ഷമതയ്ക്കായി ടൂൾ പ്രവർത്തനം മെച്ചപ്പെടുത്തുക
#
# ശക്തമായ ടൂൾ കഴിവുകളുള്ള ഏജന്റുമാരെ നിർമ്മിക്കാൻ തയ്യാറാണോ? അത്ഭുതകരമായ ഒന്നിനെ സൃഷ്ടിക്കാം! ⚡

# %%
! pip install agent-framework-core -U

# %%
# � Import core dependencies for Agent Framework and tool integration
# This sets up the essential libraries for building intelligent agents with tool capabilities

import asyncio
import os
import json

from dotenv import load_dotenv  # For loading environment variables securely
from random import randint

# These are the core components for building tool-enabled agents
from agent_framework import ChatAgent           # Main agent class
from agent_framework.openai import OpenAIChatClient  # OpenAI-compatible client

# %%
load_dotenv()

# %%
# 🔑 Environment variables verification
# Ensure all required GitHub Models credentials are properly configured
print("GITHUB_ENDPOINT:", os.environ.get("GITHUB_ENDPOINT"))
print("GITHUB_TOKEN:", "***" if os.environ.get("GITHUB_TOKEN") else "Not set")
print("GITHUB_MODEL_ID:", os.environ.get("GITHUB_MODEL_ID"))

# %%
# 🧪 Test GitHub Models connectivity
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
# 🛠️ Define travel planning tools for agent integration
# These functions provide specific capabilities that the agent can invoke dynamically

def get_random_destination() -> str:
    """
    🎲 Random destination generator tool
    Returns a randomly selected travel destination from curated list
    Useful when customers need inspiration for their next vacation
    """
    destinations = [
        "Paris, France",
        "Tokyo, Japan", 
        "New York City, USA",
        "London, England",
        "Rome, Italy",
        "Sydney, Australia",
        "Dubai, UAE",
        "Barcelona, Spain",
        "Bangkok, Thailand",
        "Amsterdam, Netherlands",
        "Istanbul, Turkey",
        "Prague, Czech Republic",
        "Santorini, Greece",
        "Reykjavik, Iceland",
        "Marrakech, Morocco",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # 🎯 Return random selection from the curated destination list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Initialize GitHub Models chat client for agent communication
# Creates the primary interface between the agent and the language model
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
# 🤖 Configure travel agent identity and behavioral instructions
# Define the agent's personality, capabilities, and operational guidelines

AGENT_NAME = "TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers at random destinations
"""

# %%
agent = ChatAgent(
        name = AGENT_NAME,
        chat_client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അസത്യവാദം**:
# ഈ രേഖ AI വിവർത്തന സേവനമായ [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് വിവർത്തനം ചെയ്തതാണ്. കൃത്യതയ്ക്കായി ഞങ്ങൾ ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് വിവർത്തനങ്ങളിൽ പിശകുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള മൗലിക രേഖയാണ് വിശ്വസനീയമായ ഉറവിടമായി കണക്കാക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മാനവ വിവർത്തനം ശുപാർശ ചെയ്യുന്നു. ഈ വിവർത്തനം ഉപയോഗിക്കുന്നതിൽ നിന്നുണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾക്കോ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കോ ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
