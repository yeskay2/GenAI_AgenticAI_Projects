# %% [markdown]
# ## **സാമ്പിളുകൾ: ഹോട്ടൽ ബുക്കിംഗിനുള്ള മൾട്ടി-എഐ ഏജന്റുകൾ**
#
# ഇന്നത്തെ വേഗതയേറിയ ലോകത്ത്, ഒരു ബിസിനസ് യാത്രയുടെ പദ്ധതി തയ്യാറാക്കുന്നത് വെറും വിമാന ടിക്കറ്റ് ബുക്ക് ചെയ്യുന്നതിലും ഹോട്ടൽ മുറി ബുക്ക് ചെയ്യുന്നതിലും മാത്രമല്ല. ഇത് ഒരു കോർഡിനേഷൻ നിലവാരവും കാര്യക്ഷമതയും ആവശ്യപ്പെടുന്ന ഒരു പ്രക്രിയയാണ്, ഇത് കൈകാര്യം ചെയ്യുന്നത് ചിലപ്പോൾ വെല്ലുവിളിപൂർണ്ണമാകാം. ഇവിടെ മൾട്ടി-എഐ ഏജന്റുകൾ രംഗപ്രവേശനം ചെയ്യുന്നു, നമ്മുടെ യാത്രാ ആവശ്യങ്ങൾ കൈകാര്യം ചെയ്യുന്നതിൽ വിപ്ലവകരമായ മാറ്റം കൊണ്ടുവരികയാണ്.
#
# നിങ്ങളുടെ യാത്രയുടെ എല്ലാ ഘടകങ്ങളും കൃത്യതയോടും എളുപ്പത്തോടും കൈകാര്യം ചെയ്യാൻ ഒരുമിച്ച് പ്രവർത്തിക്കുന്ന ബുദ്ധിമാനായ ഏജന്റുകളുടെ ഒരു ടീം നിങ്ങളുടെ സേവനത്തിനായി ഉണ്ടെന്ന് ചിന്തിക്കുക. ഞങ്ങളുടെ പുരോഗതിയായ എഐ സാങ്കേതികവിദ്യ ഉപയോഗിച്ച്, ബുക്കിംഗ് സേവനങ്ങൾക്കും യാത്രാ ക്രമീകരണത്തിനുമായി പ്രത്യേകിച്ചുള്ള ഏജന്റുകളെ സൃഷ്ടിച്ചിരിക്കുന്നു, ഒരു മിനുക്കിയതും സമ്മർദ്ദരഹിതവുമായ യാത്രാ അനുഭവം ഉറപ്പാക്കുന്നു.
#
# ഇത് ഒരു അടിസ്ഥാന സാഹചര്യമാണ്. ഒരു ബിസിനസ് യാത്രയുടെ പദ്ധതി തയ്യാറാക്കുമ്പോൾ, വിമാന ടിക്കറ്റ് വിവരങ്ങളും ഹോട്ടൽ വിവരങ്ങളും ലഭ്യമാക്കാൻ ഒരു ബിസിനസ് ട്രാവൽ ഏജന്റുമായി ആലോചിക്കേണ്ടതുണ്ട്. എഐ ഏജന്റുകൾ വഴി, ബുക്കിംഗ് സേവനങ്ങൾക്കായും യാത്രാ ക്രമീകരണത്തിനായും ഏജന്റുകളെ നിർമ്മിച്ച് സഹകരിക്കുകയും ബുദ്ധിമുട്ടിന്റെ നിലവാരം മെച്ചപ്പെടുത്തുകയും ചെയ്യാം.

# %% [markdown]
# # Azure AI ഏജന്റ് സേവനം ആരംഭിക്കുക, **.env** ഫയലിൽ നിന്ന് കോൺഫിഗറേഷൻ വിവരങ്ങൾ നേടുക
#
# ### **.env**
#
# ഒരു .env ഫയൽ സൃഷ്ടിക്കുക
#
# **.env** ഫയലിൽ Azure AI ഏജന്റ് സേവനത്തിന്റെ കണക്ഷൻ സ്ട്രിംഗ്, AOAI ഉപയോഗിക്കുന്ന മോഡൽ, അനുബന്ധ Google API Search സേവന API, ENDPOINT തുടങ്ങിയവ ഉൾപ്പെടുന്നു.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "നിങ്ങളുടെ Azure AI ഏജന്റ് സേവന മോഡൽ ഡിപ്ലോയ്മെന്റ് നാമം"
#
# [**NOTE**] നിങ്ങൾക്ക് 100,000 റേറ്റ് ലിമിറ്റ് (മിനിറ്റിൽ ടോക്കൺസ്) 600 റേറ്റ് ലിമിറ്റ് (മിനിറ്റിൽ അഭ്യർത്ഥനകൾ) ഉള്ള ഒരു മോഡൽ ആവശ്യമുണ്ട്.
#
#   നിങ്ങൾക്ക് Azure AI Foundry - Model and Endpoint-ൽ മോഡൽ ലഭിക്കും.
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "നിങ്ങളുടെ Azure AI ഏജന്റ് സേവന പ്രോജക്റ്റ് കണക്ഷൻ സ്ട്രിംഗ്"
#
#   നിങ്ങൾക്ക് AI Foundry Portal സ്ക്രീനിലെ പ്രോജക്റ്റ് ഓവർവ്യൂയിൽ നിന്ന് പ്രോജക്റ്റ് കണക്ഷൻ സ്ട്രിംഗ് ലഭിക്കും.
#
# - **SERPAPI_SEARCH_API_KEY** = "നിങ്ങളുടെ SERPAPI Search API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "നിങ്ങളുടെ SERPAPI Search Endpoint"
#
# Azure AI ഏജന്റ് സേവനത്തിന്റെ മോഡൽ ഡിപ്ലോയ്മെന്റ് നാമവും പ്രോജക്റ്റ് കണക്ഷൻ സ്ട്രിംഗും ലഭിക്കാൻ, നിങ്ങൾക്ക് Azure AI ഏജന്റ് സേവനം സൃഷ്ടിക്കേണ്ടതുണ്ട്. ഇത് നേരിട്ട് സൃഷ്ടിക്കാൻ [ഈ ടെംപ്ലേറ്റ്](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) ഉപയോഗിക്കാൻ ശുപാർശ ചെയ്യുന്നു （***ശ്രദ്ധിക്കുക:*** Azure AI ഏജന്റ് സേവനം നിലവിൽ പരിമിതമായ പ്രദേശങ്ങളിൽ സജ്ജീകരിച്ചിരിക്കുന്നു. പ്രദേശം സജ്ജീകരിക്കാൻ [ഈ ലിങ്ക്](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) കാണുക).
#
# ഏജന്റിന് SERPAPI ആക്സസ് ചെയ്യേണ്ടതുണ്ട്. [ഈ ലിങ്ക്](https://serpapi.com/searches) ഉപയോഗിച്ച് രജിസ്റ്റർ ചെയ്യാൻ ശുപാർശ ചെയ്യുന്നു. രജിസ്ട്രേഷൻ കഴിഞ്ഞാൽ, നിങ്ങൾക്ക് ഒരു യുണീക് API KEYയും ENDPOINTയും ലഭിക്കും.

# %% [markdown]
# # ആസ്യൂറിലേക്ക് ലോഗിൻ ചെയ്യുക
#
# ഇപ്പോൾ നിങ്ങൾ ആസ്യൂറിലേക്ക് ലോഗിൻ ചെയ്യേണ്ടതുണ്ട്. VScode-ൽ ഒരു ടെർമിനൽ തുറന്ന് `az login` കമാൻഡ് റൺ ചെയ്യുക.

# %% [markdown]
# # സജ്ജീകരണം
#
# ഈ നോട്ട്‌ബുക്ക് പ്രവർത്തിപ്പിക്കാൻ, നിങ്ങൾക്ക് താഴെ പറയുന്ന ലൈബ്രറികൾ ഇൻസ്റ്റാൾ ചെയ്യേണ്ടതുണ്ട്. ആവശ്യമായ ലൈബ്രറികളുടെ പട്ടികയും അനുബന്ധ പിപ് ഇൻസ്റ്റാൾ കമാൻഡുകളും ഇവിടെ നൽകിയിരിക്കുന്നു:
#
# azure-identity: Azure ഓത്തന്റിക്കേഷൻക്കായി.
# requests: HTTP അഭ്യർത്ഥനകൾ നടത്താൻ.
# semantic-kernel: സെമാന്റിക് കർണൽ ഫ്രെയിംവർക്കിനായി (ഇത് ഒരു കസ്റ്റം അല്ലെങ്കിൽ പ്രത്യേക ലൈബ്രറി ആണെന്ന് കരുതുമ്പോൾ, നിങ്ങൾക്ക് ഇത് ഒരു പ്രത്യേക സോഴ്‌സിൽ നിന്ന് അല്ലെങ്കിൽ റിപോസിറ്ററിയിൽ നിന്ന് ഇൻസ്റ്റാൾ ചെയ്യേണ്ടതുണ്ടാകാം).

# %%
# !pip install azure-identity
# !pip install requests
# !pip install semantic-kernel
# !pip install --upgrade semantic_kernel
# !pip install azure-cli

# %% [markdown]
# # വിശദീകരണം:
# import asyncio: ഇത് asyncio മോഡ്യൂൾ ഇറക്കുമതി ചെയ്യുന്നു, Python-ൽ അസിങ്ക്രോണസ് പ്രോഗ്രാമിംഗിന് പിന്തുണ നൽകുന്നു. async, await സിന്റാക്സ് ഉപയോഗിച്ച് സമകാലിക കോഡ് എഴുതാൻ ഇത് സഹായിക്കുന്നു.
# from typing: Annotated: ഇത് typing മോഡ്യൂളിൽ നിന്ന് Annotated ടൈപ്പ് ഇറക്കുമതി ചെയ്യുന്നു. Annotated ടൈപ്പ് ഹിന്റുകളിൽ മെറ്റാഡാറ്റ ചേർക്കാൻ ഉപയോഗിക്കുന്നു, ഇത് സാധൂകരണം, ഡോക്യുമെന്റേഷൻ, അല്ലെങ്കിൽ ടൂളിംഗ് പോലുള്ള വിവിധ ആവശ്യങ്ങൾക്ക് ഉപകാരപ്രദമാകാം.

# %%
import asyncio,os
from typing import Annotated

# %% [markdown]
# # വിശദീകരണം:
# `from dotenv import load_dotenv` ഉപയോഗിച്ച് `load_dotenv()` ഉപയോഗിക്കുമ്പോൾ, .env ഫയലിൽ കോൺഫിഗറേഷൻ ക്രമീകരണങ്ങളും സങ്കേതമായ വിവരങ്ങളും (ഉദാ: API കീകൾ, ഡാറ്റാബേസ് URLs) എളുപ്പത്തിൽ കൈകാര്യം ചെയ്യാം. ഇത് അവയെ നിങ്ങളുടെ സോഴ്‌സ് കോഡിൽ നിന്ന് വേർതിരിച്ച് സൂക്ഷിക്കുകയും, നിങ്ങളുടെ ആപ്ലിക്കേഷൻ കൂടുതൽ സുരക്ഷിതവും ക്രമീകരിക്കാൻ എളുപ്പവുമാക്കുകയും ചെയ്യുന്നു.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # വിശദീകരണം:
#
# ഇമ്പോർട്ട് സ്റ്റേറ്റ്മെന്റ്: from azure.identity.aio import DefaultAzureCredential: ഇത് azure.identity.aio മോഡ്യൂളിൽ നിന്ന് DefaultAzureCredential ക്ലാസ് ഇമ്പോർട്ട് ചെയ്യുന്നു. മോഡ്യൂളിന്റെ പേരിൽ ഉള്ള aio ഭാഗം ഇത് അസിങ്ക്രോണസ് ഓപ്പറേഷനുകൾക്കായി രൂപകൽപ്പന ചെയ്തതാണെന്ന് സൂചിപ്പിക്കുന്നു.
#
# DefaultAzureCredential ന്റെ ഉദ്ദേശ്യം: DefaultAzureCredential ക്ലാസ് Azure SDK for Python ന്റെ ഭാഗമാണ്. ഇത് Azure സേവനങ്ങളുമായി പ്രാമാണീകരണം നടത്താനുള്ള ഒരു ഡിഫോൾട്ട് മാർഗം നൽകുന്നു. ഇത് പരിസ്ഥിതി വേരിയബിളുകൾ, മാനേജ്ഡ് ഐഡന്റിറ്റി, Azure CLI ക്രെഡൻഷ്യലുകൾ എന്നിവ പോലുള്ള നിരവധി രീതികൾ ഒരു പ്രത്യേക ക്രമത്തിൽ ഉപയോഗിച്ച് പ്രാമാണീകരണം നടത്താൻ ശ്രമിക്കുന്നു.
#
# അസിങ്ക്രോണസ് ഓപ്പറേഷനുകൾ: aio മോഡ്യൂൾ DefaultAzureCredential ക്ലാസ് അസിങ്ക്രോണസ് ഓപ്പറേഷനുകൾ പിന്തുണയ്ക്കുന്നതായി സൂചിപ്പിക്കുന്നു. ഇതിന്റെ അർത്ഥം, നിങ്ങൾ asyncio ഉപയോഗിച്ച് ബ്ലോക്ക് ചെയ്യാത്ത പ്രാമാണീകരണ അഭ്യർത്ഥനകൾ നടത്താൻ ഇതിനെ ഉപയോഗിക്കാം.

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # വിശദീകരണം:
# `semantic_kernel` പാക്കേജിൽ നിന്ന് വിവിധ മോഡ്യൂളുകളും ക്ലാസുകളും ഇറക്കുമതി ചെയ്യുന്നു. ഓരോ ഇറക്കുമതിയുടെയും വിശദീകരണം താഴെ കൊടുത്തിരിക്കുന്നു:
#
# `semantic_kernel.agents`-ൽ നിന്ന് `AgentGroupChat`: AI ഏജന്റുകൾക്കായുള്ള ഗ്രൂപ്പ് ചാറ്റുമായി ബന്ധപ്പെട്ട പ്രവർത്തനങ്ങൾ കൈകാര്യം ചെയ്യാൻ ഈ ക്ലാസ് ഉപയോഗിക്കുന്നു. `semantic_kernel.agents.azure_ai`-ൽ നിന്ന് `AzureAIAgent`യും `AzureAIAgentSettings`ഉം:
#
# - `AzureAIAgent`: Azure AI സേവനങ്ങൾ ഉപയോഗിക്കുന്ന AI ഏജന്റുകൾ സൃഷ്ടിക്കാനും നിയന്ത്രിക്കാനും ഈ ക്ലാസ് ഉപയോഗിക്കുന്നു.
# - `AzureAIAgentSettings`: `AzureAIAgent`-നുള്ള ക്രമീകരണങ്ങൾ കോൺഫിഗർ ചെയ്യാൻ ഈ ക്ലാസ് ഉപയോഗിക്കുന്നു.
#
# `semantic_kernel.agents.strategies.termination.termination_strategy`-ൽ നിന്ന് `TerminationStrategy`:
#
# - ഈ ക്ലാസ്, ചില സാഹചര്യങ്ങളിൽ AI ഏജന്റുകളുടെ പ്രവർത്തനം അവസാനിപ്പിക്കുന്നതിനുള്ള തന്ത്രങ്ങൾ നിർവചിക്കുന്നു.
#
# `semantic_kernel.contents.chat_message_content`-ൽ നിന്ന് `ChatMessageContent`:
#
# - ചാറ്റ് സന്ദേശങ്ങളുടെ ഉള്ളടക്കം കൈകാര്യം ചെയ്യാൻ ഈ ക്ലാസ് ഉപയോഗിക്കുന്നു.
#
# `semantic_kernel.contents.utils.author_role`-ൽ നിന്ന് `AuthorRole`:
#
# - ചാറ്റ് സന്ദേശങ്ങളുടെ സന്ദർഭത്തിൽ എഴുത്തുകാരുടെ വ്യത്യസ്ത വേഷങ്ങൾ നിർവചിക്കാൻ ഈ ക്ലാസ് ഉപയോഗിക്കുന്നു.
#
# `semantic_kernel.functions.kernel_function_decorator`-ൽ നിന്ന് `kernel_function`:
#
# - സെമാന്റിക് കർണൽ ഫ്രെയിംവർക്കിനുള്ളിൽ പ്രവർത്തിപ്പിക്കാവുന്ന ഫംഗ്ഷനുകൾ നിർവചിക്കാൻ ഈ ഡെക്കറേറ്റർ ഉപയോഗിക്കുന്നു.
#
# ഈ ഇറക്കുമതികൾ, ഗ്രൂപ്പ് ചാറ്റ് പരിസ്ഥിതിയിൽ സംവദിക്കാൻ കഴിയുന്ന AI ഏജന്റുകൾ സൃഷ്ടിക്കാനും നിയന്ത്രിക്കാനും ആവശ്യമായ ഘടകങ്ങൾ സജ്ജമാക്കുന്നു. ഉദാഹരണത്തിന്, ഹോട്ടൽ ബുക്കിംഗ് പോലുള്ള പ്രവർത്തനങ്ങൾക്കായി ഇത് ഉപയോഗിക്കാം.

# %%
from semantic_kernel.agents import AgentGroupChat
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.agents.strategies.termination.termination_strategy import TerminationStrategy
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.contents import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# %% [markdown]
# # വിശദീകരണം:
# അടുത്തതായി, azure.ai.projects.models മോഡ്യൂലിൽ നിന്ന് CodeInterpreterTool ക്ലാസ് ഇറക്കുമതി ചെയ്യുന്നു.
#
# CodeInterpreterTool: ഈ ക്ലാസ് Azure AI SDKയുടെ ഭാഗമാണ്, AI പ്രോജക്റ്റുകളുടെ പ്ര_CONTEXT_ത്തിൽ കോഡ് വ്യാഖ്യാനിക്കുകയും പ്രവർത്തിപ്പിക്കുകയും ചെയ്യാൻ ഉപയോഗിക്കുന്നു. കോഡ് സ്നിപ്പറ്റുകൾ പ്രവർത്തിപ്പിക്കൽ, കോഡ് വിശകലനം, അല്ലെങ്കിൽ AI പ്രവാഹങ്ങളിൽ കോഡ് പ്രവർത്തനം സംയോജിപ്പിക്കൽ എന്നിവയ്ക്കുള്ള സൗകര്യങ്ങൾ ഇത് നൽകുന്നു.
# ഈ ഇറക്കുമതി നിങ്ങളുടെ പ്രോജക്റ്റിൽ CodeInterpreterTool ഉപയോഗിക്കുന്നതിന് ആവശ്യമായ ഘടകം സജ്ജമാക്കുന്നു, കോഡ് ഡൈനാമിക് ആയി വ്യാഖ്യാനിക്കുകയും പ്രവർത്തിപ്പിക്കുകയും ചെയ്യുന്ന പ്രവർത്തനങ്ങൾക്കായി ഇത് ഉപകാരപ്രദമാകാം.

# %%
from azure.ai.projects.models import CodeInterpreterTool

# %% [markdown]
# # വിശദീകരണം:
# ApprovalTerminationStrategy ക്ലാസ് ഒരു പ്രത്യേക തന്ത്രം നൽകുന്നു, അത് AI ഏജന്റിന്റെ പ്രവർത്തനം അവസാനിപ്പിക്കുന്നതിന് ഉപയോഗിക്കുന്നു. ഏജന്റിന്റെ ഇടപെടൽ ചരിത്രത്തിലെ അവസാന സന്ദേശത്തിൽ "saved" എന്ന വാക്ക് ഉൾക്കൊള്ളുന്നുവെങ്കിൽ ഏജന്റ് പ്രവർത്തനം അവസാനിപ്പിക്കും. ഏജന്റിന്റെ പണി "saved" എന്ന സ്ഥിരീകരണം ലഭിച്ചാൽ പൂർത്തിയായതായി കണക്കാക്കുന്ന സാഹചര്യങ്ങളിൽ ഇത് പ്രയോജനപ്രദമായിരിക്കും. ഇടപെടൽ രീതി നിർവചിക്കുക. റിസർവേഷൻ പ്ലാൻ സേവ് ചെയ്ത ശേഷം, സേവ് ചെയ്ത സിഗ്നൽ ലഭിക്കുമ്പോൾ അത് നിർത്താം.

# %%
class ApprovalTerminationStrategy(TerminationStrategy):
    """A strategy for determining when an agent should terminate."""

    async def should_agent_terminate(self, agent, history):
        """Check if the agent should terminate."""
        return "saved" in history[-1].content.lower()

# %% [markdown]
# # വിശദീകരണം:
#
# ഈ കോഡ് ലൈനിൽ create() മെത്തഡ് വിളിച്ച് ഡിഫോൾട്ട് അല്ലെങ്കിൽ മുൻകൂട്ടി നിർവചിച്ച സെറ്റിംഗുകളോടെ AzureAIAgentSettings ഒബ്ജക്റ്റ് ഇൻഷിയലൈസ് ചെയ്യുന്നു. ഈ സെറ്റിംഗ്സ് ഒബ്ജക്റ്റ് (ai_agent_settings) AzureAIAgent ഇൻസ്റ്റൻസ് കോൺഫിഗർ ചെയ്യാനും മാനേജുചെയ്യാനും ഉപയോഗിക്കാം.

# %%
ai_agent_settings = AzureAIAgentSettings.create()

# %% [markdown]
# # വിശദീകരണം:
# requests ലൈബ്രറി ഇറക്കുമതി ചെയ്യുന്നതിലൂടെ, Python കോഡിൽ HTTP അഭ്യർത്ഥനകൾ എളുപ്പത്തിൽ നടത്തുകയും വെബ് സേവനങ്ങളുമായി ഇടപഴകുകയും ചെയ്യാം.

# %%
import requests

# %% [markdown]
# # വിശദീകരണം:
# SERP (Search Engine Results Page) API സേവനം ആക്സസ് ചെയ്യുന്നതിനുള്ള API കീ സംഭരിക്കുന്ന ഒരു വേരിയബിൾ ആണ് ഇത്. API കീ നിങ്ങളുടെ അക്കൗണ്ടുമായി ബന്ധപ്പെട്ട അഭ്യർത്ഥനകൾ പ്രാമാണീകരിക്കാൻ ഉപയോഗിക്കുന്ന ഒരു പ്രത്യേക ഐഡന്റിഫയർ ആണ്.
#
# 'GOOGLE_SEARCH_API_KEY': ഇത് ഒരു പ്ലേസ്‌ഹോൾഡർ സ്ട്രിംഗ് ആണ്. 'GOOGLE_SEARCH_API_KEY' നിങ്ങളുടെ യഥാർത്ഥ SERP API കീ ഉപയോഗിച്ച് മാറ്റിസ്ഥാപിക്കേണ്ടതുണ്ട്.
#
# ഉദ്ദേശ്യം: ഈ വരിയുടെ ഉദ്ദേശ്യം API കീ ഒരു വേരിയബിൾ ആയി സംഭരിച്ച് SERP API സേവനത്തിലേക്ക് അഭ്യർത്ഥനകൾ പ്രാമാണീകരിക്കാൻ ഉപയോഗിക്കുക എന്നതാണ്. API സേവനം ആക്സസ് ചെയ്യാനും തിരയലുകൾ നടത്താനും API കീ ആവശ്യമാണ്.
#
# SERP API കീ എങ്ങനെ നേടാം: SERP API കീ നേടാൻ, https://serpapi.com എന്ന വെബ്സൈറ്റിൽ താഴെ പറയുന്ന പൊതുവായ ഘട്ടങ്ങൾ പിന്തുടരുക (നിങ്ങൾ ഉപയോഗിക്കുന്ന പ്രത്യേക SERP API സേവനത്തിന്റെ അടിസ്ഥാനത്തിൽ കൃത്യമായ ഘട്ടങ്ങൾ വ്യത്യാസപ്പെടാം):
#
# SERP API സേവനം തിരഞ്ഞെടുക്കുക: SerpAPI, Google Custom Search JSON API തുടങ്ങിയ നിരവധി SERP API സേവനങ്ങൾ ലഭ്യമാണ്. നിങ്ങളുടെ ആവശ്യങ്ങൾക്ക് ഏറ്റവും അനുയോജ്യമായത് തിരഞ്ഞെടുക്കുക.
#
# അക്കൗണ്ടിന് സൈൻ അപ്പ് ചെയ്യുക:
#
# തിരഞ്ഞെടുത്ത SERP API സേവനത്തിന്റെ വെബ്സൈറ്റിലേക്ക് https://www.serpapi.com പോകുക, അക്കൗണ്ടിന് സൈൻ അപ്പ് ചെയ്യുക. നിങ്ങൾക്ക് ചില അടിസ്ഥാന വിവരങ്ങൾ നൽകുകയും നിങ്ങളുടെ ഇമെയിൽ വിലാസം സ്ഥിരീകരിക്കുകയും ചെയ്യേണ്ടിവരും.
#
# API കീ സൃഷ്ടിക്കുക:
#
# സൈൻ അപ്പ് ചെയ്ത ശേഷം, നിങ്ങളുടെ അക്കൗണ്ടിൽ ലോഗിൻ ചെയ്ത് API വിഭാഗത്തിലേക്ക് അല്ലെങ്കിൽ ഡാഷ്‌ബോർഡിലേക്ക് പോകുക. പുതിയ API കീ സൃഷ്ടിക്കാനോ ജനറേറ്റ് ചെയ്യാനോ ഉള്ള ഓപ്ഷൻ കണ്ടെത്തുക.
# API കീ കോപ്പി ചെയ്യുക:
#
# API കീ ജനറേറ്റ് ചെയ്ത ശേഷം, അത് കോപ്പി ചെയ്യുക. ഈ കീ SERP API സേവനത്തിലേക്ക് നിങ്ങളുടെ അഭ്യർത്ഥനകൾ പ്രാമാണീകരിക്കാൻ ഉപയോഗിക്കും.
# പ്ലേസ്‌ഹോൾഡർ മാറ്റുക:
#
# നിങ്ങളുടെ .env ഫയലിൽ പ്ലേസ്‌ഹോൾഡർ മാറ്റിസ്ഥാപിക്കുക

# %%
SERPAPI_SEARCH_API_KEY=os.getenv('SERPAPI_SEARCH_API_KEY')

# %%
SERPAPI_SEARCH_ENDPOINT = os.getenv('SERPAPI_SEARCH_ENDPOINT')

# %% [markdown]
# # വിശദീകരണം:
# BookingPlugin ക്ലാസ് Serpapi.com Google Search API ഉപയോഗിച്ച് ഹോട്ടലുകളും വിമാനങ്ങളും ബുക്ക് ചെയ്യുന്നതിനുള്ള രീതികൾ നൽകുന്നു. ഇത് ആവശ്യമായ പാരാമീറ്ററുകൾ നിർമ്മിച്ച് API അഭ്യർത്ഥനകൾ അയയ്ക്കുകയും പ്രതികരണങ്ങൾ പ്രോസസ്സ് ചെയ്ത് അനുയോജ്യമായ ബുക്കിംഗ് വിവരങ്ങൾ തിരികെ നൽകുകയും ചെയ്യുന്നു. API കീ (SERPAPI_SEARCH_API_KEY)യും എൻഡ്പോയിന്റ് (SERPAPI_SEARCH_ENDPOINT)യും Google Search API-യിലേക്ക് അഭ്യർത്ഥനകൾ അയയ്ക്കാനും പ്രാമാണീകരിക്കാനും ഉപയോഗിക്കുന്നു.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""
    @kernel_function(description="booking hotel")
    def booking_hotel(self,query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-in Time"])-> Annotated[str, "Return the result of booking hotel infomation"]:

        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "2",
            "currency": "USD",
            "gl": "us",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY
        }

        response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=params)
        if response.status_code == 200:
            response = response.json()
            return response["properties"]
        else:
            return None

    
    @kernel_function(description="booking fight")
    def  booking_fight(self,origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"])-> Annotated[str, "Return the result of booking fight infomation"]:
        
        go_params = {
            "engine": "google_flights",   
            "departure_id": origin,
            "arrival_id": destination,
            "outbound_date": outbound_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }

        print(go_params)

        go_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=go_params)


        result = ''

        if go_response.status_code == 200:
            response = go_response.json()

            result += "# outbound \n " + str(response)
        else:
            print('error!!!')
            # return None

        
        back_params = {
            "engine": "google_flights",   
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": return_date,
            "return_date": return_date,  
            "currency": "USD",
            "hl": "en",
            "api_key": SERPAPI_SEARCH_API_KEY  
        }


        print(back_params)


        back_response = requests.get(SERPAPI_SEARCH_ENDPOINT, params=back_params)



        if back_response.status_code == 200:
            response = back_response.json()

            result += "\n # return \n"  + str(response)

        else:
            print('error!!!')
            # return None
        
        print(result)

        return result

# %% [markdown]
# # വിശദീകരണം:
# SavePlugin ക്ലാസ് Azure AI സേവനങ്ങൾ ഉപയോഗിച്ച് യാത്രാ പദ്ധതികൾ സംരക്ഷിക്കുന്നതിന് saving_plan എന്ന ഒരു രീതിയെ നൽകുന്നു. ഇത് Azure ക്രെഡൻഷ്യലുകൾ സജ്ജമാക്കുന്നു, ഒരു AI ഏജന്റിനെ സൃഷ്ടിക്കുന്നു, ഉപയോക്തൃ ഇൻപുട്ടുകൾ പ്രോസസ്സ് ചെയ്ത് യാത്രാ പദ്ധതി ഉള്ളടക്കം സൃഷ്ടിക്കുകയും സംരക്ഷിക്കുകയും ചെയ്യുന്നു, ഫയൽ സംരക്ഷിക്കൽ, ക്ലീൻഅപ്പ് പ്രവർത്തനങ്ങൾ എന്നിവ കൈകാര്യം ചെയ്യുന്നു. രീതി വിജയകരമായി പൂർത്തിയാകുമ്പോൾ "Saved" എന്നത് മടക്കുന്നു.

# %%
class SavePlugin:
    """Save Plugin for customers"""
    @kernel_function(description="saving plan")
    async def saving_plan(self,tripplan: Annotated[str, "The content of trip plan"])-> Annotated[str, "Return status of save content"]:

        async with (
            DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
        ):

            code_interpreter = CodeInterpreterTool()
            
            agent_definition = await client.agents.create_agent(
                model=ai_agent_settings.model_deployment_name,
                tools=code_interpreter.definitions,
                tool_resources=code_interpreter.resources,
            )


            agent = AzureAIAgent(
                client=client,
                definition=agent_definition,
            )

            thread = await client.agents.create_thread()


            user_inputs = [
                """
            
                        You are my Python programming assistant. Generate code,save """+ tripplan +
                        
                    """    
                        and execute it according to the following requirements

                        1. Save blog content to trip-{YYMMDDHHMMSS}.md

                        2. give me the download this file link
                    """
            ]



            try:
                for user_input in user_inputs:
                    # Add the user input as a chat message
                    await agent.add_chat_message(
                        thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
                    )
                    print(f"# User: '{user_input}'")
                    # Invoke the agent for the specified thread
                    async for content in agent.invoke(thread_id=thread.id):
                        if content.role != AuthorRole.TOOL:
                            print(f"# Agent: {content.content}")

                    
                    messages = await client.agents.list_messages(thread_id=thread.id)

                    # OpenAIPageableListOfThreadMessage
                    # OpenAIPageableListOfThreadMessage


                    for file_path_annotation in messages.file_path_annotations:

                            file_name = os.path.basename(file_path_annotation.text)

                            await client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./trip")

                    
            finally:
                await client.agents.delete_thread(thread.id)
                await client.agents.delete_agent(agent.id)


        return "Saved"

# %% [markdown]
# # വിശദീകരണം:
# ഈ കോഡ് Azure AI ഏജന്റുമാരെ സജ്ജമാക്കുന്നു, വിമാനങ്ങളും ഹോട്ടലുകളും ബുക്ക് ചെയ്യാനും, ഉപയോക്തൃ ഇൻപുട്ടുകൾ അടിസ്ഥാനമാക്കി യാത്രാ പദ്ധതികൾ സംരക്ഷിക്കാനും. Azure ക്രെഡൻഷ്യലുകൾ ഉപയോഗിച്ച് ഏജന്റുമാരെ സൃഷ്ടിക്കുകയും കോൺഫിഗർ ചെയ്യുകയും ചെയ്യുന്നു, ഉപയോക്തൃ ഇൻപുട്ടുകൾ ഒരു ഗ്രൂപ്പ് ചാറ്റ് വഴി പ്രോസസ്സ് ചെയ്യുകയും, പ്രവർത്തനങ്ങൾ പൂർത്തിയാക്കിയ ശേഷം ശരിയായ ക്ലീൻഅപ്പ് ഉറപ്പാക്കുകയും ചെയ്യുന്നു. ഏജന്റുമാർ അവരുടെ പ്രത്യേക പ്രവർത്തനങ്ങൾ നിർവഹിക്കാൻ പ്രത്യേക പ്ലഗിനുകൾ (BookingPlugin, SavePlugin) ഉപയോഗിക്കുന്നു.

# %%
async with (
    DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):
    BOOKING_AGENT_NAME = "BookingAgent"
    BOOKING_AGENT_INSTRUCTIONS = """
    You are a booking agent. Help me book flights or hotels.

    Thought: Please understand the user's intention and confirm whether to use the reservation system to complete the task.

    Actions:
    - For flight bookings, convert the departure and destination names into airport codes.
    - Use the appropriate API for hotel or flight bookings. Verify that all necessary parameters are available. If any parameters are missing, ask the user to provide them. If all parameters are complete, call the corresponding function.
    - If the task is not related to hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
      - For flight bookings, output separate outbound and return contents in the order of:
        Departure Airport | Airline | Flight Number | Departure Time | Arrival Airport | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
      - For hotel bookings, output in the order of:
        Property Name | Property Description | Check-in Time | Check-out Time | Prices | Nearby Places | Hotel Class | GPS Coordinates.
    """

    SAVE_AGENT_NAME = "SaveAgent"
    SAVE_AGENT_INSTRUCTIONS = """
    You are a save tool agent. Help me to save the trip plan.
    """

    # Create agent definition
    booking_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=BOOKING_AGENT_NAME,
        instructions=BOOKING_AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent
    booking_agent = AzureAIAgent(
        client=client,
        definition=booking_agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the sample plugin to the kernel
    booking_agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create agent definition
    save_agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=SAVE_AGENT_NAME,
        instructions=SAVE_AGENT_INSTRUCTIONS
    )

    # Create the AzureAI Agent
    save_agent = AzureAIAgent(
        client=client,
        definition=save_agent_definition,
    )

    save_agent.kernel.add_plugin(SavePlugin(), plugin_name="saving")

    user_inputs = [
        "I have a business trip from London to New York in Feb 20 2025 to Feb 27 2025 ,help me to book a hotel and fight tickets and save it"
    ]

    chat = AgentGroupChat(
        agents=[booking_agent, save_agent],
        termination_strategy=ApprovalTerminationStrategy(agents=[save_agent], maximum_iterations=10),
    )

    try:
        for user_input in user_inputs:
            # Add the user input as a chat message
            await chat.add_chat_message(
                ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")

            async for content in chat.invoke():
                print(f"# {content.role} - {content.name or '*'}: '{content.content}'")

            print(f"# IS COMPLETE: {chat.is_complete}")

            print("*" * 60)
            print("Chat History (In Descending Order):\n")
            async for message in chat.get_chat_messages(agent=save_agent):
                print(f"# {message.role} - {message.name or '*'}: '{message.content}'")
    finally:
        await chat.reset()
        await client.agents.delete_agent(save_agent.id)
        await client.agents.delete_agent(booking_agent.id)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അസത്യവാദം**:
# ഈ രേഖ AI വിവർത്തന സേവനമായ [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് വിവർത്തനം ചെയ്തതാണ്. കൃത്യതയ്ക്കായി ഞങ്ങൾ ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് വിവർത്തനങ്ങളിൽ പിശകുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ മാതൃഭാഷയിലുള്ള മൗലികരേഖയാണ് വിശ്വസനീയമായ ഉറവിടമായി കണക്കാക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ വിവർത്തനം ശുപാർശ ചെയ്യുന്നു. ഈ വിവർത്തനം ഉപയോഗിക്കുന്നതിൽ നിന്നുണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾക്കോ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കോ ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
