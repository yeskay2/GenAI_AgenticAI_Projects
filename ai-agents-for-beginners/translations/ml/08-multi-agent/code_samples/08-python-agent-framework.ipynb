# %% [markdown]
# # 🤝 GitHub മോഡലുകളുമായി മൾട്ടി-ഏജന്റ് വർക്ക്‌ഫ്ലോ സിസ്റ്റങ്ങൾ (Python)
#
# ## 📋 പഠന ലക്ഷ്യങ്ങൾ
#
# ഈ നോട്ട്ബുക്ക് Microsoft Agent Framework ഉപയോഗിച്ച് GitHub മോഡലുകളുമായി സങ്കീർണ്ണമായ മൾട്ടി-ഏജന്റ് സിസ്റ്റങ്ങൾ നിർമ്മിക്കുന്നതിനെക്കുറിച്ച് വിശദീകരിക്കുന്നു. ഘടനാപരമായ വർക്ക്‌ഫ്ലോകളിലൂടെ പരസ്പരം സഹകരിക്കുന്ന നിരവധി പ്രത്യേകതകളുള്ള ഏജന്റുമാരെ നിങ്ങൾ ഓർക്കസ്ട്രേറ്റ് ചെയ്യാൻ പഠിക്കും.
#
# **നിങ്ങൾ നിർമ്മിക്കുന്ന മൾട്ടി-ഏജന്റ് കഴിവുകൾ:**
# - 👥 **ഏജന്റ് സഹകരണം**: ഒരേ ലക്ഷ്യങ്ങൾ കൈവരിക്കാൻ ഒരുമിച്ച് പ്രവർത്തിക്കുന്ന ഏജന്റുമാർ
# - 🔄 **വർക്ക്‌ഫ്ലോ ഓർക്കസ്ട്രേഷൻ**: ഏജന്റുമാരുടെ ഇടപെടലുകളുടെ ഘടനാപരമായ ഏകോപനം
# - 🎭 **പങ്ക് പ്രത്യേകത**: വ്യത്യസ്ത വ്യക്തിത്വങ്ങളും വിദഗ്ധതാ മേഖലകളും ഉള്ള ഏജന്റുമാർ
# - 📋 **ഗുണനിലവാര ഉറപ്പ്**: ഏജന്റ് സഹകരണത്തിലൂടെ അവലോകനം ചെയ്യലും മെച്ചപ്പെടുത്തലും
#
# ## 🎯 മൾട്ടി-ഏജന്റ് ആർക്കിടെക്ചർ ആശയങ്ങൾ
#
# ### മൾട്ടി-ഏജന്റ് പ്രിൻസിപ്പിളുകളുടെ മധ്യഭാഗം
# - **പണി വിഭജനം**: ഓരോ ഏജന്റും പ്രത്യേക ഡൊമെയ്ൻ വിദഗ്ധതയിൽ പ്രത്യേകതയുള്ളവരാണ്
# - **സഹകരിച്ചുള്ള തീരുമാനമെടുക്കൽ**: ഏജന്റുമാർ പരസ്പരം അവലോകനം ചെയ്യുകയും മെച്ചപ്പെടുത്തുകയും ചെയ്യുന്നു
# - **വർക്ക്‌ഫ്ലോ ഏകോപനം**: ഘടനാപരമായ കൈമാറ്റങ്ങളും ആശയവിനിമയ മാതൃകകളും
# - **ഗുണനിലവാര മെച്ചപ്പെടുത്തൽ**: മൾട്ടി-പേഴ്സ്പെക്റ്റീവ് വിശകലനത്തിലൂടെ ആവർത്തന മെച്ചപ്പെടുത്തൽ
#
# ### ഏജന്റ് ഇടപെടൽ മാതൃകകൾ
# - **സീക്വൻഷ്യൽ പ്രോസസ്സിംഗ്**: ക്രമബദ്ധമായ ഏജന്റ് പങ്കാളിത്തത്തോടെ ലീനിയർ വർക്ക്‌ഫ്ലോ
# - **പിയർ റിവ്യൂ**: ഏജന്റുമാർ പരസ്പരം ഔട്ട്പുട്ടുകൾ പരിശോധിക്കുകയും മെച്ചപ്പെടുത്തുകയും ചെയ്യുന്നു
# - **ഹിയറാർക്കിക്കൽ ഘടന**: കീഴിലുള്ള വിദഗ്ധരെ ഏകോപിപ്പിക്കുന്ന ലീഡ് ഏജന്റുമാർ
# - **കൺസെൻസസ് ബിൽഡിംഗ്**: അന്തിമ തീരുമാനങ്ങളിൽ സംഭാവന ചെയ്യുന്ന നിരവധി ഏജന്റുമാർ
#
# ## 🏗️ സാങ്കേതിക ആർക്കിടെക്ചർ
#
# ### വർക്ക്‌ഫ്ലോ സിസ്റ്റം ഘടകങ്ങൾ
# - **Microsoft Agent Framework**: ഉയർന്ന നിലവാരമുള്ള വർക്ക്‌ഫ്ലോ പിന്തുണയുള്ള Python നടപ്പാക്കൽ
# - **WorkflowBuilder**: ഡിക്ലറേറ്റീവ് വർക്ക്‌ഫ്ലോ നിർവചനവും എക്സിക്യൂഷൻ എഞ്ചിനും
# - **Agent Coordination**: ഘടനാപരമായ ആശയവിനിമയവും കൈമാറ്റ സംവിധാനങ്ങളും
# - **Event-Driven Processing**: ഏജന്റ് ഔട്ട്പുട്ടുകൾ അടിസ്ഥാനമാക്കിയുള്ള പ്രതികരണ വർക്ക്‌ഫ്ലോ എക്സിക്യൂഷൻ
#
# ### മൾട്ടി-ഏജന്റ് പ്രോസസ് ഫ്ലോ
# ```python
# User Request → Agent 1 (Specialist) → Agent 2 (Reviewer) → Quality Check
#                 ↓                      ↓                    ↓
#          Initial Solution → Review & Feedback → Refined Output → Final Result
# ```
#
# ## 🎭 ഏജന്റ് റോളുകളുടെ ഉദാഹരണങ്ങൾ
#
# ### ഹോട്ടൽ കോൺസിയർജ് സിസ്റ്റം
# ഈ നോട്ട്ബുക്ക് പ്രത്യേക റോളുകളുള്ള ഒരു യാത്രാ ശുപാർശാ സിസ്റ്റം പ്രദർശിപ്പിക്കുന്നു:
#
# #### 🏨 **ഫ്രണ്ട് ഡെസ്ക് ഏജന്റ്**
# - **വിദഗ്ധത**: യാത്രാ ശുപാർശകളും പ്രാദേശിക അറിവുകളും
# - **വ്യക്തിത്വം**: കാര്യക്ഷമവും പരിചയസമ്പന്നവുമായ സംവാദ ശൈലി
# - **ഉത്തരവാദിത്തങ്ങൾ**: പ്രാഥമിക യാത്രാ ശുപാർശകളും പ്രവർത്തനങ്ങളും സൃഷ്ടിക്കുക
#
# #### 🎩 **കോൺസിയർജ് ഏജന്റ്**
# - **വിദഗ്ധത**: പ്രാമാണികമായ പ്രാദേശിക അനുഭവങ്ങളും ഗുണനിലവാര വിലയിരുത്തലും
# - **വ്യക്തിത്വം**: വിവേചനശക്തിയുള്ള, ടൂറിസ്റ്റ് അനുഭവങ്ങൾ ഒഴിവാക്കുന്നതിൽ ശ്രദ്ധ കേന്ദ്രീകരിച്ചിരിക്കുന്നു
# - **ഉത്തരവാദിത്തങ്ങൾ**: യാത്രാ ശുപാർശകൾ പ്രാമാണികതയ്ക്കായി അവലോകനം ചെയ്യുകയും മെച്ചപ്പെടുത്തുകയും ചെയ്യുക
#
# ## 🔧 സാങ്കേതിക നടപ്പാക്കൽ
#
# ### വർക്ക്‌ഫ്ലോ ആർക്കിടെക്ചർ
# - **ഏജന്റ് നിർവചനം**: പ്രത്യേക നിർദ്ദേശങ്ങളും വ്യക്തിത്വ ക്രമീകരണവും
# - **Workflow Builder**: ഇവന്റ് ഹാൻഡ്ലിംഗുമായി ഡിക്ലറേറ്റീവ് വർക്ക്‌ഫ്ലോ നിർവചനം
# - **ആശയവിനിമയ പ്രോട്ടോക്കോൾ**: ഏജന്റുമാരുടെ ഇടയിൽ ഘടനാപരമായ സന്ദേശ കൈമാറ്റം
# - **ഫല സംയോജനം**: നിരവധി ഏജന്റ് കാഴ്ചപ്പാടുകളിൽ നിന്നുള്ള ഔട്ട്പുട്ടുകൾ സംയോജിപ്പിക്കൽ
#
# ### ഇവന്റ്-ഡ്രിവൻ കോർഡിനേഷൻ
# - **WorkflowEvent**: ഏജന്റ് ആക്റ്റിവേഷൻ, കൈമാറ്റങ്ങൾ എന്നിവയ്ക്കുള്ള ട്രിഗർ പോയിന്റുകൾ
# - **OutputEvent**: ഏജന്റുമാരുടെ ഇടയിൽ ഘടനാപരമായ ഡാറ്റ കൈമാറ്റം
# - **Quality Gates**: വർക്ക്‌ഫ്ലോ പ്രോസസിലെ വാലിഡേഷൻ ചെക്ക്പോയിന്റുകൾ
# - **Feedback Loops**: ഏജന്റ് സഹകരണത്തിലൂടെ ആവർത്തന മെച്ചപ്പെടുത്തൽ
#
# ## ⚙️ മുൻ‌വ്യവസ്ഥകളും ക്രമീകരണവും
#
# **ആവശ്യമായ ഡിപെൻഡൻസികൾ:**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **പരിസ്ഥിതി ക്രമീകരണം (.env ഫയൽ):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 മൾട്ടി-ഏജന്റ് ഡിസൈൻ പാറ്റേണുകൾ
#
# ### 1. **പ്രൊഡ്യൂസർ-കൺസ്യൂമർ പാറ്റേൺ**
# - പ്രത്യേക ഏജന്റുമാർ ഉള്ളടക്കം സൃഷ്ടിക്കുകയും മറ്റുള്ളവർ അവലോകനം ചെയ്യുകയും ചെയ്യുന്നു
# - വ്യക്തമായ കൈമാറ്റ പോയിന്റുകളും ഡാറ്റ കൈമാറ്റ പ്രോട്ടോക്കോളുകളും
# - സ്വതന്ത്ര അവലോകനത്തിലൂടെ ഗുണനിലവാര ഉറപ്പ്
# - ആവർത്തന മെച്ചപ്പെടുത്തലും മെച്ചപ്പെടുത്തൽ ചക്രങ്ങളും
#
# ### 2. **കമ്മിറ്റി പാറ്റേൺ**
# - വ്യത്യസ്ത കാഴ്ചപ്പാടുകൾ സംഭാവന ചെയ്യുന്ന നിരവധി ഏജന്റുമാർ
# - ഘടനാപരമായ ചർച്ചയിലൂടെ കൺസെൻസസ് ബിൽഡിംഗ്
# - ഭാരിത അഭിപ്രായങ്ങളോടെ ജനാധിപത്യ തീരുമാനമെടുക്കൽ
# - സംഘർഷ പരിഹാരവും ടൈ-ബ്രേക്കിംഗ് സംവിധാനങ്ങളും
#
# ### 3. **ഹിയറാർക്കിക്കൽ പാറ്റേൺ**
# - കീഴിലുള്ള വിദഗ്ധരെ ഏകോപിപ്പിക്കുന്ന ലീഡ് ഏജന്റുമാർ
# - വ്യക്തമായ അധികാര ഘടനകളും തീരുമാന പ്രവാഹവും
# - സങ്കീർണ്ണമായ തീരുമാനങ്ങൾക്ക് എസ്കലേഷൻ പാതകൾ
# - പ്രകടന നിരീക്ഷണവും ഗുണനിലവാര നിയന്ത്രണവും
#
# ### 4. **പൈപ്പ്‌ലൈൻ പാറ്റേൺ**
# - പ്രത്യേക ഘട്ടങ്ങളുള്ള സീക്വൻഷ്യൽ പ്രോസസ്സിംഗ്
# - ഓരോ ഏജന്റും അവരുടെ വിദഗ്ധതാ മേഖലയിൽ മൂല്യം കൂട്ടിച്ചേർക്കുന്നു
# - സമാന്തര പ്രോസസ്സിംഗിലൂടെ കാര്യക്ഷമമായ ഔട്ട്പുട്ട്
# - ഓരോ ഘട്ടത്തിലും പിശക് കൈകാര്യം ചെയ്യലും വീണ്ടെടുക്കലും
#
# ## 🚀 ഉയർന്ന നിലവാരമുള്ള മൾട്ടി-ഏജന്റ് സവിശേഷതകൾ
#
# ### വർക്ക്‌ഫ്ലോ ഓർക്കസ്ട്രേഷൻ
# - **ഡൈനാമിക് റൂട്ടിംഗ്**: കോൺടെക്സ്റ്റ് അടിസ്ഥാനമാക്കിയുള്ള ഏജന്റ് തിരഞ്ഞെടുപ്പും റൂട്ടിംഗും
# - **പാരലൽ പ്രോസസ്സിംഗ്**: കാര്യക്ഷമതയ്ക്കായി സമാന്തര ഏജന്റ് എക്സിക്യൂഷൻ
# - **പിശക് വീണ്ടെടുക്കൽ**: ഏജന്റ് പരാജയങ്ങളും റിട്രൈകളും നയിക്കുന്ന ഗ്രേസ്‌ഫുൾ കൈകാര്യം
# - **പ്രകടന നിരീക്ഷണം**: വർക്ക്‌ഫ്ലോ എക്സിക്യൂഷനും ഓപ്റ്റിമൈസേഷനും ട്രാക്കിംഗ്
#
# ### ഏജന്റ് ആശയവിനിമയം
# - **ഘടനാപരമായ മെസേജിംഗ്**: ടൈപ്പ്-സേഫ് ആശയവിനിമയ പ്രോട്ടോക്കോളുകൾ
# - **കോൺടെക്സ്റ്റ് പ്രിസർവേഷൻ**: ഏജന്റുമാരുടെ ഇടയിൽ സംഭാഷണ ചരിത്രം നിലനിർത്തുന്നു
# - **മെറ്റാഡാറ്റ പാസിംഗ്**: ടെക്സ്റ്റ് ഉള്ളടക്കത്തിന് പുറത്ത് സമ്പന്നമായ വിവര കൈമാറ്റം
# - **ഇവന്റ് ബ്രോഡ്കാസ്റ്റിംഗ്**: കോർഡിനേഷനായി പബ്ലിഷ്-സബ്‌സ്‌ക്രൈബ് മാതൃകകൾ
#
# ### ഗുണനിലവാര ഉറപ്പ്
# - **മൾട്ടി-പേഴ്സ്പെക്റ്റീവ് റിവ്യൂ**: വ്യത്യസ്ത ഏജന്റുമാർ വ്യത്യസ്ത കാഴ്ചപ്പാടുകൾ കൊണ്ടുവരുന്നു
# - **ആവർത്തന മെച്ചപ്പെടുത്തൽ**: സഹകരണത്തിലൂടെ പുരോഗമന മെച്ചപ്പെടുത്തൽ
# - **വാലിഡേഷൻ ചെക്ക്പോയിന്റുകൾ**: വർക്ക്‌ഫ്ലോ മുഴുവൻ ഗുണനിലവാര ഗേറ്റുകൾ
# - **പ്രകടന മെട്രിക്‌സ്**: സഹകരണ ഫലപ്രാപ്തി അളക്കുന്നു
#
# ## 📊 ഉപയോഗ കേസുകളും പ്രയോഗങ്ങളും
#
# ### ബിസിനസ് പ്രോസസ് ഓട്ടോമേഷൻ
# - ഡോക്യുമെന്റ് റിവ്യൂ, അംഗീകൃത വർക്ക്‌ഫ്ലോകൾ
# - കസ്റ്റമർ സർവീസ് എസ്കലേഷൻ സിസ്റ്റങ്ങൾ
# - ഗുണനിലവാര ഉറപ്പും അനുസരണ പരിശോധനയും
# - മൾട്ടി-സ്റ്റേജ് ഉള്ളടക്കം സൃഷ്ടിയും എഡിറ്റിംഗും
#
# ### ഗവേഷണവും വിശകലനവും
# - ഗവേഷണ പ്രബന്ധങ്ങൾക്ക് പിയർ റിവ്യൂ സിസ്റ്റങ്ങൾ
# - മൾട്ടി-അനലിസ്റ്റ് ഫിനാൻഷ്യൽ അനാലിസിസ്
# - സഹകരിച്ചുള്ള റിപ്പോർട്ട് എഴുത്തും വസ്തുത പരിശോധിക്കലും
# - അക്കാദമിക് പേപ്പർ റിവ്യൂയും മെച്ചപ്പെടുത്തലും
#
# ### സൃഷ്ടിപരമായ സഹകരണം
# - എഡിറ്റർമാരും റിവ്യൂവർമാരും ഉള്ള ഉള്ളടക്കം സൃഷ്ടിക്കൽ
# - മൾട്ടി-പേഴ്സ്പെക്റ്റീവ് സൃഷ്ടിപരമായ ബ്രെയിൻസ്റ്റോർമിംഗ്
# - ആവർത്തന രൂപകൽപ്പനയും ഫീഡ്ബാക്ക് സിസ്റ്റങ്ങളും
# - സഹകരിച്ചുള്ള കഥ പറയലും ലോക നിർമ്മാണവും
#
# ബുദ്ധിമാനായ മൾട്ടി-ഏജന്റ് സഹകരണങ്ങൾ ഓർക്കസ്ട്രേറ്റ് ചെയ്യാൻ തയ്യാറാണോ? ഏജന്റുമാർ ഒരു ഉയർന്ന പ്രകടനമുള്ള ടീമിനെ പോലെ ഒരുമിച്ച് പ്രവർത്തിക്കുന്ന സിസ്റ്റങ്ങൾ നിർമ്മിക്കാം! 🌟🤖

# %%
! pip install agent-framework-core -U

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent

# %%
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings

# %%
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# Workflow output: Visit the Louvre Museum for an unparalleled art experience.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അസത്യവാദം**:
# ഈ രേഖ AI വിവർത്തന സേവനമായ [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് വിവർത്തനം ചെയ്തതാണ്. കൃത്യതയ്ക്കായി ഞങ്ങൾ ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് വിവർത്തനങ്ങളിൽ പിശകുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള മൗലിക രേഖ പ്രാമാണികമായ ഉറവിടമായി കണക്കാക്കണം. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മാനവ വിവർത്തനം ശുപാർശ ചെയ്യുന്നു. ഈ വിവർത്തനം ഉപയോഗിക്കുന്നതിൽ നിന്നുണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾക്കോ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കോ ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
