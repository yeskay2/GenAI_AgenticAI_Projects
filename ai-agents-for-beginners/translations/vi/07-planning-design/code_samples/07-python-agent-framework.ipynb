# %% [markdown]
# # 🎯 Lập Kế Hoạch & Mẫu Thiết Kế với GitHub Models (Python)
#
# ## 📋 Mục Tiêu Học Tập
#
# Notebook này trình bày các mẫu lập kế hoạch và thiết kế nâng cao để xây dựng các tác nhân thông minh sử dụng Microsoft Agent Framework với GitHub Models. Bạn sẽ học cách tạo ra các tác nhân có khả năng phân tích các vấn đề phức tạp, lập kế hoạch giải pháp nhiều bước, và phối hợp các quy trình làm việc tinh vi.
#
# **Các khả năng nâng cao bạn sẽ thành thạo:**
# - 🧠 **Lập Kế Hoạch Chiến Lược**: Phân chia các nhiệm vụ phức tạp thành các nhiệm vụ nhỏ dễ quản lý
# - 🗺️ **Lý Luận Nhiều Bước**: Các mẫu thực thi nhiệm vụ tuần tự và song song
# - 🎯 **Thiết Kế Hướng Mục Tiêu**: Các tác nhân làm việc hướng tới các mục tiêu cụ thể
# - 🔄 **Lập Kế Hoạch Thích Ứng**: Điều chỉnh chiến lược động dựa trên ngữ cảnh
#
# ## 🎯 Các Khái Niệm Kiến Trúc Lập Kế Hoạch
#
# ### Các Thành Phần Cốt Lõi của Lập Kế Hoạch
# - **Phân Tích Nhiệm Vụ**: Phân chia các vấn đề phức tạp thành các phần nhỏ dễ quản lý
# - **Lập Kế Hoạch Thực Thi**: Xác định thứ tự tối ưu và các phụ thuộc cho các nhiệm vụ nhỏ
# - **Quản Lý Tài Nguyên**: Phân bổ công cụ và khả năng một cách hiệu quả
# - **Theo Dõi Tiến Độ**: Giám sát hoàn thành và thích ứng với các thay đổi
#
# ### Các Mẫu Thiết Kế cho Lập Kế Hoạch
# - **Mẫu Chiến Lược**: Nhiều cách tiếp cận lập kế hoạch cho các tình huống khác nhau
# - **Chuỗi Trách Nhiệm**: Xử lý tuần tự với các tùy chọn dự phòng
# - **Mẫu Lệnh**: Thực thi nhiệm vụ được đóng gói với khả năng hoàn tác/làm lại
# - **Mẫu Quan Sát**: Theo dõi tiến độ và cập nhật dựa trên sự kiện
#
# ## 🏗️ Kiến Trúc Kỹ Thuật
#
# ### Các Thành Phần của Hệ Thống Lập Kế Hoạch
# - **Microsoft Agent Framework**: Triển khai Python với hỗ trợ lập kế hoạch nâng cao
# - **Tích Hợp GitHub Models**: Lý luận và ra quyết định hiệu suất cao
# - **Điều Phối Nhiệm Vụ**: Thực thi phối hợp các quy trình làm việc phức tạp
# - **Quản Lý Trạng Thái**: Theo dõi liên tục tiến độ lập kế hoạch và kết quả
#
# ### Quy Trình Lập Kế Hoạch
# ```python
# Complex Goal → Task Analysis → Subtask Decomposition → Execution Planning
#                 ↓                    ↓                    ↓
#          Priority Assessment → Resource Allocation → Sequential Execution
#                 ↓                    ↓                    ↓
#          Progress Monitoring → Adaptive Replanning → Goal Achievement
# ```
#
# ## 🧠 Các Phương Pháp Lập Kế Hoạch
#
# ### 1. **Lập Kế Hoạch Nhiệm Vụ Phân Cấp**
# - Phân tích từ trên xuống các mục tiêu phức tạp
# - Cấu trúc mục tiêu lồng nhau với các phụ thuộc
# - Lập kế hoạch đệ quy cho các mục tiêu phụ
# - Phân bổ tài nguyên hiệu quả qua các cấp độ
#
# ### 2. **Lập Kế Hoạch Tuần Tự**
# - Thực thi nhiệm vụ từng bước với các phụ thuộc rõ ràng
# - Xử lý lỗi và khôi phục ở mỗi giai đoạn
# - Các điểm kiểm tra tiến độ và xác nhận
# - Khả năng hoàn tác cho các bước thất bại
#
# ### 3. **Lập Kế Hoạch Song Song**
# - Thực thi đồng thời các nhiệm vụ độc lập
# - Đồng bộ hóa tài nguyên và giải quyết xung đột
# - Tối ưu hóa hiệu suất thông qua song song hóa
# - Hoàn thành phối hợp và tổng hợp kết quả
#
# ## ⚙️ Yêu Cầu & Cài Đặt
#
#
# **Các Phụ Thuộc Cần Thiết:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Cấu Hình Môi Trường (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Các Mẫu Thiết Kế Lập Kế Hoạch
#
# ### Lập Kế Hoạch Hướng Mục Tiêu
# - **Mục Tiêu SMART**: Cụ thể, Đo lường được, Có thể đạt được, Liên quan, Có thời hạn
# - **Theo Dõi Cột Mốc**: Đo lường tiến độ và các điểm kiểm tra xác nhận
# - **Tiêu Chí Thành Công**: Định nghĩa rõ ràng về hoàn thành nhiệm vụ
# - **Chiến Lược Thích Ứng**: Điều chỉnh kế hoạch động dựa trên phản hồi
#
# ### Lập Kế Hoạch Nhận Thức Tài Nguyên
# - **Đánh Giá Khả Năng**: Hiểu rõ các công cụ có sẵn và giới hạn của chúng
# - **Cân Bằng Tải**: Phân phối nhiệm vụ tối ưu trên các tài nguyên có sẵn
# - **Quản Lý Ràng Buộc**: Làm việc trong giới hạn hệ thống và API
# - **Tối Ưu Hiệu Suất**: Tối đa hóa hiệu quả và giảm thiểu độ trễ
#
# ### Lập Kế Hoạch Chống Lỗi
# - **Phát Hiện Lỗi**: Xác định sớm các vấn đề trong lập kế hoạch hoặc thực thi
# - **Chiến Lược Khôi Phục**: Tự động dự phòng và các cách tiếp cận thay thế
# - **Bảo Tồn Trạng Thái**: Duy trì tiến độ trong quá trình khôi phục lỗi
# - **Suy Giảm Nhẹ Nhàng**: Thành công một phần khi không thể hoàn thành toàn bộ
#
# ## 🚀 Các Tính Năng Lập Kế Hoạch Nâng Cao
#
# - **Siêu Lập Kế Hoạch**: Các tác nhân lập kế hoạch cách lập kế hoạch
# - **Lập Kế Hoạch Hợp Tác**: Phối hợp nhiều tác nhân cho các dự án phức tạp
# - **Học Từ Kinh Nghiệm**: Cải thiện chiến lược lập kế hoạch theo thời gian
# - **Thích Ứng Thời Gian Thực**: Lập kế hoạch động dựa trên điều kiện thay đổi
#
# ## 📊 Các Trường Hợp Sử Dụng & Ứng Dụng
#
# ### Tự Động Hóa Quy Trình Kinh Doanh
# - Quản lý dự án và lập lịch nhiệm vụ
# - Tối ưu hóa quy trình làm việc và phân bổ tài nguyên
# - Lập kế hoạch chiến lược và hỗ trợ ra quyết định
# - Cải tiến quy trình và tự động hóa
#
# ### Nghiên Cứu & Phân Tích
# - Tổng hợp và đánh giá tài liệu
# - Lập kế hoạch quy trình phân tích dữ liệu
# - Thiết kế và thực thi thí nghiệm
# - Tạo báo cáo và định dạng
#
# ### Dự Án Sáng Tạo
# - Quy trình tạo nội dung
# - Phối hợp dự án đa phương tiện
# - Lập kế hoạch và thực thi chiến dịch
# - Tổ chức và quản lý sự kiện
#
# Sẵn sàng xây dựng các tác nhân lập kế hoạch thông minh có thể giải quyết các thách thức phức tạp, nhiều bước? Hãy cùng kiến tạo các khả năng giải quyết vấn đề tinh vi! 🧠✨

# %%
! pip install agent-framework-core -U

# %%
# 📦 Import Standard Libraries
# os: For environment variable access
# dotenv: For loading environment variables from .env file
import os

from dotenv import load_dotenv

# %%
# 📝 Import Data Modeling Libraries
# Pydantic: For data validation and structured outputs
# BaseModel: Base class for creating data models
# Field: For adding metadata and validation to model fields
# List: Type hint for list collections
from pydantic import BaseModel, Field
from typing import List

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatMessage: For creating structured chat messages
# Role: Enum for message roles (user, assistant, system)
# ChatOptions: Configuration options for chat interactions
# OpenAIChatClient: Client for OpenAI-compatible APIs (GitHub Models)
from agent_framework import ChatMessage, Role, ChatOptions
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# Load configuration from .env file
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎯 Agent Configuration
# Define the agent's name and role

AGENT_NAME = "TravelAgent"

# 📋 System Instructions for Planning Agent
# This agent acts as a coordinator that decides which specialized agents to use
AGENT_INSTRUCTIONS = """You are a planner agent.
    Your job is to decide which agents to run based on the user's request.
    Below are the available agents specialized in different tasks:
    - FlightBooking: For booking flights and providing flight information
    - HotelBooking: For booking hotels and providing hotel information
    - CarRental: For booking cars and providing car rental information
    - ActivitiesBooking: For booking activities and providing activity information
"""

# %%
class SubTask(BaseModel):
    assigned_agent: str = Field(
        description="The specific agent assigned to handle this subtask")
    task_details: str = Field(
        description="Detailed description of what needs to be done for this subtask")


class TravelPlan(BaseModel):
    main_task: str = Field(
        description="The overall travel request from the user")
    subtasks: List[SubTask] = Field(
        description="List of subtasks broken down from the main task, each assigned to a specialized agent")

# %%
options = ChatOptions(response_format=TravelPlan)

# %%
client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
agent =  client.create_agent(name= AGENT_NAME , instructions=AGENT_INSTRUCTIONS)

# %%
messages = [
        ChatMessage(role=Role.USER, text="Create a travel plan for a family of 4, with 2 kids, from Singapore to Melbourne")
    ]

# %%
response = await agent.run(messages,response_format=TravelPlan)

# %%
response.messages[0].text
# Out:
# '{"main_task":"Plan a family trip from Singapore to Melbourne for 4 people, including 2 kids.","subtasks":[{"assigned_agent":"FlightBooking","task_details":"Book one round-trip flight from Singapore to Melbourne for a family of 4, considering family-friendly options."},{"assigned_agent":"HotelBooking","task_details":"Find and book a family-friendly hotel in Melbourne that can accommodate 4 people, including 2 kids."},{"assigned_agent":"CarRental","task_details":"Arrange a car rental in Melbourne for the family to facilitate travel around the city."},{"assigned_agent":"ActivitiesBooking","task_details":"Provide a list of kid-friendly activities and attractions in Melbourne for the family to enjoy."}]}'

# %% [markdown]
# ---
#
# **Tuyên bố miễn trừ trách nhiệm**:
# Tài liệu này đã được dịch bằng dịch vụ dịch thuật AI [Co-op Translator](https://github.com/Azure/co-op-translator). Mặc dù chúng tôi cố gắng đảm bảo độ chính xác, xin lưu ý rằng các bản dịch tự động có thể chứa lỗi hoặc không chính xác. Tài liệu gốc bằng ngôn ngữ bản địa nên được coi là nguồn thông tin chính thức. Đối với các thông tin quan trọng, khuyến nghị sử dụng dịch vụ dịch thuật chuyên nghiệp bởi con người. Chúng tôi không chịu trách nhiệm về bất kỳ sự hiểu lầm hoặc diễn giải sai nào phát sinh từ việc sử dụng bản dịch này.
