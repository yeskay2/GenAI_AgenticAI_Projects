# %% [markdown]
# # 🤝 Sistem Aliran Kerja Multi-Ejen dengan Model GitHub (Python)
#
# ## 📋 Objektif Pembelajaran
#
# Notebook ini menunjukkan cara membina sistem multi-ejen yang canggih menggunakan Microsoft Agent Framework dengan Model GitHub. Anda akan belajar mengatur beberapa ejen khusus yang bekerjasama untuk menyelesaikan masalah kompleks melalui aliran kerja yang terstruktur.
#
# **Keupayaan Multi-Ejen yang Akan Anda Bangunkan:**
# - 👥 **Kerjasama Ejen**: Beberapa ejen bekerjasama untuk mencapai matlamat bersama
# - 🔄 **Orkestrasi Aliran Kerja**: Penyelarasan terstruktur interaksi ejen
# - 🎭 **Pengkhususan Peranan**: Ejen dengan personaliti dan bidang kepakaran yang berbeza
# - 📋 **Jaminan Kualiti**: Semakan dan penambahbaikan melalui kerjasama ejen
#
# ## 🎯 Konsep Seni Bina Multi-Ejen
#
# ### Prinsip Teras Multi-Ejen
# - **Pembahagian Kerja**: Setiap ejen mengkhususkan diri dalam bidang kepakaran tertentu
# - **Pembuatan Keputusan Kolaboratif**: Ejen menyemak dan menambah baik hasil kerja satu sama lain
# - **Penyelarasan Aliran Kerja**: Penyerahan dan corak komunikasi yang terstruktur
# - **Peningkatan Kualiti**: Penambahbaikan berulang melalui analisis pelbagai perspektif
#
# ### Corak Interaksi Ejen
# - **Pemprosesan Berurutan**: Aliran kerja linear dengan penyertaan ejen yang teratur
# - **Semakan Rakan Sebaya**: Ejen mengesahkan dan menambah baik hasil kerja satu sama lain
# - **Struktur Hierarki**: Ejen utama menyelaraskan pakar bawahan
# - **Pembinaan Konsensus**: Beberapa ejen menyumbang kepada keputusan akhir
#
# ## 🏗️ Seni Bina Teknikal
#
# ### Komponen Sistem Aliran Kerja
# - **Microsoft Agent Framework**: Implementasi Python dengan sokongan aliran kerja yang maju
# - **WorkflowBuilder**: Enjin definisi dan pelaksanaan aliran kerja secara deklaratif
# - **Penyelarasan Ejen**: Mekanisme komunikasi dan penyerahan yang terstruktur
# - **Pemprosesan Berasaskan Peristiwa**: Pelaksanaan aliran kerja reaktif berdasarkan hasil ejen
#
# ### Aliran Proses Multi-Ejen
# ```python
# User Request → Agent 1 (Specialist) → Agent 2 (Reviewer) → Quality Check
#                 ↓                      ↓                    ↓
#          Initial Solution → Review & Feedback → Refined Output → Final Result
# ```
#
# ## 🎭 Contoh Peranan Ejen
#
# ### Sistem Concierge Hotel
# Notebook ini menunjukkan sistem cadangan perjalanan dengan peranan khusus:
#
# #### 🏨 **Ejen Meja Depan**
# - **Kepakaran**: Cadangan perjalanan dan pengetahuan tempatan
# - **Personaliti**: Cekap, berpengalaman, gaya komunikasi ringkas
# - **Tanggungjawab**: Menjana cadangan perjalanan dan aktiviti awal
#
# #### 🎩 **Ejen Concierge**
# - **Kepakaran**: Pengalaman tempatan yang autentik dan penilaian kualiti
# - **Personaliti**: Teliti, fokus pada cadangan yang tidak bersifat pelancongan
# - **Tanggungjawab**: Menyemak dan menambah baik cadangan perjalanan untuk keaslian
#
# ## 🔧 Implementasi Teknikal
#
# ### Seni Bina Aliran Kerja
# - **Definisi Ejen**: Arahan khusus dan konfigurasi personaliti
# - **Workflow Builder**: Definisi aliran kerja secara deklaratif dengan pengendalian peristiwa
# - **Protokol Komunikasi**: Penyampaian mesej yang terstruktur antara ejen
# - **Penggabungan Hasil**: Menggabungkan output dari pelbagai perspektif ejen
#
# ### Penyelarasan Berasaskan Peristiwa
# - **WorkflowEvent**: Titik pencetus untuk pengaktifan ejen dan penyerahan
# - **OutputEvent**: Pertukaran data yang terstruktur antara ejen
# - **Pintu Kualiti**: Titik validasi dalam proses aliran kerja
# - **Gelung Maklum Balas**: Penambahbaikan berulang melalui kerjasama ejen
#
# ## ⚙️ Prasyarat & Persediaan
#
# **Keperluan Kebergantungan:**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **Konfigurasi Persekitaran (fail .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 Corak Reka Bentuk Multi-Ejen
#
# ### 1. **Corak Pengeluar-Pengguna**
# - Ejen khusus menjana kandungan untuk disemak oleh ejen lain
# - Titik penyerahan yang jelas dan protokol pertukaran data
# - Jaminan kualiti melalui semakan bebas
# - Kitaran penambahbaikan berulang
#
# ### 2. **Corak Jawatankuasa**
# - Beberapa ejen menyumbang perspektif yang berbeza
# - Pembinaan konsensus melalui perbincangan terstruktur
# - Pembuatan keputusan secara demokratik dengan pendapat yang diberi berat
# - Mekanisme penyelesaian konflik dan pemecahan kebuntuan
#
# ### 3. **Corak Hierarki**
# - Ejen utama menyelaraskan pakar bawahan
# - Struktur kuasa yang jelas dan aliran keputusan
# - Laluan eskalasi untuk keputusan yang kompleks
# - Pemantauan prestasi dan kawalan kualiti
#
# ### 4. **Corak Saluran Paip**
# - Pemprosesan berurutan dengan peringkat khusus
# - Setiap ejen menambah nilai dalam bidang kepakaran mereka
# - Aliran kerja yang cekap melalui pemprosesan selari
# - Pengendalian kesilapan dan pemulihan di setiap peringkat
#
# ## 🚀 Ciri Multi-Ejen Lanjutan
#
# ### Orkestrasi Aliran Kerja
# - **Penghalaan Dinamik**: Pemilihan dan penghalaan ejen berdasarkan konteks
# - **Pemprosesan Selari**: Pelaksanaan ejen serentak untuk kecekapan
# - **Pemulihan Kesilapan**: Pengendalian kegagalan ejen dan percubaan semula secara berkesan
# - **Pemantauan Prestasi**: Penjejakan pelaksanaan aliran kerja dan pengoptimuman
#
# ### Komunikasi Ejen
# - **Pemesejan Terstruktur**: Protokol komunikasi yang selamat jenis
# - **Pemeliharaan Konteks**: Mengekalkan sejarah perbualan antara ejen
# - **Pemindahan Metadata**: Pertukaran maklumat yang kaya di luar kandungan teks
# - **Penyiaran Peristiwa**: Corak penerbit-langgan untuk penyelarasan
#
# ### Jaminan Kualiti
# - **Semakan Pelbagai Perspektif**: Ejen yang berbeza membawa pandangan unik
# - **Penambahbaikan Berulang**: Peningkatan progresif melalui kerjasama
# - **Titik Validasi**: Pintu kualiti sepanjang proses aliran kerja
# - **Metrik Prestasi**: Mengukur keberkesanan kerjasama
#
# ## 📊 Kes Penggunaan & Aplikasi
#
# ### Automasi Proses Perniagaan
# - Aliran kerja semakan dan kelulusan dokumen
# - Sistem eskalasi perkhidmatan pelanggan
# - Jaminan kualiti dan pemeriksaan pematuhan
# - Penciptaan dan penyuntingan kandungan berperingkat
#
# ### Penyelidikan & Analisis
# - Sistem semakan rakan sebaya untuk kertas penyelidikan
# - Analisis kewangan oleh pelbagai penganalisis
# - Penulisan laporan kolaboratif dan semakan fakta
# - Semakan dan penambahbaikan kertas akademik
#
# ### Kolaborasi Kreatif
# - Penciptaan kandungan dengan editor dan penyemak
# - Pemikiran kreatif pelbagai perspektif
# - Reka bentuk berulang dan sistem maklum balas
# - Penceritaan kolaboratif dan pembinaan dunia
#
# Bersedia untuk mengatur kolaborasi multi-ejen yang pintar? Mari bina sistem di mana ejen bekerjasama seperti pasukan berprestasi tinggi! 🌟🤖

# %%
! pip install agent-framework-core -U

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent

# %%
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings

# %%
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# Workflow output: Visit the Louvre Museum for an unparalleled art experience.

# %% [markdown]
# ---
#
# **Penafian**:
# Dokumen ini telah diterjemahkan menggunakan perkhidmatan terjemahan AI [Co-op Translator](https://github.com/Azure/co-op-translator). Walaupun kami berusaha untuk memastikan ketepatan, sila ambil perhatian bahawa terjemahan automatik mungkin mengandungi kesilapan atau ketidaktepatan. Dokumen asal dalam bahasa asalnya harus dianggap sebagai sumber yang berwibawa. Untuk maklumat yang kritikal, terjemahan manusia profesional adalah disyorkan. Kami tidak bertanggungjawab atas sebarang salah faham atau salah tafsir yang timbul daripada penggunaan terjemahan ini.
